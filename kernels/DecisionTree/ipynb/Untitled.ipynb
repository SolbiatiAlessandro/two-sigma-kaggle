# %%
df = pd.read_csv('../../data/market_train_df.csv')

# %%
df
# Out:
#        Unnamed: 0                       time assetCode  \
# 0               0  2007-02-01 22:00:00+00:00       A.N
# 1               1  2007-02-01 22:00:00+00:00     AAI.N
# 2               2  2007-02-01 22:00:00+00:00     AAP.N
# 3               3  2007-02-01 22:00:00+00:00    AAPL.O
# 4               4  2007-02-01 22:00:00+00:00     ABB.N
# 5               5  2007-02-01 22:00:00+00:00     ABC.N
# 6               6  2007-02-01 22:00:00+00:00     ABD.N
# 7               7  2007-02-01 22:00:00+00:00     ABM.N
# 8               8  2007-02-01 22:00:00+00:00     ABT.N
# 9               9  2007-02-01 22:00:00+00:00     ABV.N
# 10             10  2007-02-01 22:00:00+00:00     ABY.N
# 11             11  2007-02-01 22:00:00+00:00     ACF.N
# 12             12  2007-02-01 22:00:00+00:00     ACH.N
# 13             13  2007-02-01 22:00:00+00:00     ACL.N
# 14             14  2007-02-01 22:00:00+00:00     ACS.N
# 15             15  2007-02-01 22:00:00+00:00    ACTS.O
# ...
