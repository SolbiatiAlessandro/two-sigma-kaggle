# %%
from multiprocessing import Pool

def create_lag(df_code,n_lag=[3,7,14,],shift_size=1):
    code = df_code['assetCode'].unique()
    
    for col in return_features:
        for window in n_lag:
            rolled = df_code[col].shift(shift_size).rolling(window=window)
            lag_mean = rolled.mean()
            lag_max = rolled.max()
            lag_min = rolled.min()
            lag_std = rolled.std()
            df_code['%s_lag_%s_mean'%(col,window)] = lag_mean
            df_code['%s_lag_%s_max'%(col,window)] = lag_max
            df_code['%s_lag_%s_min'%(col,window)] = lag_min
#             df_code['%s_lag_%s_std'%(col,window)] = lag_std
    return df_code.fillna(-1)

def generate_lag_features(df,n_lag = [3,7,14]):
    features = ['time', 'assetCode', 'assetName', 'volume', 'close', 'open',
       'returnsClosePrevRaw1', 'returnsOpenPrevRaw1',
       'returnsClosePrevMktres1', 'returnsOpenPrevMktres1',
       'returnsClosePrevRaw10', 'returnsOpenPrevRaw10',
       'returnsClosePrevMktres10', 'returnsOpenPrevMktres10',
       'returnsOpenNextMktres10', 'universe']
    
    assetCodes = df['assetCode'].unique()
    print(assetCodes)
    all_df = []
    df_codes = df.groupby('assetCode')
    df_codes = [df_code[1][['time','assetCode']+return_features] for df_code in df_codes]
    print('total %s df'%len(df_codes))
    
    pool = Pool(4)
    all_df = pool.map(create_lag, df_codes)
    
    new_df = pd.concat(all_df)  
    new_df.drop(return_features,axis=1,inplace=True)
    pool.close()
    
    return new_df

def mis_impute(data):
    for i in data.columns:
        if data[i].dtype == "object":
            data[i] = data[i].fillna("other")
        elif (data[i].dtype == "int64" or data[i].dtype == "float64"):
            data[i] = data[i].fillna(data[i].mean())
        else:
            pass
    return data

def data_prep(market_train):
    lbl = {k: v for v, k in enumerate(market_train['assetCode'].unique())}
    market_train['assetCodeT'] = market_train['assetCode'].map(lbl)
    market_train = market_train.dropna(axis=0)
    return market_train

fcol=['volume', 'close', 'open', 'returnsClosePrevRaw1', 'returnsOpenPrevRaw1', 'returnsClosePrevMktres1', 'returnsOpenPrevMktres1', 'returnsClosePrevRaw10', 'returnsOpenPrevRaw10', 'returnsClosePrevMktres10', 'returnsOpenPrevMktres10', 'returnsClosePrevMktres10_lag_3_mean', 'returnsClosePrevMktres10_lag_3_max', 'returnsClosePrevMktres10_lag_3_min', 'returnsClosePrevMktres10_lag_7_mean', 'returnsClosePrevMktres10_lag_7_max', 'returnsClosePrevMktres10_lag_7_min', 'returnsClosePrevMktres10_lag_14_mean', 'returnsClosePrevMktres10_lag_14_max', 'returnsClosePrevMktres10_lag_14_min', 'returnsClosePrevRaw10_lag_3_mean', 'returnsClosePrevRaw10_lag_3_max', 'returnsClosePrevRaw10_lag_3_min', 'returnsClosePrevRaw10_lag_7_mean', 'returnsClosePrevRaw10_lag_7_max', 'returnsClosePrevRaw10_lag_7_min', 'returnsClosePrevRaw10_lag_14_mean', 'returnsClosePrevRaw10_lag_14_max', 'returnsClosePrevRaw10_lag_14_min', 'open_lag_3_mean', 'open_lag_3_max', 'open_lag_3_min', 'open_lag_7_mean', 'open_lag_7_max', 'open_lag_7_min', 'open_lag_14_mean', 'open_lag_14_max', 'open_lag_14_min', 'close_lag_3_mean', 'close_lag_3_max', 'close_lag_3_min', 'close_lag_7_mean', 'close_lag_7_max', 'close_lag_7_min', 'close_lag_14_mean', 'close_lag_14_max', 'close_lag_14_min', 'assetCodeT']

# %%
import pandas as pd
import numpy as np

# %%
market_test_df = pd.read_csv("../../data/market_test_df.csv").drop('Unnamed: 0', axis=1)
market_test_df['time'] = pd.to_datetime(market_test_df['time'])

# %%
dates = market_test_df['time'].unique()
market_test_df[market_test_df['time'] == dates[0]].tail()
# Out:
#                    time assetCode              assetName      volume  close  \
# 875 2016-10-13 22:00:00    ZION.O          Zions Bancorp   3041647.0  30.36
# 876 2016-10-13 22:00:00    ZIOP.O  ZIOPHARM Oncology Inc   1042606.0   5.22
# 877 2016-10-13 22:00:00    ZLTQ.O  ZELTIQ Aesthetics Inc    358309.0  40.83
# 878 2016-10-13 22:00:00    ZNGA.O              Zynga Inc  13474904.0   2.90
# 879 2016-10-13 22:00:00     ZTS.N             Zoetis Inc   2812177.0  51.02
#
#       open  returnsClosePrevRaw1  returnsOpenPrevRaw1  \
# 875  30.78             -0.027235            -0.017241
# 876   5.19             -0.003817            -0.038889
# 877  40.00              0.012649            -0.003736
# 878   2.91             -0.013605             0.003448
# 879  51.13             -0.007779             0.001960
#
#      returnsClosePrevMktres1  returnsOpenPrevMktres1  returnsClosePrevRaw10  \
# 875                -0.023449               -0.014122              -0.005242
# 876                 0.007138               -0.026353              -0.064516
# 877                 0.017270               -0.001255               0.064113
# 878                -0.008828                0.006002               0.032028
# 879                -0.003743                0.006036               0.000000
#
#      returnsOpenPrevRaw10  returnsClosePrevMktres10  returnsOpenPrevMktres10  \
# 875             -0.004528                  0.004824                 0.015436
# 876             -0.115843                 -0.060812                -0.105750
# 877              0.013942                  0.059521                 0.005566
# 878              0.024648                  0.022769                 0.002984
# 879             -0.011790                  0.011654                 0.008790
#
#      returnsOpenNextMktres10  universe
# 875                 0.060453       1.0
# 876                 0.034282       0.0
# 877                -0.189523       0.0
# 878                -0.039757       1.0
# 879                -0.046295       1.0

# %%
import pickle as pk
_ref_models = pk.load(open("../pickle/_ref_models.pkl","rb"))
# Out:
# /Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/lightgbm/__init__.py:46: UserWarning: Starting from version 2.2.1, the library file in distribution wheels for macOS is built by the Apple Clang (Xcode_8.3.1) compiler.
# This means that in case of installing LightGBM from PyPI via the ``pip install lightgbm`` command, you don't need to install the gcc compiler anymore.
# Instead of that, you need to install the OpenMP library, which is required for running LightGBM on the system with the Apple Clang compiler.
# You can install the OpenMP library by the following command: ``brew install libomp``.
#   "You can install the OpenMP library by the following command: ``brew install libomp``.", UserWarning)

# %%
# load models
gbm_1 = _ref_models[0]
gbm_2 = _ref_models[1]
gbm_3 = _ref_models[2]
gbm_4 = _ref_models[3]
gbm_5 = _ref_models[4]
gbm_6 = _ref_models[5]

# %%
mins,maxs,rng = pk.load(open("../pickle/normalizing.pkl","rb"))

# %%
import time

PREDICTIONS = []

#artificial prediction
#days = env.get_prediction_days()
days = []
for date in dates:
    market_obs_df = market_test_df[market_test_df['time'] == date]
    predictions_template_df = pd.DataFrame({'assetCode':market_test_df[market_test_df['time'] == date]['assetCode'],
                                            'confidenceValue':0.0})
    days.append([market_obs_df,None,predictions_template_df])
 

n_days = 0
n_lag=[3,7,14]
prep_time = 0
prediction_time = 0
packaging_time = 0
total_market_obs_df = []
for (market_obs_df, news_obs_df, predictions_template_df) in days[:5]:
    n_days +=1
    if (n_days%50==0):
        pass
        #print(n_days,end=' ')
    t = time.time()
    market_obs_df['time'] = market_obs_df['time'].dt.date
    
    return_features = ['returnsClosePrevMktres10','returnsClosePrevRaw10','open','close']
    total_market_obs_df.append(market_obs_df)
    if len(total_market_obs_df)==1:
        history_df = total_market_obs_df[0]
    else:
        history_df = pd.concat(total_market_obs_df[-(np.max(n_lag)+1):])
    new_df = generate_lag_features(history_df,n_lag=[3,7,14])
    market_obs_df = pd.merge(market_obs_df,new_df,how='left',on=['time','assetCode'])
    market_obs_df = mis_impute(market_obs_df)
    market_obs_df = data_prep(market_obs_df)
    
    X_live = market_obs_df[fcol].values
    X_live = 1 - ((maxs - X_live) / rng)
    prep_time += time.time() - t
    t = time.time()
    lp = (gbm_1.predict(X_live) + gbm_2.predict(X_live)+gbm_3.predict(X_live)+gbm_4.predict(X_live)+gbm_5.predict(X_live)+gbm_6.predict(X_live))/6
    prediction_time += time.time() -t
    t = time.time()
    confidence = lp
    confidence = (confidence-confidence.min())/(confidence.max()-confidence.min())
    #print("max_min_predict",max_min_predict)
    confidence = confidence * 2 - 1
    preds = pd.DataFrame({'assetCode':market_obs_df['assetCode'],'confidence':confidence})
    predictions_template_df = predictions_template_df.merge(preds,how='left').drop('confidenceValue',axis=1).fillna(0).rename(columns={'confidence':'confidenceValue'})
    PREDICTIONS.append(predictions_template_df)
    packaging_time += time.time() - t
    
#env.write_submission_file()
#sub  = pd.read_csv("submission_versionnew.csv")
# Out:
# /Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ['LGIH.O' 'LGND.O' 'LH.N' 'LHO.N' 'LII.N' 'LILA.O' 'LILAK.O' 'LITE.O'
#  'LIVN.O' 'LKQ.O' 'LLTC.O' 'LLY.N' 'LM.N' 'LMCK.O' 'LMNX.O' 'LMT.N' 'LN.N'
#  'LNC.N' 'LNCE.O' 'LNG.A' 'LNKD.N' 'LNT.N' 'LOCK.N' 'LOGI.O' 'LOGM.O'
#  'LOPE.O' 'LOW.N' 'LPI.N' 'LPL.N' 'LPLA.O' 'LPNT.O' 'LPT.N' 'LPX.N' 'LQ.N'
#  'LRCX.O' 'LSCC.O' 'LSI.N' 'LSTR.O' 'LSXMA.O' 'LSXMK.O' 'LTRPA.O' 'LTXB.O'
#  'LUK.N' 'LULU.O' 'LUV.N' 'LVLT.N' 'LVS.N' 'LXK.N' 'LXP.N' 'LXRX.O'
#  'LYB.N' 'LYG.N' 'LYV.N' 'LZB.N' 'M.N' 'MA.N' 'MAA.N' 'MAC.N' 'MAN.N'
#  'MANH.O' 'MAR.O' 'MAS.N' 'MASI.O' 'MAT.O' 'MBFI.O' 'MBI.N' 'MBT.N'
#  'MCD.N' 'MCHP.O' 'MCK.N' 'MCO.N' 'MD.N' 'MDC.N' 'MDCO.O' 'MDLZ.O' 'MDP.N'
#  'MDRX.O' 'MDSO.O' 'MDT.N' 'MDU.N' 'MDXG.O' 'MEG.N' 'MELI.O' 'MENT.O'
#  'MEOH.O' 'MET.N' 'MFA.N' 'MFC.N' 'MFS.N' 'MGA.N' 'MGLN.O' 'MGM.N'
#  'MGNX.O' 'MGP.N' 'MHK.N' 'MHLD.O' 'MIC.N' 'MIDD.O' 'MIK.O' 'MINI.O'
#  'MITL.O' 'MJN.N' 'MKC.N' 'MKSI.O' 'MKTX.O' 'MLHR.O' 'MLM.N' 'MLNX.O'
#  'MMC.N' 'MMM.N' 'MMP.N' 'MMS.N' 'MMSI.O' 'MNK.N' 'MNR.N' 'MNRO.O'
#  'MNST.O' 'MNTA.O' 'MO.N' 'MOH.N' 'MOMO.O' 'MON.N' 'MORE.N' 'MOS.N'
#  'MPC.N' 'MPEL.O' 'MPLX.N' 'MPW.N' 'MPWR.O' 'MRC.N' 'MRCY.O' 'MRK.N'
#  'MRO.N' 'MRVL.O' 'MS.N' 'MSCC.O' 'MSCI.N' 'MSFT.O' 'MSGN.N' 'MSI.N'
#  'MSM.N' 'MTB.N' 'MTCH.O' 'MTDR.N' 'MTG.N' 'MTN.N' 'MTOR.N' 'MTSI.O'
#  'MTU.N' 'MTZ.N' 'MU.O' 'MUR.N' 'MUSA.N' 'MUX.N' 'MWA.N' 'MXIM.O' 'MXL.N'
#  'MYCC.N' 'MYGN.O' 'MYL.O' 'N.N' 'NAT.N' 'NATI.O' 'NAV.N' 'NAVI.O'
#  'NBIX.O' 'NBL.N' 'NBR.N' 'NCLH.O' 'NCMI.O' 'NCR.N' 'NCS.N' 'NDAQ.O'
#  'NDSN.O' 'NE.N' 'NEE.N' 'NEM.N' 'NEP.N' 'NEWM.N' 'NEWR.N' 'NFG.N'
#  'NFLX.O' 'NFX.N' 'NG.A' 'NGD.A' 'NGL.N' 'NGVT.N' 'NHI.N' 'NI.N' 'NJR.N'
#  'NKE.N' 'NKTR.O' 'NLSN.N' 'NLY.N' 'NMBL.N' 'NNN.N' 'NOC.N' 'NOK.N'
#  'NOMD.N' 'NOV.N' 'NOW.N' 'NRF.N' 'NRG.N' 'NRZ.N' 'NSA.N' 'NSAM.N' 'NSC.N'
#  'NSM.N' 'NSR.N' 'NTAP.O' 'NTCT.O' 'NTES.O' 'NTGR.O' 'NTRI.O' 'NTRS.O'
#  'NUAN.O' 'NUE.N' 'NUS.N' 'NUVA.O' 'NVCR.O' 'NVDA.O' 'NVO.N' 'NVRO.N'
#  'NVS.N' 'NWBI.O' 'NWE.N' 'NWL.N' 'NWS.O' 'NWSA.O' 'NXPI.O' 'NXST.O'
#  'NXTM.O' 'NYCB.N' 'NYLD.N' 'NYT.N' 'O.N' 'OA.N' 'OAS.N' 'OC.N' 'OCLR.O'
#  'ODFL.O' 'ODP.O' 'OFC.N' 'OGE.N' 'OHI.N' 'OI.N' 'OII.N' 'OIS.N' 'OKE.N'
#  'OKS.N' 'OLED.O' 'OLLI.O' 'OLN.N' 'OMC.N' 'OMF.N' 'OMI.N' 'ON.O' 'ONB.O'
#  'ONCE.O' 'OPHT.O' 'OPK.O' 'ORAN.N' 'ORBC.O' 'ORCL.N' 'ORI.N' 'ORLY.O'
#  'OSG.N' 'OSK.N' 'OTEX.O' 'OUT.N' 'OXY.N' 'OZM.N' 'P.N' 'PAA.N' 'PAAS.O'
#  'PACB.O' 'PACW.O' 'PAG.N' 'PAH.N' 'PANW.N' 'PAY.N' 'PAYC.N' 'PAYX.O'
#  'PB.N' 'PBCT.O' 'PBF.N' 'PBH.N' 'PBI.N' 'PBR.N' 'PBRa.N' 'PBYI.N'
#  'PCAR.O' 'PCG.N' 'PCH.O' 'PCLN.O' 'PCRX.O' 'PDCE.O' 'PDCO.O' 'PDM.N'
#  'PDS.N' 'PE.N' 'PEB.N' 'PEG.N' 'PEGA.O' 'PEGI.O' 'PEI.N' 'PENN.O' 'PEP.N'
#  'PF.N' 'PFE.N' 'PFG.N' 'PFGC.N' 'PFPT.O' 'PG.N' 'PGH.N' 'PGR.N' 'PGRE.N'
#  'PH.N' 'PHG.N' 'PHH.N' 'PHM.N' 'PII.N' 'PINC.O' 'PKG.N' 'PKI.N' 'PKX.N'
#  'PLAB.O' 'PLAY.O' 'PLCE.O' 'PLD.N' 'PLKI.O' 'PLNT.N' 'PM.N' 'PMC.N'
#  'PMT.N' 'PNC.N' 'PNFP.O' 'PNK.O' 'PNM.N' 'PNR.N' 'PNRA.O' 'PNW.N'
#  'PODD.O' 'POL.N' 'POOL.O' 'POR.N' 'POST.N' 'POT.N' 'PPC.O' 'PPG.N'
#  'PPL.N' 'PPS.N' 'PRAA.O' 'PRAH.O' 'PRGO.N' 'PRGS.O' 'PRI.N' 'PRIM.O'
#  'PRTA.O' 'PRTY.N' 'PRU.N' 'PRXL.O' 'PSA.N' 'PSEC.O' 'PSO.N' 'PSTG.N'
#  'PSX.N' 'PSXP.N' 'PTC.O' 'PTEN.O' 'PTLA.O' 'PUK.N' 'PVG.N' 'PVH.N'
#  'PVTB.O' 'PWE.N' 'PWR.N' 'PX.N' 'PXD.N' 'PYPL.O' 'PZZA.O' 'Q.N' 'QCOM.O'
#  'QEP.N' 'QLYS.O' 'QRVO.O' 'QSII.O' 'QSR.N' 'QTS.N' 'QUOT.N' 'QVCA.O'
#  'R.N' 'RACE.N' 'RAD.N' 'RAI.N' 'RARE.O' 'RATE.N' 'RAX.N' 'RBA.N' 'RBS.N'
#  'RCL.N' 'RDC.N' 'RDN.N' 'RDSa.N' 'RDSb.N' 'RDUS.O' 'REG.N' 'REGN.O'
#  'RES.N' 'REXR.N' 'RF.N' 'RGC.N' 'RGEN.O' 'RGLD.O' 'RHI.N' 'RHP.N' 'RHT.N'
#  'RICE.N' 'RIG.N' 'RIO.N' 'RJF.N' 'RL.N' 'RLGY.N' 'RLJ.N' 'RMBS.O' 'RMD.N'
#  'RNG.N' 'RNR.N' 'RNST.O' 'ROCK.O' 'ROIC.O' 'ROK.N' 'ROL.N' 'ROP.N'
#  'ROST.O' 'RP.O' 'RPAI.N' 'RPM.N' 'RPT.N' 'RRC.N' 'RRR.O' 'RS.N' 'RSG.N'
#  'RSPP.N' 'RTN.N' 'RTRX.O' 'RWT.N' 'RXN.N' 'RY.N' 'RYAAY.O' 'RYN.N' 'S.N'
#  'SAAS.O' 'SABR.O' 'SAFM.O' 'SAGE.O' 'SAIC.N' 'SAN.N' 'SAND.A' 'SANM.O'
#  'SAP.N' 'SATS.O' 'SAVE.O' 'SBAC.O' 'SBGI.O' 'SBGL.N' 'SBH.N' 'SBNY.O'
#  'SBRA.O' 'SBS.N' 'SBUX.O' 'SC.N' 'SCAI.O' 'SCCO.N' 'SCG.N' 'SCHW.N'
#  'SCI.N' 'SCOR.O' 'SCS.N' 'SCSS.O' 'SCTY.O' 'SDRL.N' 'SE.N' 'SEAS.N'
#  'SEE.N' 'SEIC.O' 'SEM.N' 'SEMG.N' 'SEP.N' 'SERV.N' 'SF.N' 'SFL.N'
#  'SFLY.O' 'SFM.O' 'SFS.N' 'SGEN.O' 'SGMS.O' 'SGYP.O' 'SHAK.N' 'SHEN.O'
#  'SHLD.O' 'SHLM.O' 'SHLX.N' 'SHO.N' 'SHOO.O' 'SHOP.N' 'SHPG.O' 'SHW.N'
#  'SID.N' 'SIG.N' 'SIGI.O' 'SIMO.O' 'SINA.O' 'SIR.O' 'SIRI.O' 'SIVB.O'
#  'SIX.N' 'SJI.N' 'SJM.N' 'SJR.N' 'SKM.N' 'SKT.N' 'SKX.N' 'SKYW.O' 'SLAB.O'
#  'SLB.N' 'SLCA.N' 'SLF.N' 'SLG.N' 'SLGN.O' 'SLM.O' 'SM.N' 'SMCI.O'
#  'SMFG.N' 'SMG.N' 'SMTC.O' 'SNA.N' 'SNCR.O' 'SNE.N' 'SNH.O' 'SNI.O'
#  'SNN.N' 'SNPS.O' 'SNR.N' 'SNV.N' 'SNY.N' 'SO.N' 'SOHU.O' 'SON.N' 'SONC.O'
#  'SPB.N' 'SPG.N' 'SPGI.N' 'SPLK.O' 'SPLS.O' 'SPN.N' 'SPNC.O' 'SPR.N'
#  'SPTN.O' 'SPWR.O' 'SPXC.N' 'SQ.N' 'SQM.N' 'SR.N' 'SRC.N' 'SRCL.O' 'SRE.N'
#  'SRG.N' 'SRPT.O' 'SSL.N' 'SSNC.O' 'SSP.N' 'SSW.N' 'SSYS.O' 'ST.N'
#  'STAG.N' 'STAR.N' 'STAY.N' 'STE.N' 'STI.N' 'STJ.N' 'STL.N' 'STLD.O'
#  'STM.N' 'STMP.O' 'STNG.N' 'STOR.N' 'STRZA.O' 'STT.N' 'STWD.N' 'STX.O'
#  'STZ.N' 'SU.N' 'SUI.N' 'SUM.N' 'SUN.N' 'SUPN.O' 'SWC.N' 'SWFT.N' 'SWHC.O'
#  'SWK.N' 'SWKS.O' 'SWN.N' 'SWX.N' 'SXL.N' 'SYF.N' 'SYK.N' 'SYKE.O'
#  'SYMC.O' 'SYNA.O' 'SYNT.O' 'SYRG.A' 'SYT.N' 'SYY.N' 'T.N' 'TAHO.N'
#  'TAP.N' 'TASR.O' 'TBI.N' 'TBPH.O' 'TCB.N' 'TCBI.O' 'TCK.N' 'TCO.N' 'TD.N'
#  'TDC.N' 'TDG.N' 'TDS.N' 'TEAM.O' 'TECD.O' 'TECH.O' 'TEF.N' 'TEL.N'
#  'TEN.N' 'TER.N' 'TERP.O' 'TEVA.N' 'TEX.N' 'TFSL.O' 'TGI.N' 'TGNA.N'
#  'TGP.N' 'TGT.N' 'THC.N' 'THG.N' 'THO.N' 'THRM.O' 'THS.N' 'TIF.N' 'TILE.O'
#  'TIME.N' 'TIVO.O' 'TJX.N' 'TKR.N' 'TLLP.N' 'TLN.N' 'TLRD.N' 'TMH.N'
#  'TMK.N' 'TMO.N' 'TMUS.O' 'TNET.N' 'TOL.N' 'TOT.N' 'TPC.N' 'TPH.N'
#  'TPRE.N' 'TPX.N' 'TRCO.N' 'TREE.O' 'TRGP.N' 'TRI.N' 'TRIP.O' 'TRMB.O'
#  'TRMK.O' 'TRN.N' 'TRNO.N' 'TROW.O' 'TRP.N' 'TRQ.N' 'TRTN.N' 'TRU.N'
#  'TRUE.O' 'TRV.N' 'TS.N' 'TSCO.O' 'TSE.N' 'TSEM.O' 'TSL.N' 'TSLA.O'
#  'TSM.N' 'TSN.N' 'TSO.N' 'TSRO.O' 'TSS.N' 'TSU.N' 'TTC.N' 'TTEK.O' 'TTM.N'
#  'TTMI.O' 'TTS.O' 'TTWO.O' 'TUP.N' 'TV.N' 'TVPT.N' 'TWOU.O' 'TWTR.N'
#  'TWX.N' 'TX.N' 'TXMD.A' 'TXN.O' 'TXRH.O' 'TXT.N' 'TYPE.O' 'UAL.N' 'UAc.N'
#  'UBNT.O' 'UBS.N' 'UBSI.O' 'UCBI.O' 'UDR.N' 'UE.N' 'UFS.N' 'UGI.N' 'UGP.N'
#  'UHS.N' 'UL.N' 'ULTA.O' 'UMBF.O' 'UMC.N' 'UMPQ.O' 'UN.N' 'UNFI.O' 'UNH.N'
#  'UNM.N' 'UNP.N' 'UNT.N' 'UNVR.N' 'UPS.N' 'URBN.O' 'URI.N' 'USB.N'
#  'USCR.O' 'USFD.N' 'USG.N' 'UTHR.O' 'UTX.N' 'UVE.N' 'V.N' 'VA.O' 'VAL.N'
#  'VALE.N' 'VAR.N' 'VECO.O' 'VEEV.N' 'VER.N' 'VFC.N' 'VG.N' 'VGR.N'
#  'VIAB.O' 'VIAV.O' 'VIPS.N' 'VIV.N' 'VLO.N' 'VLY.N' 'VMC.N' 'VMW.N'
#  'VNO.N' 'VNTV.N' 'VOD.O' 'VOYA.N' 'VR.N' 'VRNT.O' 'VRSK.O' 'VRSN.O'
#  'VRTU.O' 'VRTX.O' 'VSAT.O' 'VSH.N' 'VSTO.N' 'VTR.N' 'VVC.N' 'VWR.O'
#  'VZ.N' 'W.N' 'WAB.N' 'WAFD.O' 'WAIR.N' 'WAL.N' 'WAT.N' 'WB.O' 'WBA.O'
#  'WBC.N' 'WBMD.O' 'WBS.N' 'WCC.N' 'WCG.N' 'WCN.N' 'WDAY.N' 'WDC.O' 'WDR.N'
#  'WEB.O' 'WEC.N' 'WEN.O' 'WERN.O' 'WES.N' 'WETF.O' 'WFC.N' 'WFM.O' 'WFT.N'
#  'WGL.N' 'WHR.N' 'WIT.N' 'WIX.O' 'WLK.N' 'WLTW.O' 'WM.N' 'WMB.N' 'WMGI.O'
#  'WMS.N' 'WMT.N' 'WNC.N' 'WNR.N' 'WOOF.O' 'WOR.N' 'WPC.N' 'WPG.N' 'WPX.N'
#  'WPZ.N' 'WR.N' 'WRB.N' 'WRE.N' 'WRI.N' 'WRK.N' 'WSM.N' 'WST.N' 'WTFC.O'
#  'WTR.N' 'WU.N' 'WUBA.N' 'WWAV.N' 'WWD.O' 'WWE.N' 'WWW.N' 'WY.N' 'WYN.N'
#  'WYNN.O' 'X.N' 'XEC.N' 'XEL.N' 'XHR.N' 'XL.N' 'XLNX.O' 'XLRN.O' 'XNCR.O'
#  'XOM.N' 'XON.N' 'XPO.N' 'XRAY.O' 'XRS.N' 'XXIA.O' 'XYL.N' 'YELP.N'
#  'YHOO.O' 'YNDX.O' 'YPF.N' 'YRD.N' 'YUM.N' 'YY.O' 'Z.O' 'ZAYO.N' 'ZBH.N'
#  'ZBRA.O' 'ZEN.N' 'ZG.O' 'ZION.O' 'ZIOP.O' 'ZLTQ.O' 'ZNGA.O' 'ZTS.N']
# total 880 df
# ['LGIH.O' 'LGND.O' 'LH.N' ... 'LGF.N' 'SNX.N' 'VNDA.O']
# total 1849 df
# ['LGIH.O' 'LGND.O' 'LH.N' ... 'E.N' 'HNI.N' 'ILG.O']
# total 1852 df
# ['LGIH.O' 'LGND.O' 'LH.N' ... 'HNI.N' 'ILG.O' 'AZO.N']
# total 1853 df
# ['LGIH.O' 'LGND.O' 'LH.N' ... 'FWRD.O' 'IDA.N' 'TRS.O']
# total 1858 df

# %%
PREDICTIONS[0]
df_X_live = 1 - ((maxs - market_obs_df[fcol]) / rng)

# %%
pk.dump(df_X_live, open("../pickle/_ref_rolling_dataset_1.pkl","wb"))

# %%
df_X_live.tail()
# Out:
#         volume     close      open  returnsClosePrevRaw1  returnsOpenPrevRaw1  \
# 1838  0.002506  0.020561  0.003065              0.021347             0.005318
# 1839  0.001910  0.003326  0.000522              0.020294             0.005440
# 1840  0.000858  0.026310  0.004092              0.020278             0.005460
# 1841  0.026670  0.001856  0.000283              0.020623             0.005327
# 1842  0.002891  0.033462  0.005109              0.020639             0.005330
#
#       returnsClosePrevMktres1  returnsOpenPrevMktres1  returnsClosePrevRaw10  \
# 1838                 0.027004                0.004671               0.020404
# 1839                 0.025939                0.004732               0.018350
# 1840                 0.025929                0.004831               0.020646
# 1841                 0.026275                0.004684               0.020080
# 1842                 0.026293                0.004676               0.019774
#
#       returnsOpenPrevRaw10  returnsClosePrevMktres10     ...      \
# 1838              0.004706                  0.067685     ...
# 1839              0.004399                  0.065748     ...
# 1840              0.005015                  0.067426     ...
# 1841              0.004837                  0.066765     ...
# 1842              0.004691                  0.067179     ...
#
#       close_lag_3_mean  close_lag_3_max  close_lag_3_min  close_lag_7_mean  \
# 1838               0.0              0.0              0.0               0.0
# 1839               0.0              0.0              0.0               0.0
# 1840               0.0              0.0              0.0               0.0
# 1841               0.0              0.0              0.0               0.0
# 1842               0.0              0.0              0.0               0.0
#
#       close_lag_7_max  close_lag_7_min  close_lag_14_mean  close_lag_14_max  \
# 1838              0.0              0.0                0.0               0.0
# 1839              0.0              0.0                0.0               0.0
# 1840              0.0              0.0                0.0               0.0
# 1841              0.0              0.0                0.0               0.0
# 1842              0.0              0.0                0.0               0.0
#
#       close_lag_14_min  assetCodeT
# 1838               0.0    0.561564
# 1839               0.0    0.561870
# 1840               0.0    0.562175
# 1841               0.0    0.562481
# 1842               0.0    0.562786
#
# [5 rows x 48 columns]

# %%
compare_X_live = pk.load(open('../pickle/rolling_dataset_1.pkl','rb'))

# %%
compare_X_live.tail()
# Out:
#         volume     close      open  returnsClosePrevRaw1  returnsOpenPrevRaw1  \
# 1838  0.002506  0.020561  0.003065              0.021347             0.005318
# 1839  0.001910  0.003326  0.000522              0.020294             0.005440
# 1840  0.000858  0.026310  0.004092              0.020278             0.005460
# 1841  0.026670  0.001856  0.000283              0.020623             0.005327
# 1842  0.002891  0.033462  0.005109              0.020639             0.005330
#
#       returnsClosePrevMktres1  returnsOpenPrevMktres1  returnsClosePrevRaw10  \
# 1838                 0.027004                0.004671               0.020404
# 1839                 0.025939                0.004732               0.018350
# 1840                 0.025929                0.004831               0.020646
# 1841                 0.026275                0.004684               0.020080
# 1842                 0.026293                0.004676               0.019774
#
#       returnsOpenPrevRaw10  returnsClosePrevMktres10     ...      \
# 1838              0.004706                  0.067685     ...
# 1839              0.004399                  0.065748     ...
# 1840              0.005015                  0.067426     ...
# 1841              0.004837                  0.066765     ...
# 1842              0.004691                  0.067179     ...
#
#       lag_3_close_mean  lag_3_close_max  lag_3_close_min  lag_7_close_mean  \
# 1838               0.0              0.0              0.0               0.0
# 1839               0.0              0.0              0.0               0.0
# 1840               0.0              0.0              0.0               0.0
# 1841               0.0              0.0              0.0               0.0
# 1842               0.0              0.0              0.0               0.0
#
#       lag_7_close_max  lag_7_close_min  lag_14_close_mean  lag_14_close_max  \
# 1838              0.0              0.0                0.0               0.0
# 1839              0.0              0.0                0.0               0.0
# 1840              0.0              0.0                0.0               0.0
# 1841              0.0              0.0                0.0               0.0
# 1842              0.0              0.0                0.0               0.0
#
#       lag_14_close_min  assetCodeT
# 1838               0.0    0.561564
# 1839               0.0    0.561870
# 1840               0.0    0.562175
# 1841               0.0    0.562481
# 1842               0.0    0.562786
#
# [5 rows x 48 columns]

# %%
compare_X_live.iloc[0][0]
# Out:
# 0.0011599427047023214

# %%
compare_X_live.columns[9], compare_X_live.columns[10], compare_X_live.columns[5], compare_X_live.columns[6]
# Out:
# ('returnsClosePrevMktres10',
#  'returnsOpenPrevMktres10',
#  'returnsClosePrevMktres1',
#  'returnsOpenPrevMktres1')

# %%
for i in range(len(df_X_live)):
    for j in range(len(df_X_live.iloc[i])):
        equal = df_X_live.iloc[i][j] == compare_X_live.iloc[i][j]
        if not equal:
            print("NOT EQUAL ON {} {}".format(i,j))
            print(df_X_live.iloc[i][j])
            print(compare_X_live.iloc[i][j])
# Out:
# NOT EQUAL ON 8 9
# 0.06736583038573696
# 0.06734593381749365
# NOT EQUAL ON 8 10
# 0.014867325957504507
# 0.014865896674771673
# NOT EQUAL ON 118 5
# 0.02659697260983085
# 0.026603590675826294
# NOT EQUAL ON 118 6
# 0.004723669863732627
# 0.004707785826653765
# NOT EQUAL ON 118 9
# 0.06736583038573696
# 0.06734593381749365
# NOT EQUAL ON 118 10
# 0.014867325957504507
# 0.014865896674771673
# NOT EQUAL ON 144 9
# 0.06736583038573696
# 0.06734593381749365
# NOT EQUAL ON 144 10
# 0.014867325957504507
# 0.014865896674771673
# NOT EQUAL ON 177 9
# 0.06736583038573696
# 0.06734593381749365
# NOT EQUAL ON 177 10
# 0.014867325957504507
# 0.014865896674771673
# NOT EQUAL ON 222 9
# 0.06736583038573696
# 0.06734593381749365
# NOT EQUAL ON 222 10
# 0.014867325957504507
# 0.014865896674771673
# NOT EQUAL ON 238 9
# 0.06736583038573696
# 0.06734593381749365
# NOT EQUAL ON 238 10
# 0.014867325957504507
# 0.014865896674771673
# NOT EQUAL ON 281 9
# 0.06736583038573696
# 0.06734593381749365
# NOT EQUAL ON 281 10
# 0.014867325957504507
# 0.014865896674771673
# NOT EQUAL ON 313 9
# 0.06736583038573696
# 0.06734593381749365
# NOT EQUAL ON 313 10
# 0.014867325957504507
# 0.014865896674771673
# NOT EQUAL ON 351 9
# 0.06736583038573696
# 0.06734593381749365
# NOT EQUAL ON 351 10
# 0.014867325957504507
# 0.014865896674771673
# NOT EQUAL ON 385 9
# 0.06736583038573696
# 0.06734593381749365
# NOT EQUAL ON 385 10
# 0.014867325957504507
# 0.014865896674771673
# NOT EQUAL ON 420 9
# 0.06736583038573696
# 0.06734593381749365
# NOT EQUAL ON 420 10
# 0.014867325957504507
# 0.014865896674771673
# NOT EQUAL ON 465 9
# 0.06736583038573696
# 0.06734593381749365
# NOT EQUAL ON 465 10
# 0.014867325957504507
# 0.014865896674771673
# NOT EQUAL ON 469 9
# 0.06736583038573696
# 0.06734593381749365
# NOT EQUAL ON 469 10
# 0.014867325957504507
# 0.014865896674771673
# NOT EQUAL ON 491 9
# 0.06736583038573696
# 0.06734593381749365
# NOT EQUAL ON 491 10
# 0.014867325957504507
# 0.014865896674771673
# NOT EQUAL ON 525 9
# 0.06736583038573696
# 0.06734593381749365
# NOT EQUAL ON 525 10
# 0.014867325957504507
# 0.014865896674771673
# NOT EQUAL ON 574 9
# 0.06736583038573696
# 0.06734593381749365
# NOT EQUAL ON 574 10
# 0.014867325957504507
# 0.014865896674771673
# NOT EQUAL ON 592 9
# 0.06736583038573696
# 0.06734593381749365
# NOT EQUAL ON 592 10
# 0.014867325957504507
# 0.014865896674771673
# NOT EQUAL ON 670 9
# 0.06736583038573696
# 0.06734593381749365
# NOT EQUAL ON 670 10
# 0.014867325957504507
# 0.014865896674771673
# NOT EQUAL ON 682 9
# 0.06736583038573696
# 0.06734593381749365
# NOT EQUAL ON 682 10
# 0.014867325957504507
# 0.014865896674771673
# NOT EQUAL ON 702 9
# 0.06736583038573696
# 0.06734593381749365
# NOT EQUAL ON 702 10
# 0.014867325957504507
# 0.014865896674771673
# NOT EQUAL ON 703 9
# 0.06736583038573696
# 0.06734593381749365
# NOT EQUAL ON 703 10
# 0.014867325957504507
# 0.014865896674771673
# NOT EQUAL ON 761 9
# 0.06736583038573696
# 0.06734593381749365
# NOT EQUAL ON 761 10
# 0.014867325957504507
# 0.014865896674771673
# NOT EQUAL ON 780 5
# 0.02659697260983085
# 0.026603590675826294
# NOT EQUAL ON 780 6
# 0.004723669863732627
# 0.004707785826653765
# NOT EQUAL ON 780 9
# 0.06736583038573696
# 0.06734593381749365
# NOT EQUAL ON 780 10
# 0.014867325957504507
# 0.014865896674771673
# NOT EQUAL ON 933 9
# 0.06736583038573696
# 0.06734593381749365
# NOT EQUAL ON 933 10
# 0.014867325957504507
# 0.014865896674771673
# NOT EQUAL ON 1144 9
# 0.06736583038573696
# 0.06734593381749365
# NOT EQUAL ON 1144 10
# 0.014867325957504507
# 0.014865896674771673
# NOT EQUAL ON 1187 5
# 0.02659697260983085
# 0.026603590675826294
# NOT EQUAL ON 1187 6
# 0.004723669863732627
# 0.004707785826653765
# NOT EQUAL ON 1187 9
# 0.06736583038573696
# 0.06734593381749365
# NOT EQUAL ON 1187 10
# 0.014867325957504507
# 0.014865896674771673
# NOT EQUAL ON 1233 9
# 0.06736583038573696
# 0.06734593381749365
# NOT EQUAL ON 1233 10
# 0.014867325957504507
# 0.014865896674771673
# NOT EQUAL ON 1390 9
# 0.06736583038573696
# 0.06734593381749365
# NOT EQUAL ON 1390 10
# 0.014867325957504507
# 0.014865896674771673
# NOT EQUAL ON 1407 9
# 0.06736583038573696
# 0.06734593381749365
# NOT EQUAL ON 1407 10
# 0.014867325957504507
# 0.014865896674771673
# NOT EQUAL ON 1418 9
# 0.06736583038573696
# 0.06734593381749365
# NOT EQUAL ON 1418 10
# 0.014867325957504507
# 0.014865896674771673
# NOT EQUAL ON 1423 5
# 0.02659697260983085
# 0.026603590675826294
# NOT EQUAL ON 1423 6
# 0.004723669863732627
# 0.004707785826653765
# NOT EQUAL ON 1423 9
# 0.06736583038573696
# 0.06734593381749365
# NOT EQUAL ON 1423 10
# 0.014867325957504507
# 0.014865896674771673
# NOT EQUAL ON 1507 5
# 0.02659697260983085
# 0.026603590675826294
# NOT EQUAL ON 1507 6
# 0.004723669863732627
# 0.004707785826653765
# NOT EQUAL ON 1507 9
# 0.06736583038573696
# 0.06734593381749365
# NOT EQUAL ON 1507 10
# 0.014867325957504507
# 0.014865896674771673
# NOT EQUAL ON 1513 9
# 0.06736583038573696
# 0.06734593381749365
# NOT EQUAL ON 1513 10
# 0.014867325957504507
# 0.014865896674771673
# NOT EQUAL ON 1526 9
# 0.06736583038573696
# 0.06734593381749365
# NOT EQUAL ON 1526 10
# 0.014867325957504507
# 0.014865896674771673
# NOT EQUAL ON 1530 9
# 0.06736583038573696
# 0.06734593381749365
# NOT EQUAL ON 1530 10
# 0.014867325957504507
# 0.014865896674771673
# NOT EQUAL ON 1573 9
# 0.06736583038573696
# 0.06734593381749365
# NOT EQUAL ON 1573 10
# 0.014867325957504507
# 0.014865896674771673
# NOT EQUAL ON 1638 5
# 0.02659697260983085
# 0.026603590675826294
# NOT EQUAL ON 1638 6
# 0.004723669863732627
# 0.004707785826653765
# NOT EQUAL ON 1638 9
# 0.06736583038573696
# 0.06734593381749365
# NOT EQUAL ON 1638 10
# 0.014867325957504507
# 0.014865896674771673
# NOT EQUAL ON 1712 9
# 0.06736583038573696
# 0.06734593381749365
# NOT EQUAL ON 1712 10
# 0.014867325957504507
# 0.014865896674771673
# NOT EQUAL ON 1729 5
# 0.02659697260983085
# 0.026603590675826294
# NOT EQUAL ON 1729 6
# 0.004723669863732627
# 0.004707785826653765
# NOT EQUAL ON 1729 9
# 0.06736583038573696
# 0.06734593381749365
# NOT EQUAL ON 1729 10
# 0.014867325957504507
# 0.014865896674771673
# NOT EQUAL ON 1768 9
# 0.06736583038573696
# 0.06734593381749365
# NOT EQUAL ON 1768 10
# 0.014867325957504507
# 0.014865896674771673
# NOT EQUAL ON 1782 9
# 0.06736583038573696
# 0.06734593381749365
# NOT EQUAL ON 1782 10
# 0.014867325957504507
# 0.014865896674771673

# %%
df_X_live = pk.load(open('../pickle/_ref_rolling_dataset_1.pkl','rb'))

# %%
df_X_live.iloc[8]
# Out:
# volume                                  0.000188
# close                                   0.023846
# open                                    0.003535
# returnsClosePrevRaw1                    0.021341
# returnsOpenPrevRaw1                     0.005282
# returnsClosePrevMktres1                 0.026999
# returnsOpenPrevMktres1                  0.004634
# returnsClosePrevRaw10                   0.021011
# returnsOpenPrevRaw10                    0.004846
# returnsClosePrevMktres10                0.067366
# returnsOpenPrevMktres10                 0.014867
# returnsClosePrevMktres10_lag_3_mean     0.060072
# returnsClosePrevMktres10_lag_3_max      0.019114
# returnsClosePrevMktres10_lag_3_min      0.217383
# returnsClosePrevMktres10_lag_7_mean     0.036780
# returnsClosePrevMktres10_lag_7_max      0.000185
# returnsClosePrevMktres10_lag_7_min      0.277212
# returnsClosePrevMktres10_lag_14_mean    0.000000
# returnsClosePrevMktres10_lag_14_max     0.000000
# returnsClosePrevMktres10_lag_14_min     0.552971
# returnsClosePrevRaw10_lag_3_mean        0.000000
# returnsClosePrevRaw10_lag_3_max         0.000000
# returnsClosePrevRaw10_lag_3_min         0.000000
# returnsClosePrevRaw10_lag_7_mean        0.000000
# returnsClosePrevRaw10_lag_7_max         0.000000
# returnsClosePrevRaw10_lag_7_min         0.000000
# returnsClosePrevRaw10_lag_14_mean       0.000000
# returnsClosePrevRaw10_lag_14_max        0.000000
# returnsClosePrevRaw10_lag_14_min        0.000000
# open_lag_3_mean                         0.000000
# open_lag_3_max                          0.000000
# open_lag_3_min                          0.000000
# open_lag_7_mean                         0.000000
# open_lag_7_max                          0.000000
# open_lag_7_min                          0.000000
# open_lag_14_mean                        0.000000
# open_lag_14_max                         0.000000
# open_lag_14_min                         0.000000
# close_lag_3_mean                        0.000000
# close_lag_3_max                         0.000000
# close_lag_3_min                         0.000000
# close_lag_7_mean                        0.000000
# close_lag_7_max                         0.000000
# close_lag_7_min                         0.000000
# close_lag_14_mean                       0.000000
# close_lag_14_max                        0.000000
# close_lag_14_min                        0.000000
# assetCodeT                              0.002444
# Name: 8, dtype: float64

# %%
8       ABCB.O  0.695615  0.696494
118     APFH.N -0.505888 -0.437336
144      ATR.N  0.166013  0.172895
177     BANR.O  0.586117  0.590670
222      BLD.N  0.567054  0.572736
238      BOX.N  0.678455  0.681280
313      CCU.N  0.073580  0.063046
420     CSTM.N  0.509296  0.494727
465      DDC.N  0.272437  0.251786
469      DEA.N  0.050674  0.029699
592      EVH.N  0.137207  0.137220
670     FRGI.O -0.323142 -0.322178
682      FUL.N -0.442546 -0.447138
702      GGG.N -0.207914 -0.219843
703      GHL.N -0.522267 -0.526471
761     HASI.N -0.148810 -0.159931
780      HII.N -0.344792 -0.237589
933      KNL.N -0.230580 -0.222746
1144     NEP.N -0.430391 -0.427869
1187    NVRO.N -0.308194 -0.235391
1233    OTEX.O  0.048668  0.051525
1390     RNR.N -0.527257 -0.535770
1407    RTRX.O -0.030127 -0.036894
1418    SAIC.N -0.472767 -0.476151
1423    SATS.O -0.260163 -0.181130
1507     SNX.N -0.351866 -0.266667
1513     SPB.N -0.030298 -0.039186
1526      SR.N -0.263508 -0.272651
1530     SRG.N -0.034596 -0.037471
1573    SYNT.O -0.198527 -0.207932
1638    TRNO.N -0.295412 -0.146239
1712     VAL.N  0.014393  0.005176
1729    VNDA.O  0.036533 -0.038312
1768     WES.N -0.122177 -0.152032
1782     WMS.N -0.131834 -0.149183

(Pdb) X_test.iloc[8]
volume                                  0.000188
close                                   0.023846
open                                    0.003535
returnsClosePrevRaw1                    0.021341
returnsOpenPrevRaw1                     0.005282
returnsClosePrevMktres1                 0.026999
returnsOpenPrevMktres1                  0.004634
returnsClosePrevRaw10                   0.021011
returnsOpenPrevRaw10                    0.004846
returnsClosePrevMktres10                0.067366

# %%
save_name = os.path.join("../pickle","rolling_predictions_dataset.pkl")
with open(save_name,"wb") as f:
    pk.dump(days, f)
    print("[_save] days to "+save_name)
# Out:
# [_save] days to ../pickle/rolling_predictions_dataset.pkl

# %%
save_name = os.path.join("../pickle","_ref_rolling_predictions.pkl")
with open(save_name,"wb") as f:
    if not PREDICTED:
        pk.dump(PREDICTIONS, f)
        print("[_save] rolling preds to PREDICTIONS")
# Out:
# [_save] rolling preds to PREDICTIONS

# %%
PREDICTED = True
if PREDICTED:
    import pickle as pk
    PREDICTIONS = pk.load(open("../pickle/_ref_rolling_predictions.pkl","rb"))

# %%
PRETRAINED = True
if PRETRAINED:
    import sys;sys.path.append('../')
    import os
    from model_lgbm_71 import model
    os.listdir('../pickle')
    model = model('DecisionTree.model_lgbm_71')
    model._load()
    print(help(model.predict))
# Out:
# init model DecisionTree.model_lgbm_71
# [_load] models loaded succesfully
# Help on method predict in module model_lgbm_71:
#
# predict(X, verbose=False, do_shap=False, normalize=True, normalize_vals=[None]) method of model_lgbm_71.model instance
#     given a block of X features gives prediction for everyrow+".pkl"
#
#     Args:
#         X: [market_train_df, news_train_df]
#         shap: perform shap analysis
#         normalize: (bool)
#         normalize_vals: recommmended self.maxs, self.mins
#     Returns:
#         y: pandas.Series
#
# None

# %%
#prediction
import time

_COMPARE_PREDICTIONS = []

days = []
for date in dates:
    market_obs_df = market_test_df[market_test_df['time'] == date]
    predictions_template_df = pd.DataFrame({'assetCode':market_test_df[market_test_df['time'] == date]['assetCode'],
                                            'confidenceValue':0.0})
    days.append([market_obs_df,None,predictions_template_df])

#days = env.get_prediction_days()
# SHOULD WORK?
n_days = 0
prep_time = 0
prediction_time = 0
n_lag=[3,7,14]
packaging_time = 0
total_market_obs_df = []
for (market_obs_df, news_obs_df, predictions_template_df) in days[:]:
    n_days +=1
    if (n_days%50==0):
        pass
        #print(n_days,end=' ')
    t = time.time()
    market_obs_df['time'] = market_obs_df['time'].dt.date

    total_market_obs_df.append(market_obs_df)
    if len(total_market_obs_df)==1:
        history_df = total_market_obs_df[0]
    else:
        history_df = pd.concat(total_market_obs_df[-(np.max(n_lag)+1):])
        
    
    confidence = model.predict_rolling([history_df, None], market_obs_df, verbose=True, normalize=True, normalize_vals = [maxs,mins])      
        
    preds = pd.DataFrame({'assetCode':market_obs_df['assetCode'],'confidence':confidence})
    predictions_template_df = predictions_template_df.merge(preds,how='left').drop('confidenceValue',axis=1).fillna(0).rename(columns={'confidence':'confidenceValue'})
    _COMPARE_PREDICTIONS.append(predictions_template_df)
    packaging_time += time.time() - t
# Out:
# /Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Starting rolled prediction for model DecisionTree.model_lgbm_71, Fri Jan  4 19:36:15 2019
# Starting features generation for model DecisionTree.model_lgbm_71, Fri Jan  4 19:36:15 2019
# ['LGIH.O' 'LGND.O' 'LH.N' 'LHO.N' 'LII.N' 'LILA.O' 'LILAK.O' 'LITE.O'
#  'LIVN.O' 'LKQ.O' 'LLTC.O' 'LLY.N' 'LM.N' 'LMCK.O' 'LMNX.O' 'LMT.N' 'LN.N'
#  'LNC.N' 'LNCE.O' 'LNG.A' 'LNKD.N' 'LNT.N' 'LOCK.N' 'LOGI.O' 'LOGM.O'
#  'LOPE.O' 'LOW.N' 'LPI.N' 'LPL.N' 'LPLA.O' 'LPNT.O' 'LPT.N' 'LPX.N' 'LQ.N'
#  'LRCX.O' 'LSCC.O' 'LSI.N' 'LSTR.O' 'LSXMA.O' 'LSXMK.O' 'LTRPA.O' 'LTXB.O'
#  'LUK.N' 'LULU.O' 'LUV.N' 'LVLT.N' 'LVS.N' 'LXK.N' 'LXP.N' 'LXRX.O'
#  'LYB.N' 'LYG.N' 'LYV.N' 'LZB.N' 'M.N' 'MA.N' 'MAA.N' 'MAC.N' 'MAN.N'
#  'MANH.O' 'MAR.O' 'MAS.N' 'MASI.O' 'MAT.O' 'MBFI.O' 'MBI.N' 'MBT.N'
#  'MCD.N' 'MCHP.O' 'MCK.N' 'MCO.N' 'MD.N' 'MDC.N' 'MDCO.O' 'MDLZ.O' 'MDP.N'
#  'MDRX.O' 'MDSO.O' 'MDT.N' 'MDU.N' 'MDXG.O' 'MEG.N' 'MELI.O' 'MENT.O'
#  'MEOH.O' 'MET.N' 'MFA.N' 'MFC.N' 'MFS.N' 'MGA.N' 'MGLN.O' 'MGM.N'
#  'MGNX.O' 'MGP.N' 'MHK.N' 'MHLD.O' 'MIC.N' 'MIDD.O' 'MIK.O' 'MINI.O'
#  'MITL.O' 'MJN.N' 'MKC.N' 'MKSI.O' 'MKTX.O' 'MLHR.O' 'MLM.N' 'MLNX.O'
#  'MMC.N' 'MMM.N' 'MMP.N' 'MMS.N' 'MMSI.O' 'MNK.N' 'MNR.N' 'MNRO.O'
#  'MNST.O' 'MNTA.O' 'MO.N' 'MOH.N' 'MOMO.O' 'MON.N' 'MORE.N' 'MOS.N'
#  'MPC.N' 'MPEL.O' 'MPLX.N' 'MPW.N' 'MPWR.O' 'MRC.N' 'MRCY.O' 'MRK.N'
#  'MRO.N' 'MRVL.O' 'MS.N' 'MSCC.O' 'MSCI.N' 'MSFT.O' 'MSGN.N' 'MSI.N'
#  'MSM.N' 'MTB.N' 'MTCH.O' 'MTDR.N' 'MTG.N' 'MTN.N' 'MTOR.N' 'MTSI.O'
#  'MTU.N' 'MTZ.N' 'MU.O' 'MUR.N' 'MUSA.N' 'MUX.N' 'MWA.N' 'MXIM.O' 'MXL.N'
#  'MYCC.N' 'MYGN.O' 'MYL.O' 'N.N' 'NAT.N' 'NATI.O' 'NAV.N' 'NAVI.O'
#  'NBIX.O' 'NBL.N' 'NBR.N' 'NCLH.O' 'NCMI.O' 'NCR.N' 'NCS.N' 'NDAQ.O'
#  'NDSN.O' 'NE.N' 'NEE.N' 'NEM.N' 'NEP.N' 'NEWM.N' 'NEWR.N' 'NFG.N'
#  'NFLX.O' 'NFX.N' 'NG.A' 'NGD.A' 'NGL.N' 'NGVT.N' 'NHI.N' 'NI.N' 'NJR.N'
#  'NKE.N' 'NKTR.O' 'NLSN.N' 'NLY.N' 'NMBL.N' 'NNN.N' 'NOC.N' 'NOK.N'
#  'NOMD.N' 'NOV.N' 'NOW.N' 'NRF.N' 'NRG.N' 'NRZ.N' 'NSA.N' 'NSAM.N' 'NSC.N'
#  'NSM.N' 'NSR.N' 'NTAP.O' 'NTCT.O' 'NTES.O' 'NTGR.O' 'NTRI.O' 'NTRS.O'
#  'NUAN.O' 'NUE.N' 'NUS.N' 'NUVA.O' 'NVCR.O' 'NVDA.O' 'NVO.N' 'NVRO.N'
#  'NVS.N' 'NWBI.O' 'NWE.N' 'NWL.N' 'NWS.O' 'NWSA.O' 'NXPI.O' 'NXST.O'
#  'NXTM.O' 'NYCB.N' 'NYLD.N' 'NYT.N' 'O.N' 'OA.N' 'OAS.N' 'OC.N' 'OCLR.O'
#  'ODFL.O' 'ODP.O' 'OFC.N' 'OGE.N' 'OHI.N' 'OI.N' 'OII.N' 'OIS.N' 'OKE.N'
#  'OKS.N' 'OLED.O' 'OLLI.O' 'OLN.N' 'OMC.N' 'OMF.N' 'OMI.N' 'ON.O' 'ONB.O'
#  'ONCE.O' 'OPHT.O' 'OPK.O' 'ORAN.N' 'ORBC.O' 'ORCL.N' 'ORI.N' 'ORLY.O'
#  'OSG.N' 'OSK.N' 'OTEX.O' 'OUT.N' 'OXY.N' 'OZM.N' 'P.N' 'PAA.N' 'PAAS.O'
#  'PACB.O' 'PACW.O' 'PAG.N' 'PAH.N' 'PANW.N' 'PAY.N' 'PAYC.N' 'PAYX.O'
#  'PB.N' 'PBCT.O' 'PBF.N' 'PBH.N' 'PBI.N' 'PBR.N' 'PBRa.N' 'PBYI.N'
#  'PCAR.O' 'PCG.N' 'PCH.O' 'PCLN.O' 'PCRX.O' 'PDCE.O' 'PDCO.O' 'PDM.N'
#  'PDS.N' 'PE.N' 'PEB.N' 'PEG.N' 'PEGA.O' 'PEGI.O' 'PEI.N' 'PENN.O' 'PEP.N'
#  'PF.N' 'PFE.N' 'PFG.N' 'PFGC.N' 'PFPT.O' 'PG.N' 'PGH.N' 'PGR.N' 'PGRE.N'
#  'PH.N' 'PHG.N' 'PHH.N' 'PHM.N' 'PII.N' 'PINC.O' 'PKG.N' 'PKI.N' 'PKX.N'
#  'PLAB.O' 'PLAY.O' 'PLCE.O' 'PLD.N' 'PLKI.O' 'PLNT.N' 'PM.N' 'PMC.N'
#  'PMT.N' 'PNC.N' 'PNFP.O' 'PNK.O' 'PNM.N' 'PNR.N' 'PNRA.O' 'PNW.N'
#  'PODD.O' 'POL.N' 'POOL.O' 'POR.N' 'POST.N' 'POT.N' 'PPC.O' 'PPG.N'
#  'PPL.N' 'PPS.N' 'PRAA.O' 'PRAH.O' 'PRGO.N' 'PRGS.O' 'PRI.N' 'PRIM.O'
#  'PRTA.O' 'PRTY.N' 'PRU.N' 'PRXL.O' 'PSA.N' 'PSEC.O' 'PSO.N' 'PSTG.N'
#  'PSX.N' 'PSXP.N' 'PTC.O' 'PTEN.O' 'PTLA.O' 'PUK.N' 'PVG.N' 'PVH.N'
#  'PVTB.O' 'PWE.N' 'PWR.N' 'PX.N' 'PXD.N' 'PYPL.O' 'PZZA.O' 'Q.N' 'QCOM.O'
#  'QEP.N' 'QLYS.O' 'QRVO.O' 'QSII.O' 'QSR.N' 'QTS.N' 'QUOT.N' 'QVCA.O'
#  'R.N' 'RACE.N' 'RAD.N' 'RAI.N' 'RARE.O' 'RATE.N' 'RAX.N' 'RBA.N' 'RBS.N'
#  'RCL.N' 'RDC.N' 'RDN.N' 'RDSa.N' 'RDSb.N' 'RDUS.O' 'REG.N' 'REGN.O'
#  'RES.N' 'REXR.N' 'RF.N' 'RGC.N' 'RGEN.O' 'RGLD.O' 'RHI.N' 'RHP.N' 'RHT.N'
#  'RICE.N' 'RIG.N' 'RIO.N' 'RJF.N' 'RL.N' 'RLGY.N' 'RLJ.N' 'RMBS.O' 'RMD.N'
#  'RNG.N' 'RNR.N' 'RNST.O' 'ROCK.O' 'ROIC.O' 'ROK.N' 'ROL.N' 'ROP.N'
#  'ROST.O' 'RP.O' 'RPAI.N' 'RPM.N' 'RPT.N' 'RRC.N' 'RRR.O' 'RS.N' 'RSG.N'
#  'RSPP.N' 'RTN.N' 'RTRX.O' 'RWT.N' 'RXN.N' 'RY.N' 'RYAAY.O' 'RYN.N' 'S.N'
#  'SAAS.O' 'SABR.O' 'SAFM.O' 'SAGE.O' 'SAIC.N' 'SAN.N' 'SAND.A' 'SANM.O'
#  'SAP.N' 'SATS.O' 'SAVE.O' 'SBAC.O' 'SBGI.O' 'SBGL.N' 'SBH.N' 'SBNY.O'
#  'SBRA.O' 'SBS.N' 'SBUX.O' 'SC.N' 'SCAI.O' 'SCCO.N' 'SCG.N' 'SCHW.N'
#  'SCI.N' 'SCOR.O' 'SCS.N' 'SCSS.O' 'SCTY.O' 'SDRL.N' 'SE.N' 'SEAS.N'
#  'SEE.N' 'SEIC.O' 'SEM.N' 'SEMG.N' 'SEP.N' 'SERV.N' 'SF.N' 'SFL.N'
#  'SFLY.O' 'SFM.O' 'SFS.N' 'SGEN.O' 'SGMS.O' 'SGYP.O' 'SHAK.N' 'SHEN.O'
#  'SHLD.O' 'SHLM.O' 'SHLX.N' 'SHO.N' 'SHOO.O' 'SHOP.N' 'SHPG.O' 'SHW.N'
#  'SID.N' 'SIG.N' 'SIGI.O' 'SIMO.O' 'SINA.O' 'SIR.O' 'SIRI.O' 'SIVB.O'
#  'SIX.N' 'SJI.N' 'SJM.N' 'SJR.N' 'SKM.N' 'SKT.N' 'SKX.N' 'SKYW.O' 'SLAB.O'
#  'SLB.N' 'SLCA.N' 'SLF.N' 'SLG.N' 'SLGN.O' 'SLM.O' 'SM.N' 'SMCI.O'
#  'SMFG.N' 'SMG.N' 'SMTC.O' 'SNA.N' 'SNCR.O' 'SNE.N' 'SNH.O' 'SNI.O'
#  'SNN.N' 'SNPS.O' 'SNR.N' 'SNV.N' 'SNY.N' 'SO.N' 'SOHU.O' 'SON.N' 'SONC.O'
#  'SPB.N' 'SPG.N' 'SPGI.N' 'SPLK.O' 'SPLS.O' 'SPN.N' 'SPNC.O' 'SPR.N'
#  'SPTN.O' 'SPWR.O' 'SPXC.N' 'SQ.N' 'SQM.N' 'SR.N' 'SRC.N' 'SRCL.O' 'SRE.N'
#  'SRG.N' 'SRPT.O' 'SSL.N' 'SSNC.O' 'SSP.N' 'SSW.N' 'SSYS.O' 'ST.N'
#  'STAG.N' 'STAR.N' 'STAY.N' 'STE.N' 'STI.N' 'STJ.N' 'STL.N' 'STLD.O'
#  'STM.N' 'STMP.O' 'STNG.N' 'STOR.N' 'STRZA.O' 'STT.N' 'STWD.N' 'STX.O'
#  'STZ.N' 'SU.N' 'SUI.N' 'SUM.N' 'SUN.N' 'SUPN.O' 'SWC.N' 'SWFT.N' 'SWHC.O'
#  'SWK.N' 'SWKS.O' 'SWN.N' 'SWX.N' 'SXL.N' 'SYF.N' 'SYK.N' 'SYKE.O'
#  'SYMC.O' 'SYNA.O' 'SYNT.O' 'SYRG.A' 'SYT.N' 'SYY.N' 'T.N' 'TAHO.N'
#  'TAP.N' 'TASR.O' 'TBI.N' 'TBPH.O' 'TCB.N' 'TCBI.O' 'TCK.N' 'TCO.N' 'TD.N'
#  'TDC.N' 'TDG.N' 'TDS.N' 'TEAM.O' 'TECD.O' 'TECH.O' 'TEF.N' 'TEL.N'
#  'TEN.N' 'TER.N' 'TERP.O' 'TEVA.N' 'TEX.N' 'TFSL.O' 'TGI.N' 'TGNA.N'
#  'TGP.N' 'TGT.N' 'THC.N' 'THG.N' 'THO.N' 'THRM.O' 'THS.N' 'TIF.N' 'TILE.O'
#  'TIME.N' 'TIVO.O' 'TJX.N' 'TKR.N' 'TLLP.N' 'TLN.N' 'TLRD.N' 'TMH.N'
#  'TMK.N' 'TMO.N' 'TMUS.O' 'TNET.N' 'TOL.N' 'TOT.N' 'TPC.N' 'TPH.N'
#  'TPRE.N' 'TPX.N' 'TRCO.N' 'TREE.O' 'TRGP.N' 'TRI.N' 'TRIP.O' 'TRMB.O'
#  'TRMK.O' 'TRN.N' 'TRNO.N' 'TROW.O' 'TRP.N' 'TRQ.N' 'TRTN.N' 'TRU.N'
#  'TRUE.O' 'TRV.N' 'TS.N' 'TSCO.O' 'TSE.N' 'TSEM.O' 'TSL.N' 'TSLA.O'
#  'TSM.N' 'TSN.N' 'TSO.N' 'TSRO.O' 'TSS.N' 'TSU.N' 'TTC.N' 'TTEK.O' 'TTM.N'
#  'TTMI.O' 'TTS.O' 'TTWO.O' 'TUP.N' 'TV.N' 'TVPT.N' 'TWOU.O' 'TWTR.N'
#  'TWX.N' 'TX.N' 'TXMD.A' 'TXN.O' 'TXRH.O' 'TXT.N' 'TYPE.O' 'UAL.N' 'UAc.N'
#  'UBNT.O' 'UBS.N' 'UBSI.O' 'UCBI.O' 'UDR.N' 'UE.N' 'UFS.N' 'UGI.N' 'UGP.N'
#  'UHS.N' 'UL.N' 'ULTA.O' 'UMBF.O' 'UMC.N' 'UMPQ.O' 'UN.N' 'UNFI.O' 'UNH.N'
#  'UNM.N' 'UNP.N' 'UNT.N' 'UNVR.N' 'UPS.N' 'URBN.O' 'URI.N' 'USB.N'
#  'USCR.O' 'USFD.N' 'USG.N' 'UTHR.O' 'UTX.N' 'UVE.N' 'V.N' 'VA.O' 'VAL.N'
#  'VALE.N' 'VAR.N' 'VECO.O' 'VEEV.N' 'VER.N' 'VFC.N' 'VG.N' 'VGR.N'
#  'VIAB.O' 'VIAV.O' 'VIPS.N' 'VIV.N' 'VLO.N' 'VLY.N' 'VMC.N' 'VMW.N'
#  'VNO.N' 'VNTV.N' 'VOD.O' 'VOYA.N' 'VR.N' 'VRNT.O' 'VRSK.O' 'VRSN.O'
#  'VRTU.O' 'VRTX.O' 'VSAT.O' 'VSH.N' 'VSTO.N' 'VTR.N' 'VVC.N' 'VWR.O'
#  'VZ.N' 'W.N' 'WAB.N' 'WAFD.O' 'WAIR.N' 'WAL.N' 'WAT.N' 'WB.O' 'WBA.O'
#  'WBC.N' 'WBMD.O' 'WBS.N' 'WCC.N' 'WCG.N' 'WCN.N' 'WDAY.N' 'WDC.O' 'WDR.N'
#  'WEB.O' 'WEC.N' 'WEN.O' 'WERN.O' 'WES.N' 'WETF.O' 'WFC.N' 'WFM.O' 'WFT.N'
#  'WGL.N' 'WHR.N' 'WIT.N' 'WIX.O' 'WLK.N' 'WLTW.O' 'WM.N' 'WMB.N' 'WMGI.O'
#  'WMS.N' 'WMT.N' 'WNC.N' 'WNR.N' 'WOOF.O' 'WOR.N' 'WPC.N' 'WPG.N' 'WPX.N'
#  'WPZ.N' 'WR.N' 'WRB.N' 'WRE.N' 'WRI.N' 'WRK.N' 'WSM.N' 'WST.N' 'WTFC.O'
#  'WTR.N' 'WU.N' 'WUBA.N' 'WWAV.N' 'WWD.O' 'WWE.N' 'WWW.N' 'WY.N' 'WYN.N'
#  'WYNN.O' 'X.N' 'XEC.N' 'XEL.N' 'XHR.N' 'XL.N' 'XLNX.O' 'XLRN.O' 'XNCR.O'
#  'XOM.N' 'XON.N' 'XPO.N' 'XRAY.O' 'XRS.N' 'XXIA.O' 'XYL.N' 'YELP.N'
#  'YHOO.O' 'YNDX.O' 'YPF.N' 'YRD.N' 'YUM.N' 'YY.O' 'Z.O' 'ZAYO.N' 'ZBH.N'
#  'ZBRA.O' 'ZEN.N' 'ZG.O' 'ZION.O' 'ZIOP.O' 'ZLTQ.O' 'ZNGA.O' 'ZTS.N']
# total 880 df
# Finished features generation for model DecisionTree.model_lgbm_71, TIME 12.319231033325195
# X_test shape (880, 48)
# Finished rolled prediction for model DecisionTree.model_lgbm_71, TIME 12.440201997756958
# Starting rolled prediction for model DecisionTree.model_lgbm_71, Fri Jan  4 19:36:27 2019
# Starting features generation for model DecisionTree.model_lgbm_71, Fri Jan  4 19:36:27 2019
# ['LGIH.O' 'LGND.O' 'LH.N' ... 'LGF.N' 'SNX.N' 'VNDA.O']
# total 1849 df
# Finished features generation for model DecisionTree.model_lgbm_71, TIME 24.711770057678223
# X_test shape (1843, 48)
# Finished rolled prediction for model DecisionTree.model_lgbm_71, TIME 24.910052061080933
# Starting rolled prediction for model DecisionTree.model_lgbm_71, Fri Jan  4 19:36:52 2019
# Starting features generation for model DecisionTree.model_lgbm_71, Fri Jan  4 19:36:52 2019
# ['LGIH.O' 'LGND.O' 'LH.N' ... 'E.N' 'HNI.N' 'ILG.O']
# total 1852 df
# Finished features generation for model DecisionTree.model_lgbm_71, TIME 33.355878829956055
# X_test shape (1845, 48)
# Finished rolled prediction for model DecisionTree.model_lgbm_71, TIME 33.611745834350586
# Starting rolled prediction for model DecisionTree.model_lgbm_71, Fri Jan  4 19:37:26 2019
# Starting features generation for model DecisionTree.model_lgbm_71, Fri Jan  4 19:37:26 2019
# ['LGIH.O' 'LGND.O' 'LH.N' ... 'HNI.N' 'ILG.O' 'AZO.N']
# total 1853 df
# Finished features generation for model DecisionTree.model_lgbm_71, TIME 30.13370108604431
# X_test shape (1844, 48)
# Finished rolled prediction for model DecisionTree.model_lgbm_71, TIME 30.36882185935974
# Starting rolled prediction for model DecisionTree.model_lgbm_71, Fri Jan  4 19:37:56 2019
# Starting features generation for model DecisionTree.model_lgbm_71, Fri Jan  4 19:37:56 2019
# ['LGIH.O' 'LGND.O' 'LH.N' ... 'FWRD.O' 'IDA.N' 'TRS.O']
# total 1858 df
# Finished features generation for model DecisionTree.model_lgbm_71, TIME 24.974744081497192
# X_test shape (1841, 48)
# Finished rolled prediction for model DecisionTree.model_lgbm_71, TIME 25.207004070281982
# Starting rolled prediction for model DecisionTree.model_lgbm_71, Fri Jan  4 19:38:21 2019
# Starting features generation for model DecisionTree.model_lgbm_71, Fri Jan  4 19:38:21 2019
# ['LGIH.O' 'LGND.O' 'LH.N' ... 'ENIC.N' 'NSIT.O' 'RE.N']
# total 1861 df
# Finished features generation for model DecisionTree.model_lgbm_71, TIME 24.17809796333313
# X_test shape (1842, 48)
# Finished rolled prediction for model DecisionTree.model_lgbm_71, TIME 24.45856809616089
# Starting rolled prediction for model DecisionTree.model_lgbm_71, Fri Jan  4 19:38:46 2019
# Starting features generation for model DecisionTree.model_lgbm_71, Fri Jan  4 19:38:46 2019
# ['LGIH.O' 'LGND.O' 'LH.N' ... 'CPPL.N' 'MLI.N' 'SFUN.N']
# total 1866 df
# Finished features generation for model DecisionTree.model_lgbm_71, TIME 24.999958038330078
# X_test shape (1840, 48)
# Finished rolled prediction for model DecisionTree.model_lgbm_71, TIME 25.21079993247986
# Starting rolled prediction for model DecisionTree.model_lgbm_71, Fri Jan  4 19:39:11 2019
# Starting features generation for model DecisionTree.model_lgbm_71, Fri Jan  4 19:39:11 2019
# ['LGIH.O' 'LGND.O' 'LH.N' ... 'BZUN.O' 'CW.N' 'NGHC.O']
# total 1869 df
# Finished features generation for model DecisionTree.model_lgbm_71, TIME 26.747829914093018
# X_test shape (1843, 48)
# Finished rolled prediction for model DecisionTree.model_lgbm_71, TIME 26.992510080337524
# Starting rolled prediction for model DecisionTree.model_lgbm_71, Fri Jan  4 19:39:38 2019
# Starting features generation for model DecisionTree.model_lgbm_71, Fri Jan  4 19:39:38 2019
# ['LGIH.O' 'LGND.O' 'LH.N' ... 'CW.N' 'NGHC.O' 'FGP.N']
# total 1870 df
# Finished features generation for model DecisionTree.model_lgbm_71, TIME 27.559096097946167
# X_test shape (1843, 48)
# Finished rolled prediction for model DecisionTree.model_lgbm_71, TIME 27.796816110610962
# Starting rolled prediction for model DecisionTree.model_lgbm_71, Fri Jan  4 19:40:06 2019
# Starting features generation for model DecisionTree.model_lgbm_71, Fri Jan  4 19:40:06 2019
# ['LGIH.O' 'LGND.O' 'LH.N' ... 'NGHC.O' 'FGP.N' 'MIME.O']
# total 1871 df
# Finished features generation for model DecisionTree.model_lgbm_71, TIME 32.08464169502258
# X_test shape (1841, 48)
# Finished rolled prediction for model DecisionTree.model_lgbm_71, TIME 32.37160515785217
# Starting rolled prediction for model DecisionTree.model_lgbm_71, Fri Jan  4 19:40:39 2019
# Starting features generation for model DecisionTree.model_lgbm_71, Fri Jan  4 19:40:39 2019
# ['LGIH.O' 'LGND.O' 'LH.N' ... 'AMN.N' 'GVA.N' 'PTHN.N']
# total 1874 df
# Finished features generation for model DecisionTree.model_lgbm_71, TIME 39.41637110710144
# X_test shape (1842, 48)
# Finished rolled prediction for model DecisionTree.model_lgbm_71, TIME 39.705114126205444
# Starting rolled prediction for model DecisionTree.model_lgbm_71, Fri Jan  4 19:41:18 2019
# Starting features generation for model DecisionTree.model_lgbm_71, Fri Jan  4 19:41:18 2019
# ['LGIH.O' 'LGND.O' 'LH.N' ... 'CHT.N' 'NSU.A' 'TFX.N']
# total 1878 df
# Finished features generation for model DecisionTree.model_lgbm_71, TIME 29.5797917842865
# X_test shape (1839, 48)
# Finished rolled prediction for model DecisionTree.model_lgbm_71, TIME 29.923911333084106
# Starting rolled prediction for model DecisionTree.model_lgbm_71, Fri Jan  4 19:41:48 2019
# Starting features generation for model DecisionTree.model_lgbm_71, Fri Jan  4 19:41:48 2019
# ['LGIH.O' 'LGND.O' 'LH.N' ... 'CORT.O' 'RRD.N' 'WTW.N']
# total 1883 df
# Finished features generation for model DecisionTree.model_lgbm_71, TIME 57.95551085472107
# X_test shape (1842, 48)
# Finished rolled prediction for model DecisionTree.model_lgbm_71, TIME 58.79226589202881
# Starting rolled prediction for model DecisionTree.model_lgbm_71, Fri Jan  4 19:42:47 2019
# Starting features generation for model DecisionTree.model_lgbm_71, Fri Jan  4 19:42:47 2019
# ['LGIH.O' 'LGND.O' 'LH.N' ... 'RRD.N' 'WTW.N' 'VC.N']
# total 1884 df
# Finished features generation for model DecisionTree.model_lgbm_71, TIME 60.51302409172058
# X_test shape (1842, 48)
# Finished rolled prediction for model DecisionTree.model_lgbm_71, TIME 60.959904193878174
# Starting rolled prediction for model DecisionTree.model_lgbm_71, Fri Jan  4 19:43:48 2019
# Starting features generation for model DecisionTree.model_lgbm_71, Fri Jan  4 19:43:48 2019
# ['LGIH.O' 'LGND.O' 'LH.N' ... 'RRD.N' 'WTW.N' 'VC.N']
# total 1884 df
# Finished features generation for model DecisionTree.model_lgbm_71, TIME 51.40115523338318
# X_test shape (1840, 48)
# Finished rolled prediction for model DecisionTree.model_lgbm_71, TIME 51.875043869018555
# Starting rolled prediction for model DecisionTree.model_lgbm_71, Fri Jan  4 19:44:40 2019
# Starting features generation for model DecisionTree.model_lgbm_71, Fri Jan  4 19:44:40 2019
# ['A.N' 'AAL.O' 'AAN.N' ... 'WTW.N' 'VC.N' 'QUAD.N']
# total 1879 df
# Finished features generation for model DecisionTree.model_lgbm_71, TIME 64.69792103767395
# X_test shape (1839, 48)
# Finished rolled prediction for model DecisionTree.model_lgbm_71, TIME 65.37027716636658
# Starting rolled prediction for model DecisionTree.model_lgbm_71, Fri Jan  4 19:45:46 2019
# Starting features generation for model DecisionTree.model_lgbm_71, Fri Jan  4 19:45:46 2019
# ['A.N' 'AAL.O' 'AAN.N' ... 'TEP.N' 'VEDL.N' 'WEX.N']
# total 1883 df
# Finished features generation for model DecisionTree.model_lgbm_71, TIME 55.744521141052246
# X_test shape (1840, 48)
# Finished rolled prediction for model DecisionTree.model_lgbm_71, TIME 56.1646089553833
# Starting rolled prediction for model DecisionTree.model_lgbm_71, Fri Jan  4 19:46:42 2019
# Starting features generation for model DecisionTree.model_lgbm_71, Fri Jan  4 19:46:42 2019
# ['A.N' 'AAL.O' 'AAN.N' ... 'VEDL.N' 'WEX.N' 'RGA.N']
# total 1882 df
# Finished features generation for model DecisionTree.model_lgbm_71, TIME 39.23584794998169
# X_test shape (1840, 48)
# Finished rolled prediction for model DecisionTree.model_lgbm_71, TIME 39.648828983306885
# Starting rolled prediction for model DecisionTree.model_lgbm_71, Fri Jan  4 19:47:22 2019
# Starting features generation for model DecisionTree.model_lgbm_71, Fri Jan  4 19:47:22 2019
# ['A.N' 'AAL.O' 'AAN.N' ... 'RGA.N' 'ALV.N' 'BNFT.O']
# total 1876 df
# Finished features generation for model DecisionTree.model_lgbm_71, TIME 40.15024495124817
# X_test shape (1841, 48)
# Finished rolled prediction for model DecisionTree.model_lgbm_71, TIME 40.61081910133362
# Starting rolled prediction for model DecisionTree.model_lgbm_71, Fri Jan  4 19:48:02 2019
# Starting features generation for model DecisionTree.model_lgbm_71, Fri Jan  4 19:48:02 2019
# ['A.N' 'AAL.O' 'AAN.N' ... 'BNFT.O' 'OGS.N' 'VAC.N']
# total 1876 df
# Finished features generation for model DecisionTree.model_lgbm_71, TIME 34.95093035697937
# X_test shape (1837, 48)
# Finished rolled prediction for model DecisionTree.model_lgbm_71, TIME 35.38612103462219
# Starting rolled prediction for model DecisionTree.model_lgbm_71, Fri Jan  4 19:48:38 2019
# Starting features generation for model DecisionTree.model_lgbm_71, Fri Jan  4 19:48:38 2019
# ['A.N' 'AAL.O' 'AAN.N' ... 'OGS.N' 'VAC.N' 'VVV.N']
# total 1870 df
# Finished features generation for model DecisionTree.model_lgbm_71, TIME 26.85818600654602
# X_test shape (1833, 48)
# Finished rolled prediction for model DecisionTree.model_lgbm_71, TIME 27.147391080856323
# Starting rolled prediction for model DecisionTree.model_lgbm_71, Fri Jan  4 19:49:05 2019
# Starting features generation for model DecisionTree.model_lgbm_71, Fri Jan  4 19:49:05 2019
# ['A.N' 'AAL.O' 'AAN.N' ... 'PRLB.N' 'RCI.N' 'ULTI.O']
# total 1880 df
# Finished features generation for model DecisionTree.model_lgbm_71, TIME 27.48750877380371
# X_test shape (1841, 48)
# Finished rolled prediction for model DecisionTree.model_lgbm_71, TIME 27.887691974639893
# Starting rolled prediction for model DecisionTree.model_lgbm_71, Fri Jan  4 19:49:33 2019
# Starting features generation for model DecisionTree.model_lgbm_71, Fri Jan  4 19:49:33 2019
# ['A.N' 'AAL.O' 'AAN.N' ... 'DST.N' 'KALU.O' 'MMYT.O']
# total 1882 df
# Finished features generation for model DecisionTree.model_lgbm_71, TIME 26.7426118850708
# X_test shape (1844, 48)
# Finished rolled prediction for model DecisionTree.model_lgbm_71, TIME 27.09416890144348
# Starting rolled prediction for model DecisionTree.model_lgbm_71, Fri Jan  4 19:50:00 2019
# Starting features generation for model DecisionTree.model_lgbm_71, Fri Jan  4 19:50:00 2019
# ['A.N' 'AAL.O' 'AAN.N' ... 'LAD.N' 'PZE.N' 'VIVO.O']
# total 1882 df
# Finished features generation for model DecisionTree.model_lgbm_71, TIME 27.56004786491394
# X_test shape (1839, 48)
# Finished rolled prediction for model DecisionTree.model_lgbm_71, TIME 27.957921981811523
# Starting rolled prediction for model DecisionTree.model_lgbm_71, Fri Jan  4 19:50:28 2019
# Starting features generation for model DecisionTree.model_lgbm_71, Fri Jan  4 19:50:28 2019
# ['A.N' 'AAL.O' 'AAN.N' ... 'VIVO.O' 'FTS.N' 'SSD.N']
# total 1882 df
# Finished features generation for model DecisionTree.model_lgbm_71, TIME 28.150432109832764
# X_test shape (1839, 48)
# Finished rolled prediction for model DecisionTree.model_lgbm_71, TIME 28.523598670959473
# Starting rolled prediction for model DecisionTree.model_lgbm_71, Fri Jan  4 19:50:57 2019
# Starting features generation for model DecisionTree.model_lgbm_71, Fri Jan  4 19:50:57 2019
# ['A.N' 'AAL.O' 'AAN.N' ... 'SSD.N' 'PAM.N' 'VSM.N']
# total 1877 df
# Finished features generation for model DecisionTree.model_lgbm_71, TIME 30.455438137054443
# X_test shape (1838, 48)
# Finished rolled prediction for model DecisionTree.model_lgbm_71, TIME 31.09825325012207
# Starting rolled prediction for model DecisionTree.model_lgbm_71, Fri Jan  4 19:51:28 2019
# Starting features generation for model DecisionTree.model_lgbm_71, Fri Jan  4 19:51:28 2019
# ['A.N' 'AAL.O' 'AAN.N' ... 'NS.N' 'WING.O' 'WSTC.O']
# total 1880 df
# Finished features generation for model DecisionTree.model_lgbm_71, TIME 26.34742021560669
# X_test shape (1841, 48)
# Finished rolled prediction for model DecisionTree.model_lgbm_71, TIME 26.648258209228516
# Starting rolled prediction for model DecisionTree.model_lgbm_71, Fri Jan  4 19:51:54 2019
# Starting features generation for model DecisionTree.model_lgbm_71, Fri Jan  4 19:51:54 2019
# ['A.N' 'AAL.O' 'AAN.N' ... 'WSTC.O' 'NCI.N' 'NMFC.N']
# total 1881 df
# Finished features generation for model DecisionTree.model_lgbm_71, TIME 27.216087102890015
# X_test shape (1840, 48)
# Finished rolled prediction for model DecisionTree.model_lgbm_71, TIME 27.6034939289093
# Starting rolled prediction for model DecisionTree.model_lgbm_71, Fri Jan  4 19:52:22 2019
# Starting features generation for model DecisionTree.model_lgbm_71, Fri Jan  4 19:52:22 2019
# ['A.N' 'AAL.O' 'AAN.N' ... 'BOKF.O' 'MTL.N' 'SAIA.O']
# total 1883 df
# Finished features generation for model DecisionTree.model_lgbm_71, TIME 30.37468910217285
# X_test shape (1839, 48)
# Finished rolled prediction for model DecisionTree.model_lgbm_71, TIME 30.697771072387695
# Starting rolled prediction for model DecisionTree.model_lgbm_71, Fri Jan  4 19:52:53 2019
# Starting features generation for model DecisionTree.model_lgbm_71, Fri Jan  4 19:52:53 2019
# ['A.N' 'AAL.O' 'AAN.N' ... 'CSGP.O' 'MTH.N' 'PKY.N']
# total 1886 df
# Finished features generation for model DecisionTree.model_lgbm_71, TIME 29.263636112213135
# X_test shape (1838, 48)
# Finished rolled prediction for model DecisionTree.model_lgbm_71, TIME 29.640810012817383
# Starting rolled prediction for model DecisionTree.model_lgbm_71, Fri Jan  4 19:53:23 2019
# Starting features generation for model DecisionTree.model_lgbm_71, Fri Jan  4 19:53:23 2019
# ['A.N' 'AAL.O' 'AAN.N' ... 'NYMT.O' 'RUSHA.O' 'TEDU.O']
# total 1885 df
# Finished features generation for model DecisionTree.model_lgbm_71, TIME 28.404444932937622
# X_test shape (1837, 48)
# Finished rolled prediction for model DecisionTree.model_lgbm_71, TIME 28.718475103378296
# Starting rolled prediction for model DecisionTree.model_lgbm_71, Fri Jan  4 19:53:51 2019
# Starting features generation for model DecisionTree.model_lgbm_71, Fri Jan  4 19:53:51 2019
# ['A.N' 'AAL.O' 'AAN.N' ... 'ENS.N' 'FCN.N' 'HUBS.N']
# total 1888 df
# Finished features generation for model DecisionTree.model_lgbm_71, TIME 28.381658792495728
# X_test shape (1833, 48)
# Finished rolled prediction for model DecisionTree.model_lgbm_71, TIME 28.69793462753296
# Starting rolled prediction for model DecisionTree.model_lgbm_71, Fri Jan  4 19:54:20 2019
# Starting features generation for model DecisionTree.model_lgbm_71, Fri Jan  4 19:54:20 2019
# ['A.N' 'AAL.O' 'AAN.N' ... 'COHR.O' 'FDP.N' 'OSIS.O']
# total 1891 df
# Finished features generation for model DecisionTree.model_lgbm_71, TIME 29.3241868019104
# X_test shape (1832, 48)
# Finished rolled prediction for model DecisionTree.model_lgbm_71, TIME 29.60517716407776
# Starting rolled prediction for model DecisionTree.model_lgbm_71, Fri Jan  4 19:54:50 2019
# Starting features generation for model DecisionTree.model_lgbm_71, Fri Jan  4 19:54:50 2019
# ['A.N' 'AAL.O' 'AAN.N' ... 'PCTY.O' 'TREX.N' 'XOG.O']
# total 1890 df
# Finished features generation for model DecisionTree.model_lgbm_71, TIME 27.535044193267822
# X_test shape (1832, 48)
# Finished rolled prediction for model DecisionTree.model_lgbm_71, TIME 27.878612995147705
# Starting rolled prediction for model DecisionTree.model_lgbm_71, Fri Jan  4 19:55:18 2019
# Starting features generation for model DecisionTree.model_lgbm_71, Fri Jan  4 19:55:18 2019
# ['A.N' 'AAL.O' 'AAN.N' ... 'XOG.O' 'SSTK.N' 'TAL.N']
# total 1887 df
# Finished features generation for model DecisionTree.model_lgbm_71, TIME 29.05525827407837
# X_test shape (1826, 48)
# Finished rolled prediction for model DecisionTree.model_lgbm_71, TIME 29.350857973098755
# Starting rolled prediction for model DecisionTree.model_lgbm_71, Fri Jan  4 19:55:47 2019
# Starting features generation for model DecisionTree.model_lgbm_71, Fri Jan  4 19:55:47 2019
# ['A.N' 'AAL.O' 'AAN.N' ... 'EGOV.O' 'LFUS.O' 'TLK.N']
# total 1889 df
# Finished features generation for model DecisionTree.model_lgbm_71, TIME 28.95804190635681
# X_test shape (1823, 48)
# Finished rolled prediction for model DecisionTree.model_lgbm_71, TIME 29.30204963684082
# Starting rolled prediction for model DecisionTree.model_lgbm_71, Fri Jan  4 19:56:16 2019
# Starting features generation for model DecisionTree.model_lgbm_71, Fri Jan  4 19:56:16 2019
# ['A.N' 'AAL.O' 'AAN.N' ... 'HIFR.N' 'RNST.O' 'YUMC.N']
# total 1893 df
# Finished features generation for model DecisionTree.model_lgbm_71, TIME 29.35089612007141
# X_test shape (1824, 48)
# Finished rolled prediction for model DecisionTree.model_lgbm_71, TIME 29.634814023971558
# Starting rolled prediction for model DecisionTree.model_lgbm_71, Fri Jan  4 19:56:46 2019
# Starting features generation for model DecisionTree.model_lgbm_71, Fri Jan  4 19:56:46 2019
# ['A.N' 'AAL.O' 'AAN.N' ... 'HMST.O' 'LVNTA.O' 'MATX.N']
# total 1888 df
# Finished features generation for model DecisionTree.model_lgbm_71, TIME 28.567409992218018
# X_test shape (1824, 48)
# Finished rolled prediction for model DecisionTree.model_lgbm_71, TIME 28.87099313735962
# Starting rolled prediction for model DecisionTree.model_lgbm_71, Fri Jan  4 19:57:15 2019
# Starting features generation for model DecisionTree.model_lgbm_71, Fri Jan  4 19:57:15 2019
# ['A.N' 'AAL.O' 'AAN.N' ... 'ORBK.O' 'TFSL.O' 'UA.N']
# total 1891 df
# Finished features generation for model DecisionTree.model_lgbm_71, TIME 30.597293853759766
# X_test shape (1827, 48)
# Finished rolled prediction for model DecisionTree.model_lgbm_71, TIME 30.93730401992798
# Starting rolled prediction for model DecisionTree.model_lgbm_71, Fri Jan  4 19:57:46 2019
# Starting features generation for model DecisionTree.model_lgbm_71, Fri Jan  4 19:57:46 2019
# ['A.N' 'AAL.O' 'AAN.N' ... 'FRTA.O' 'QCP.N' 'RGR.N']
# total 1892 df
# Finished features generation for model DecisionTree.model_lgbm_71, TIME 31.50833296775818
# X_test shape (1829, 48)
# Finished rolled prediction for model DecisionTree.model_lgbm_71, TIME 32.02295207977295
# Starting rolled prediction for model DecisionTree.model_lgbm_71, Fri Jan  4 19:58:18 2019
# Starting features generation for model DecisionTree.model_lgbm_71, Fri Jan  4 19:58:18 2019
# ['A.N' 'AAL.O' 'AAN.N' ... 'EGP.N' 'IBOC.O' 'LGFb.N']
# total 1896 df
# Finished features generation for model DecisionTree.model_lgbm_71, TIME 26.996469974517822
# X_test shape (1833, 48)
# Finished rolled prediction for model DecisionTree.model_lgbm_71, TIME 27.33565902709961
# Starting rolled prediction for model DecisionTree.model_lgbm_71, Fri Jan  4 19:58:45 2019
# Starting features generation for model DecisionTree.model_lgbm_71, Fri Jan  4 19:58:45 2019
# ['A.N' 'AAL.O' 'AAN.N' ... 'SXC.N' 'TECK.N' 'TRST.O']
# total 1897 df
# Finished features generation for model DecisionTree.model_lgbm_71, TIME 31.019733905792236
# X_test shape (1834, 48)
# Finished rolled prediction for model DecisionTree.model_lgbm_71, TIME 31.557432889938354
# Starting rolled prediction for model DecisionTree.model_lgbm_71, Fri Jan  4 19:59:17 2019
# Starting features generation for model DecisionTree.model_lgbm_71, Fri Jan  4 19:59:17 2019
# ['A.N' 'AAL.O' 'AAN.N' ... 'TRST.O' 'DDC.N' 'IMPV.O']
# total 1894 df
# Finished features generation for model DecisionTree.model_lgbm_71, TIME 29.888493061065674
# X_test shape (1832, 48)
# Finished rolled prediction for model DecisionTree.model_lgbm_71, TIME 30.21999502182007
# Starting rolled prediction for model DecisionTree.model_lgbm_71, Fri Jan  4 19:59:47 2019
# Starting features generation for model DecisionTree.model_lgbm_71, Fri Jan  4 19:59:47 2019
# ['A.N' 'AAL.O' 'AAN.N' ... 'TRST.O' 'DDC.N' 'IMPV.O']
# total 1888 df
# Finished features generation for model DecisionTree.model_lgbm_71, TIME 26.995895862579346
# X_test shape (1830, 48)
# Finished rolled prediction for model DecisionTree.model_lgbm_71, TIME 27.33262801170349
# Starting rolled prediction for model DecisionTree.model_lgbm_71, Fri Jan  4 20:00:15 2019
# Starting features generation for model DecisionTree.model_lgbm_71, Fri Jan  4 20:00:15 2019
# ['A.N' 'AAL.O' 'AAN.N' ... 'PFGC.N' 'TWLO.N' 'ZTO.N']
# total 1891 df
# Finished features generation for model DecisionTree.model_lgbm_71, TIME 31.217482089996338
# X_test shape (1830, 48)
# Finished rolled prediction for model DecisionTree.model_lgbm_71, TIME 31.52758502960205
# Starting rolled prediction for model DecisionTree.model_lgbm_71, Fri Jan  4 20:00:46 2019
# Starting features generation for model DecisionTree.model_lgbm_71, Fri Jan  4 20:00:46 2019
# ['A.N' 'AAL.O' 'AAN.N' ... 'NVCR.O' 'PFS.N' 'TOWN.O']
# total 1889 df
# Finished features generation for model DecisionTree.model_lgbm_71, TIME 26.72469401359558
# X_test shape (1835, 48)
# Finished rolled prediction for model DecisionTree.model_lgbm_71, TIME 27.067068099975586
# Starting rolled prediction for model DecisionTree.model_lgbm_71, Fri Jan  4 20:01:13 2019
# Starting features generation for model DecisionTree.model_lgbm_71, Fri Jan  4 20:01:13 2019
# ['A.N' 'AAL.O' 'AAN.N' ... 'AA.N' 'NEO.O' 'SBCF.O']
# total 1887 df
# Finished features generation for model DecisionTree.model_lgbm_71, TIME 30.242604970932007
# X_test shape (1835, 48)
# Finished rolled prediction for model DecisionTree.model_lgbm_71, TIME 30.73428988456726
# Starting rolled prediction for model DecisionTree.model_lgbm_71, Fri Jan  4 20:01:44 2019
# Starting features generation for model DecisionTree.model_lgbm_71, Fri Jan  4 20:01:44 2019
# ['A.N' 'AAL.O' 'AAN.N' ... 'AA.N' 'NEO.O' 'SBCF.O']
# total 1882 df
# Process ForkPoolWorker-189:
# Process ForkPoolWorker-192:
# Process ForkPoolWorker-191:
# Process ForkPoolWorker-190:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/multiprocess/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/multiprocess/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/multiprocess/pool.py", line 44, in mapstar
#     return list(map(*args))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-be32848dae10> in <module>
#      34
#      35
# ---> 36     confidence = model.predict_rolling([history_df, None], market_obs_df, verbose=True, normalize=True, normalize_vals = [maxs,mins])
#      37
#      38     preds = pd.DataFrame({'assetCode':market_obs_df['assetCode'],'confidence':confidence})
#
# ~/Desktop/Coding/AI/two-sigma-kaggle/kernels/DecisionTree/model_lgbm_71.py in predict_rolling(self, historical_df, market_obs_df, verbose, normalize, normalize_vals)
#     480             raise "Error: model is not trained!"
#     481
# --> 482         X_test = self._generate_features(historical_df[0], historical_df[1], verbose=verbose, normalize=normalize, normalize_vals=normalize_vals, output_len=len(market_obs_df))
#     483         X_test.reset_index(drop=True,inplace=True)
#     484         #import pdb;pdb.set_trace()
#
# ~/Desktop/Coding/AI/two-sigma-kaggle/kernels/DecisionTree/model_lgbm_71.py in _generate_features(self, market_data, news_data, verbose, normalize, normalize_vals, output_len)
#     159         return_features = ['returnsClosePrevMktres10','returnsClosePrevRaw10','open','close']
#     160         n_lag = [3,7,14]
# --> 161         new_df = generate_lag_features(complete_features,n_lag=n_lag)
#     162         new_df['time'] = pd.to_datetime(new_df['time'])
#     163         complete_features['time'] = pd.to_datetime(complete_features['time'])
#
# ~/Desktop/Coding/AI/two-sigma-kaggle/kernels/DecisionTree/model_lgbm_71.py in generate_lag_features(df, n_lag)
#     144
#     145             pool = Pool(4)
# --> 146             all_df = pool.map(create_lag, df_codes)
#     147
#     148             new_df = pd.concat(all_df)
#
# ~/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pathos/multiprocessing.py in map(self, f, *args, **kwds)
#     135         AbstractWorkerPool._AbstractWorkerPool__map(self, f, *args, **kwds)
#     136         _pool = self._serve()
# --> 137         return _pool.map(star(f), zip(*args)) # chunksize
#     138     map.__doc__ = AbstractWorkerPool.map.__doc__
#     139     def imap(self, f, *args, **kwds):
#
# ~/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/multiprocess/pool.py in map(self, func, iterable, chunksize)
#     266         in a list that is returned.
#     267         '''
# --> 268         return self._map_async(func, iterable, mapstar, chunksize).get()
#     269
#     270     def starmap(self, func, iterable, chunksize=None):
#
# ~/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/multiprocess/pool.py in get(self, timeout)
#     649
#     650     def get(self, timeout=None):
# --> 651         self.wait(timeout)
#     652         if not self.ready():
#     653             raise TimeoutError
#
# ~/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/multiprocess/pool.py in wait(self, timeout)
#     646
#     647     def wait(self, timeout=None):
# --> 648         self._event.wait(timeout)
#     649
#     650     def get(self, timeout=None):
#
# /usr/local/Cellar/python/3.7.1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# /usr/local/Cellar/python/3.7.1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pathos/helpers/mp_helper.py", line 15, in <lambda>
#     func = lambda args: f(*args)
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/multiprocess/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pathos/helpers/mp_helper.py", line 15, in <lambda>
#     func = lambda args: f(*args)
#   File "../model_lgbm_71.py", line 121, in create_lag
#     lag_std = rolled.std()
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/window.py", line 1616, in std
#     return super(Rolling, self).std(ddof=ddof, **kwargs)
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/window.py", line 1167, in std
#     ddof=ddof, **kwargs)
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/window.py", line 840, in _apply
#     blocks, obj, index = self._create_blocks()
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/window.py", line 128, in _create_blocks
#     blocks = obj._to_dict_of_blocks(copy=False).values()
#   File "../model_lgbm_71.py", line 118, in create_lag
#     lag_mean = rolled.mean()
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/generic.py", line 4888, in _to_dict_of_blocks
#     for k, v, in self._data.to_dict(copy=copy).items()}
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/window.py", line 1605, in mean
#     return super(Rolling, self).mean(*args, **kwargs)
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/internals.py", line 4009, in to_dict
#     for dtype, blocks in bd.items()}
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/window.py", line 1058, in mean
#     return self._apply('roll_mean', 'mean', **kwargs)
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/internals.py", line 4009, in <dictcomp>
#     for dtype, blocks in bd.items()}
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/window.py", line 840, in _apply
#     blocks, obj, index = self._create_blocks()
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/internals.py", line 3865, in combine
#     axes[0] = self.items.take(indexer)
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/window.py", line 128, in _create_blocks
#     blocks = obj._to_dict_of_blocks(copy=False).values()
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/generic.py", line 4888, in _to_dict_of_blocks
#     for k, v, in self._data.to_dict(copy=copy).items()}
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/indexes/base.py", line 2195, in take
#     return self._shallow_copy(taken)
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/internals.py", line 4009, in to_dict
#     for dtype, blocks in bd.items()}
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/indexes/numeric.py", line 68, in _shallow_copy
#     return self._shallow_copy_with_infer(values=values, **kwargs)
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/internals.py", line 4009, in <dictcomp>
#     for dtype, blocks in bd.items()}
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/indexes/base.py", line 545, in _shallow_copy_with_infer
#     return Index(values, **attributes)
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/internals.py", line 3861, in combine
#     axis=0, allow_fill=False)
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/indexes/base.py", line 371, in __new__
#     return Int64Index(data, copy=copy, dtype=dtype, name=name)
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/algorithms.py", line 1588, in take_nd
#     if is_extension_array_dtype(arr):
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/indexes/numeric.py", line 47, in __new__
#     if copy or not is_dtype_equal(data.dtype, cls._default_dtype):
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/dtypes/common.py", line 1711, in is_extension_array_dtype
#     if isinstance(arr_or_dtype, (ABCIndexClass, ABCSeries)):
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/dtypes/common.py", line 720, in is_dtype_equal
#     source = _get_dtype(source)
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/dtypes/generic.py", line 9, in _check
#     return getattr(inst, attr, '_typ') in comp
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/dtypes/common.py", line 1806, in _get_dtype
#     if isinstance(arr_or_dtype, np.dtype):
# KeyboardInterrupt
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/multiprocess/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/multiprocess/pool.py", line 44, in mapstar
#     return list(map(*args))
# Traceback (most recent call last):
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pathos/helpers/mp_helper.py", line 15, in <lambda>
#     func = lambda args: f(*args)
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/indexes/base.py", line 3078, in get_loc
#     return self._engine.get_loc(key)
#   File "pandas/_libs/index.pyx", line 140, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/index.pyx", line 162, in pandas._libs.index.IndexEngine.get_loc
#   File "../model_lgbm_71.py", line 120, in create_lag
#     lag_min = rolled.min()
#   File "pandas/_libs/hashtable_class_helper.pxi", line 1492, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/window.py", line 1599, in min
#     return super(Rolling, self).min(*args, **kwargs)
#   File "pandas/_libs/hashtable_class_helper.pxi", line 1500, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'lag_3_open_max'
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/window.py", line 1054, in min
#     return self._apply('roll_min', 'min', **kwargs)
#
# During handling of the above exception, another exception occurred:
#
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/window.py", line 840, in _apply
#     blocks, obj, index = self._create_blocks()
# Traceback (most recent call last):
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/window.py", line 128, in _create_blocks
#     blocks = obj._to_dict_of_blocks(copy=False).values()
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/internals.py", line 4243, in set
#     loc = self.items.get_loc(item)
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/generic.py", line 4888, in _to_dict_of_blocks
#     for k, v, in self._data.to_dict(copy=copy).items()}
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/indexes/base.py", line 3080, in get_loc
#     return self._engine.get_loc(self._maybe_cast_indexer(key))
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/internals.py", line 4009, in to_dict
#     for dtype, blocks in bd.items()}
#   File "pandas/_libs/index.pyx", line 140, in pandas._libs.index.IndexEngine.get_loc
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/internals.py", line 4009, in <dictcomp>
#     for dtype, blocks in bd.items()}
#   File "pandas/_libs/index.pyx", line 162, in pandas._libs.index.IndexEngine.get_loc
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/internals.py", line 3865, in combine
#     axes[0] = self.items.take(indexer)
#   File "pandas/_libs/hashtable_class_helper.pxi", line 1492, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/indexes/base.py", line 2195, in take
#     return self._shallow_copy(taken)
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/indexes/numeric.py", line 68, in _shallow_copy
#     return self._shallow_copy_with_infer(values=values, **kwargs)
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/indexes/base.py", line 545, in _shallow_copy_with_infer
#     return Index(values, **attributes)
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/indexes/base.py", line 370, in __new__
#     from .numeric import Int64Index
#   File "<frozen importlib._bootstrap>", line 1019, in _handle_fromlist
# KeyboardInterrupt
#   File "pandas/_libs/hashtable_class_helper.pxi", line 1500, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'lag_3_open_max'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/multiprocess/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/multiprocess/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/multiprocess/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/multiprocess/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pathos/helpers/mp_helper.py", line 15, in <lambda>
#     func = lambda args: f(*args)
#   File "../model_lgbm_71.py", line 123, in create_lag
#     df_code['lag_%s_%s_max'%(window,col)] = lag_max
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/frame.py", line 3119, in __setitem__
#     self._set_item(key, value)
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/frame.py", line 3195, in _set_item
#     NDFrame._set_item(self, key, value)
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/generic.py", line 2600, in _set_item
#     self._data.set(key, value)
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/internals.py", line 4246, in set
#     self.insert(len(self.items), item, value)
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/internals.py", line 4344, in insert
#     new_axis = self.items.insert(loc, item)
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/indexes/base.py", line 4374, in insert
#     item = self._coerce_scalar_to_index(item)._ndarray_values
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/indexes/base.py", line 951, in _coerce_scalar_to_index
#     return Index([item], dtype=dtype, **self._get_attributes_dict())
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/indexes/base.py", line 280, in __new__
#     if is_interval_dtype(data) or is_interval_dtype(dtype):
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/dtypes/common.py", line 510, in is_interval_dtype
#     return IntervalDtype.is_dtype(arr_or_dtype)
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/dtypes/dtypes.py", line 725, in is_dtype
#     return super(IntervalDtype, cls).is_dtype(dtype)
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/dtypes/base.py", line 93, in is_dtype
#     return cls.construct_from_string(dtype) is not None
#   File "/Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/pandas/core/dtypes/dtypes.py", line 684, in construct_from_string
#     raise TypeError(msg.format(typ=type(string)))
# KeyboardInterrupt

# %%
len(PREDICTIONS), PREDICTIONS[1].shape
# Out:
# (55, (1843, 2))

# %%
len(_COMPARE_PREDICTIONS), _COMPARE_PREDICTIONS[1].shape
# Out:
# (47, (1843, 2))

# %%
PREDICTIONS[1].shape, _COMPARE_PREDICTIONS[1].shape
# Out:
# ((1843, 2), (1843, 2))

# %%
from matplotlib import pyplot as plt
index = 35
plt.figure(figsize=(15,5))
plt.subplot('122')
plt.hist(PREDICTIONS[index]['confidenceValue'],bins='auto')
plt.subplot('121')
plt.hist(_COMPARE_PREDICTIONS[index]['confidenceValue'],bins='auto')
plt.show()

# %%
for x in PREDICTIONS[1].iloc[:,1]:
    assert type(x)==float

# %%
index = 6
df = pd.DataFrame({'assetCode':PREDICTIONS[index]['assetCode'],'ref':PREDICTIONS[index]['confidenceValue'],'compare':_COMPARE_PREDICTIONS[index]['confidenceValue']})
df[df.iloc[:,1] != df.iloc[:,2]]
# Out:
# Empty DataFrame
# Columns: [assetCode, ref, compare]
# Index: []

# %%
for i, ref in enumerate(_COMPARE_PREDICTIONS):
    df = pd.DataFrame({'assetCode':PREDICTIONS[i]['assetCode'],'ref':PREDICTIONS[i]['confidenceValue'],'compare':_COMPARE_PREDICTIONS[i]['confidenceValue']})
    try:
        assert all(df.iloc[:,1] == df.iloc[:,2])
    except:
        print("AssertionError on "+str(i))
    print("ACCEPTED "+str(i))
# Out:
# ACCEPTED 0
# ACCEPTED 1
# ACCEPTED 2
# ACCEPTED 3
# ACCEPTED 4
# ACCEPTED 5
# ACCEPTED 6
# ACCEPTED 7
# ACCEPTED 8
# ACCEPTED 9
# ACCEPTED 10
# ACCEPTED 11
# ACCEPTED 12
# ACCEPTED 13
# ACCEPTED 14
# ACCEPTED 15
# ACCEPTED 16
# ACCEPTED 17
# ACCEPTED 18
# ACCEPTED 19
# ACCEPTED 20
# ACCEPTED 21
# ACCEPTED 22
# ACCEPTED 23
# ACCEPTED 24
# ACCEPTED 25
# ACCEPTED 26
# ACCEPTED 27
# ACCEPTED 28
# ACCEPTED 29
# ACCEPTED 30
# ACCEPTED 31
# ACCEPTED 32
# ACCEPTED 33
# ACCEPTED 34
# ACCEPTED 35
# ACCEPTED 36
# ACCEPTED 37
# ACCEPTED 38
# ACCEPTED 39
# ACCEPTED 40
# ACCEPTED 41
# ACCEPTED 42
# ACCEPTED 43
# ACCEPTED 44
# ACCEPTED 45
# ACCEPTED 46

# %%
compare_X_live = pk.load(open('../pickle/rolling_dataset_1.pkl','rb'))

# %%
ref_X_live = pk.load(open('../pickle/_ref_rolling_dataset_1.pkl','rb'))

# %%
compare_X_live.columns[9]
# Out:
# 'returnsClosePrevMktres10'

# %%
compare_X_live.iloc[8][9]
# Out:
# 0.0048455803509486195

# %%
ref_X_live.iloc[8][9]
# Out:
# 0.06736583038573696

# %%
days[1][0].iloc[8]['returnsClosePrevMktres10']
# Out:
# nan
