# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../../data"))

# Any results you write to the current directory are saved as output.
# Out:
# ['.DS_Store', 'market_test_df.csv', 'market_train_df.csv', 'market_train_df_head.csv', 'news_train_df_head.csv']

# %%
import numpy as np
import lightgbm as lgb
import pandas as pd
#from kaggle.competitions import twosigmanews
import matplotlib.pyplot as plt
import random
from datetime import datetime, date
from xgboost import XGBClassifier
from sklearn import model_selection
from sklearn.metrics import mean_squared_error
import time
# Out:
# /Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/lightgbm/__init__.py:46: UserWarning: Starting from version 2.2.1, the library file in distribution wheels for macOS is built by the Apple Clang (Xcode_8.3.1) compiler.
# This means that in case of installing LightGBM from PyPI via the ``pip install lightgbm`` command, you don't need to install the gcc compiler anymore.
# Instead of that, you need to install the OpenMP library, which is required for running LightGBM on the system with the Apple Clang compiler.
# You can install the OpenMP library by the following command: ``brew install libomp``.
#   "You can install the OpenMP library by the following command: ``brew install libomp``.", UserWarning)

# %%
# official way to get the data
#from kaggle.competitions import twosigmanews
#env = twosigmanews.make_env()
#print('Done!')

# %%
market_train_df = pd.read_csv("../../data/market_train_df.csv").drop('Unnamed: 0', axis=1)

# %%
market_train_df['time'] = pd.to_datetime(market_train_df['time']).dt.date
market_train_df = market_train_df.loc[market_train_df['time']>=date(2010, 1, 1)]

# %%
from multiprocessing import Pool

def create_lag(df_code,n_lag=[3,7,14,],shift_size=1):
    code = df_code['assetCode'].unique()
    
    for col in return_features:
        for window in n_lag:
            rolled = df_code[col].shift(shift_size).rolling(window=window)
            lag_mean = rolled.mean()
            lag_max = rolled.max()
            lag_min = rolled.min()
            lag_std = rolled.std()
            df_code['%s_lag_%s_mean'%(col,window)] = lag_mean
            df_code['%s_lag_%s_max'%(col,window)] = lag_max
            df_code['%s_lag_%s_min'%(col,window)] = lag_min
#             df_code['%s_lag_%s_std'%(col,window)] = lag_std
    return df_code.fillna(-1)

def generate_lag_features(df,n_lag = [3,7,14]):
    features = ['time', 'assetCode', 'assetName', 'volume', 'close', 'open',
       'returnsClosePrevRaw1', 'returnsOpenPrevRaw1',
       'returnsClosePrevMktres1', 'returnsOpenPrevMktres1',
       'returnsClosePrevRaw10', 'returnsOpenPrevRaw10',
       'returnsClosePrevMktres10', 'returnsOpenPrevMktres10',
       'returnsOpenNextMktres10', 'universe']
    
    assetCodes = df['assetCode'].unique()
    print(assetCodes)
    all_df = []
    df_codes = df.groupby('assetCode')
    df_codes = [df_code[1][['time','assetCode']+return_features] for df_code in df_codes]
    print('total %s df'%len(df_codes))
    
    pool = Pool(4)
    all_df = pool.map(create_lag, df_codes)
    
    new_df = pd.concat(all_df)  
    new_df.drop(return_features,axis=1,inplace=True)
    pool.close()
    
    return new_df

# %%
# return_features = ['close']
# new_df = generate_lag_features(market_train_df,n_lag = 5)
# market_train_df = pd.merge(market_train_df,new_df,how='left',on=['time','assetCode'])

# %%
return_features = ['returnsClosePrevMktres10','returnsClosePrevRaw10','open','close']
n_lag = [3,7,14]
new_df = generate_lag_features(market_train_df,n_lag=n_lag)
market_train_df = pd.merge(market_train_df,new_df,how='left',on=['time','assetCode'])
# Out:
# ['A.N' 'AAI.N' 'AAP.N' ... 'HASI.N' 'NPTN.N' 'APFH.N']
# total 3274 df

# %%
print(market_train_df.columns)
# Out:
# Index(['time', 'assetCode', 'assetName', 'volume', 'close', 'open',
#        'returnsClosePrevRaw1', 'returnsOpenPrevRaw1',
#        'returnsClosePrevMktres1', 'returnsOpenPrevMktres1',
#        'returnsClosePrevRaw10', 'returnsOpenPrevRaw10',
#        'returnsClosePrevMktres10', 'returnsOpenPrevMktres10',
#        'returnsOpenNextMktres10', 'universe',
#        'returnsClosePrevMktres10_lag_3_mean',
#        'returnsClosePrevMktres10_lag_3_max',
#        'returnsClosePrevMktres10_lag_3_min',
#        'returnsClosePrevMktres10_lag_7_mean',
#        'returnsClosePrevMktres10_lag_7_max',
#        'returnsClosePrevMktres10_lag_7_min',
#        'returnsClosePrevMktres10_lag_14_mean',
#        'returnsClosePrevMktres10_lag_14_max',
#        'returnsClosePrevMktres10_lag_14_min',
#        'returnsClosePrevRaw10_lag_3_mean', 'returnsClosePrevRaw10_lag_3_max',
#        'returnsClosePrevRaw10_lag_3_min', 'returnsClosePrevRaw10_lag_7_mean',
#        'returnsClosePrevRaw10_lag_7_max', 'returnsClosePrevRaw10_lag_7_min',
#        'returnsClosePrevRaw10_lag_14_mean', 'returnsClosePrevRaw10_lag_14_max',
#        'returnsClosePrevRaw10_lag_14_min', 'open_lag_3_mean', 'open_lag_3_max',
#        'open_lag_3_min', 'open_lag_7_mean', 'open_lag_7_max', 'open_lag_7_min',
#        'open_lag_14_mean', 'open_lag_14_max', 'open_lag_14_min',
#        'close_lag_3_mean', 'close_lag_3_max', 'close_lag_3_min',
#        'close_lag_7_mean', 'close_lag_7_max', 'close_lag_7_min',
#        'close_lag_14_mean', 'close_lag_14_max', 'close_lag_14_min'],
#       dtype='object')

# %%
# return_features = ['open']
# new_df = generate_lag_features(market_train_df,n_lag=[3,7,14])
# market_train_df = pd.merge(market_train_df,new_df,how='left',on=['time','assetCode'])

# %%
def mis_impute(data):
    for i in data.columns:
        if data[i].dtype == "object":
            data[i] = data[i].fillna("other")
        elif (data[i].dtype == "int64" or data[i].dtype == "float64"):
            data[i] = data[i].fillna(data[i].mean())
        else:
            pass
    return data

market_train_df = mis_impute(market_train_df)

# %%
def data_prep(market_train):
    lbl = {k: v for v, k in enumerate(market_train['assetCode'].unique())}
    market_train['assetCodeT'] = market_train['assetCode'].map(lbl)
    market_train = market_train.dropna(axis=0)
    return market_train

market_train_df = data_prep(market_train_df)
# # check the shape
print(market_train_df.shape)
# Out:
# (2846738, 53)

# %%
from sklearn.preprocessing import LabelEncoder

up = market_train_df['returnsOpenNextMktres10'] >= 0


universe = market_train_df['universe'].values
d = market_train_df['time']

fcol = [c for c in market_train_df if c not in ['assetCode', 'assetCodes', 'assetCodesLen', 'assetName', 'audiences', 
                                             'firstCreated', 'headline', 'headlineTag', 'marketCommentary', 'provider', 
                                             'returnsOpenNextMktres10', 'sourceId', 'subjects', 'time', 'time_x', 'universe','sourceTimestamp']]

X = market_train_df[fcol].values
up = up.values
r = market_train_df.returnsOpenNextMktres10.values

# Scaling of X values
# It is good to keep these scaling values for later
mins = np.min(X, axis=0)
maxs = np.max(X, axis=0)
rng = maxs - mins
X = 1 - ((maxs - X) / rng)

# Sanity check
assert X.shape[0] == up.shape[0] == r.shape[0]

from xgboost import XGBClassifier
from sklearn import model_selection
from sklearn.metrics import mean_squared_error
import time

import pickle as pk
with open("../pickle/_ref_market_train_df.pkl","wb") as f:
    #dumps generated features for comparison
    pk.dump(X, f)

X_train, X_test, up_train, up_test, r_train, r_test,u_train,u_test,d_train,d_test = model_selection.train_test_split(X, up, r,universe,d, test_size=0.25, random_state=99)


# te = market_train_df['time']>date(2015, 1, 1)

# tt = 0
# for tt,i in enumerate(te.values):
#     if i:
#         idx = tt
#         print(i,tt)
#         break
# print(idx)
# # for ind_tr, ind_te in tscv.split(X):
# #     print(ind_tr)
# X_train, X_test = X[:idx],X[idx:]

# up_train, up_test = up[:idx],up[idx:]
# r_train, r_test = r[:idx],r[idx:]
# u_train,u_test = universe[:idx],universe[idx:]
# d_train,d_test = d[:idx],d[idx:]

# train_data = lgb.Dataset(X_train, label=up_train.astype(int))
train_data = lgb.Dataset(X, label=up.astype(int))
test_data = lgb.Dataset(X_test, label=up_test.astype(int))

# %%
# these are tuned params I found
x_1 = [0.19000424246380565, 2452, 212, 239, 202]
x_2 = [0.19016805202090095, 2583, 213, 172, 220]
x_3 = [0.19564034613157152, 2452, 210, 160, 219]
x_4 = [0.19016805202090095, 2500, 213, 150, 202]
x_5 = [0.19000424246380565, 2600, 215, 140, 220]
x_6 = [0.19000424246380565, 2652, 216, 152, 202]

"""
x_1 = [0.19000424246380565, 2452, 212, 328, 202]
x_2 = [0.19016805202090095, 2583, 213, 312, 220]
x_3 = [0.19564034613157152, 2455, 210, 330, 219]
x_4 = [0.15000000000000000, 2600, 220, 340, 202]
x_5 = [0.15000000000000000, 2600, 220, 330, 220]
x_6 = [0.15000000000000000, 2400, 220, 340, 202]
"""
print(up_train)
def exp_loss(p,y):
    y = y.get_label()
#     p = p.get_label()
    grad = -y*(1.0-1.0/(1.0+np.exp(-y*p)))
    hess = -(np.exp(y*p)*(y*p-1)-1)/((np.exp(y*p)+1)**2)
    
    return grad,hess

params_1 = {
        'task': 'train',
        'boosting_type': 'gbdt',
        'objective': 'binary',
#         'objective': 'regression',
        'learning_rate': x_1[0],
        'num_leaves': x_1[1],
        'min_data_in_leaf': x_1[2],
#         'num_iteration': x_1[3],
        'num_iteration': 239,
        'max_bin': x_1[4],
        'verbose': 1
    }

params_2 = {
        'task': 'train',
        'boosting_type': 'gbdt',
        'objective': 'binary',
#         'objective': 'regression',
        'learning_rate': x_2[0],
        'num_leaves': x_2[1],
        'min_data_in_leaf': x_2[2],
#         'num_iteration': x_2[3],
        'num_iteration': 172,
        'max_bin': x_2[4],
        'verbose': 1
    }

params_3 = {
        'task': 'train',
        'boosting_type': 'gbdt',
        'objective': 'binary',
        'learning_rate': x_3[0],
        'num_leaves': x_3[1],
        'min_data_in_leaf': x_3[2],
        'num_iteration': x_3[3],
        'max_bin': x_3[4],
        'verbose': 1
    }

params_4 = {
        'task': 'train',
        'boosting_type': 'gbdt',
        'objective': 'binary',
        'learning_rate': x_4[0],
        'num_leaves': x_4[1],
        'min_data_in_leaf': x_4[2],
        'num_iteration': x_4[3],
        'max_bin': x_4[4],
        'verbose': 1
    }

params_5 = {
        'task': 'train',
        'boosting_type': 'gbdt',#dart
        'objective': 'binary',
        'learning_rate': x_5[0],
        'num_leaves': x_5[1],
        'min_data_in_leaf': x_5[2],
        'num_iteration': x_5[3],
        'max_bin': x_5[4],
        'verbose': 1
    }

params_6 = {
        'task': 'train',
        'boosting_type': 'gbdt',
        'objective': 'binary',
        'learning_rate': x_6[0],
        'num_leaves': x_6[1],
        'min_data_in_leaf': x_6[2],
        'num_iteration': x_6[3],
        'max_bin': x_6[4],
        'verbose': 1
    }

gbm_1 = lgb.train(params_1,
        train_data,
        num_boost_round=100,
        valid_sets=test_data,
        early_stopping_rounds=5,
#         fobj=exp_loss,
        )

gbm_2 = lgb.train(params_2,
        train_data,
        num_boost_round=100,
        valid_sets=test_data,
        early_stopping_rounds=5,
#         fobj=exp_loss,
        )

gbm_3 = lgb.train(params_3,
        train_data,
        num_boost_round=100,
        valid_sets=test_data,
        early_stopping_rounds=5,
#         fobj=exp_loss,
        )

gbm_4 = lgb.train(params_4,
        train_data,
        num_boost_round=100,
        valid_sets=test_data,
        early_stopping_rounds=5,
#         fobj=exp_loss,
        )

gbm_5 = lgb.train(params_5,
        train_data,
        num_boost_round=100,
        valid_sets=test_data,
        early_stopping_rounds=5,
#         fobj=exp_loss,
        )


gbm_6 = lgb.train(params_6,
        train_data,
        num_boost_round=100,
        valid_sets=test_data,
        early_stopping_rounds=10,
#         fobj=exp_loss,
        )
# Out:
# [ True  True False ... False False  True]
# /Users/alex/Desktop/Coding/AI/two-sigma-kaggle/env3/lib/python3.7/site-packages/lightgbm/engine.py:116: UserWarning: Found `num_iteration` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [1]	valid_0's binary_logloss: 0.686931
# Training until validation scores don't improve for 5 rounds.
# [2]	valid_0's binary_logloss: 0.682219
# [3]	valid_0's binary_logloss: 0.678278
# [4]	valid_0's binary_logloss: 0.674929
# [5]	valid_0's binary_logloss: 0.67202
# [6]	valid_0's binary_logloss: 0.66939
# [7]	valid_0's binary_logloss: 0.667001
# [8]	valid_0's binary_logloss: 0.664809
# [9]	valid_0's binary_logloss: 0.662691
# [10]	valid_0's binary_logloss: 0.660414
# [11]	valid_0's binary_logloss: 0.658421
# [12]	valid_0's binary_logloss: 0.656347
# [13]	valid_0's binary_logloss: 0.654358
# [14]	valid_0's binary_logloss: 0.652363
# [15]	valid_0's binary_logloss: 0.650411
# [16]	valid_0's binary_logloss: 0.648334
# [17]	valid_0's binary_logloss: 0.646779
# [18]	valid_0's binary_logloss: 0.644703
# [19]	valid_0's binary_logloss: 0.643046
# [20]	valid_0's binary_logloss: 0.640843
# [21]	valid_0's binary_logloss: 0.639291
# [22]	valid_0's binary_logloss: 0.63769
# [23]	valid_0's binary_logloss: 0.634964
# [24]	valid_0's binary_logloss: 0.633487
# [25]	valid_0's binary_logloss: 0.63204
# [26]	valid_0's binary_logloss: 0.630691
# [27]	valid_0's binary_logloss: 0.628801
# [28]	valid_0's binary_logloss: 0.627248
# [29]	valid_0's binary_logloss: 0.625206
# [30]	valid_0's binary_logloss: 0.623757
# [31]	valid_0's binary_logloss: 0.621385
# [32]	valid_0's binary_logloss: 0.620036
# [33]	valid_0's binary_logloss: 0.618735
# [34]	valid_0's binary_logloss: 0.61746
# [35]	valid_0's binary_logloss: 0.615754
# [36]	valid_0's binary_logloss: 0.614614
# [37]	valid_0's binary_logloss: 0.613146
# [38]	valid_0's binary_logloss: 0.611538
# [39]	valid_0's binary_logloss: 0.610414
# [40]	valid_0's binary_logloss: 0.60875
# [41]	valid_0's binary_logloss: 0.607684
# [42]	valid_0's binary_logloss: 0.606324
# [43]	valid_0's binary_logloss: 0.604975
# [44]	valid_0's binary_logloss: 0.603557
# [45]	valid_0's binary_logloss: 0.602286
# [46]	valid_0's binary_logloss: 0.600932
# [47]	valid_0's binary_logloss: 0.599895
# [48]	valid_0's binary_logloss: 0.597765
# [49]	valid_0's binary_logloss: 0.596661
# [50]	valid_0's binary_logloss: 0.595517
# [51]	valid_0's binary_logloss: 0.594054
# [52]	valid_0's binary_logloss: 0.592279
# [53]	valid_0's binary_logloss: 0.591254
# [54]	valid_0's binary_logloss: 0.589292
# [55]	valid_0's binary_logloss: 0.588334
# [56]	valid_0's binary_logloss: 0.587165
# [57]	valid_0's binary_logloss: 0.586137
# [58]	valid_0's binary_logloss: 0.584966
# [59]	valid_0's binary_logloss: 0.583855
# [60]	valid_0's binary_logloss: 0.582508
# [61]	valid_0's binary_logloss: 0.581157
# [62]	valid_0's binary_logloss: 0.579346
# [63]	valid_0's binary_logloss: 0.578303
# [64]	valid_0's binary_logloss: 0.577254
# [65]	valid_0's binary_logloss: 0.575675
# [66]	valid_0's binary_logloss: 0.574701
# [67]	valid_0's binary_logloss: 0.573395
# [68]	valid_0's binary_logloss: 0.572257
# [69]	valid_0's binary_logloss: 0.571237
# [70]	valid_0's binary_logloss: 0.570135
# [71]	valid_0's binary_logloss: 0.568493
# [72]	valid_0's binary_logloss: 0.567444
# [73]	valid_0's binary_logloss: 0.566287
# [74]	valid_0's binary_logloss: 0.565275
# [75]	valid_0's binary_logloss: 0.563739
# [76]	valid_0's binary_logloss: 0.562598
# [77]	valid_0's binary_logloss: 0.561369
# [78]	valid_0's binary_logloss: 0.560201
# [79]	valid_0's binary_logloss: 0.559231
# [80]	valid_0's binary_logloss: 0.557984
# [81]	valid_0's binary_logloss: 0.556222
# [82]	valid_0's binary_logloss: 0.555228
# [83]	valid_0's binary_logloss: 0.554258
# [84]	valid_0's binary_logloss: 0.553164
# [85]	valid_0's binary_logloss: 0.552188
# [86]	valid_0's binary_logloss: 0.551242
# [87]	valid_0's binary_logloss: 0.549974
# [88]	valid_0's binary_logloss: 0.549008
# [89]	valid_0's binary_logloss: 0.548031
# [90]	valid_0's binary_logloss: 0.54685
# [91]	valid_0's binary_logloss: 0.54583
# [92]	valid_0's binary_logloss: 0.544967
# [93]	valid_0's binary_logloss: 0.543755
# [94]	valid_0's binary_logloss: 0.542756
# [95]	valid_0's binary_logloss: 0.541854
# [96]	valid_0's binary_logloss: 0.540356
# [97]	valid_0's binary_logloss: 0.539384
# [98]	valid_0's binary_logloss: 0.538416
# [99]	valid_0's binary_logloss: 0.536744
# [100]	valid_0's binary_logloss: 0.535687
# [101]	valid_0's binary_logloss: 0.534547
# [102]	valid_0's binary_logloss: 0.533597
# [103]	valid_0's binary_logloss: 0.532736
# [104]	valid_0's binary_logloss: 0.531404
# [105]	valid_0's binary_logloss: 0.530326
# [106]	valid_0's binary_logloss: 0.529349
# [107]	valid_0's binary_logloss: 0.528462
# [108]	valid_0's binary_logloss: 0.527381
# [109]	valid_0's binary_logloss: 0.526541
# [110]	valid_0's binary_logloss: 0.52565
# [111]	valid_0's binary_logloss: 0.524526
# [112]	valid_0's binary_logloss: 0.523379
# [113]	valid_0's binary_logloss: 0.522554
# [114]	valid_0's binary_logloss: 0.521513
# [115]	valid_0's binary_logloss: 0.520378
# [116]	valid_0's binary_logloss: 0.519589
# [117]	valid_0's binary_logloss: 0.518682
# [118]	valid_0's binary_logloss: 0.517823
# [119]	valid_0's binary_logloss: 0.516472
# [120]	valid_0's binary_logloss: 0.515623
# [121]	valid_0's binary_logloss: 0.51483
# [122]	valid_0's binary_logloss: 0.513888
# [123]	valid_0's binary_logloss: 0.512708
# [124]	valid_0's binary_logloss: 0.511731
# [125]	valid_0's binary_logloss: 0.510861
# [126]	valid_0's binary_logloss: 0.50962
# [127]	valid_0's binary_logloss: 0.508736
# [128]	valid_0's binary_logloss: 0.507855
# [129]	valid_0's binary_logloss: 0.506902
# [130]	valid_0's binary_logloss: 0.505449
# [131]	valid_0's binary_logloss: 0.504614
# [132]	valid_0's binary_logloss: 0.503674
# [133]	valid_0's binary_logloss: 0.502854
# [134]	valid_0's binary_logloss: 0.501687
# [135]	valid_0's binary_logloss: 0.500877
# [136]	valid_0's binary_logloss: 0.500049
# [137]	valid_0's binary_logloss: 0.498929
# [138]	valid_0's binary_logloss: 0.498111
# [139]	valid_0's binary_logloss: 0.496999
# [140]	valid_0's binary_logloss: 0.496234
# [141]	valid_0's binary_logloss: 0.495315
# [142]	valid_0's binary_logloss: 0.494535
# [143]	valid_0's binary_logloss: 0.493372
# [144]	valid_0's binary_logloss: 0.492551
# [145]	valid_0's binary_logloss: 0.491679
# [146]	valid_0's binary_logloss: 0.490856
# [147]	valid_0's binary_logloss: 0.489897
# [148]	valid_0's binary_logloss: 0.488924
# [149]	valid_0's binary_logloss: 0.487961
# [150]	valid_0's binary_logloss: 0.487226
# [151]	valid_0's binary_logloss: 0.486485
# [152]	valid_0's binary_logloss: 0.485378
# [153]	valid_0's binary_logloss: 0.484569
# [154]	valid_0's binary_logloss: 0.483758
# [155]	valid_0's binary_logloss: 0.482649
# [156]	valid_0's binary_logloss: 0.481885
# [157]	valid_0's binary_logloss: 0.480938
# [158]	valid_0's binary_logloss: 0.480143
# [159]	valid_0's binary_logloss: 0.479317
# [160]	valid_0's binary_logloss: 0.478518
# [161]	valid_0's binary_logloss: 0.477554
# [162]	valid_0's binary_logloss: 0.476691
# [163]	valid_0's binary_logloss: 0.475907
# [164]	valid_0's binary_logloss: 0.474781
# [165]	valid_0's binary_logloss: 0.473984
# [166]	valid_0's binary_logloss: 0.473271
# [167]	valid_0's binary_logloss: 0.472442
# [168]	valid_0's binary_logloss: 0.471359
# [169]	valid_0's binary_logloss: 0.470621
# [170]	valid_0's binary_logloss: 0.469785
# [171]	valid_0's binary_logloss: 0.469035
# [172]	valid_0's binary_logloss: 0.46832
# [173]	valid_0's binary_logloss: 0.467271
# [174]	valid_0's binary_logloss: 0.466192
# [175]	valid_0's binary_logloss: 0.465384
# [176]	valid_0's binary_logloss: 0.464244
# [177]	valid_0's binary_logloss: 0.463513
# [178]	valid_0's binary_logloss: 0.462766
# [179]	valid_0's binary_logloss: 0.461952
# [180]	valid_0's binary_logloss: 0.461235
# [181]	valid_0's binary_logloss: 0.460521
# [182]	valid_0's binary_logloss: 0.45978
# [183]	valid_0's binary_logloss: 0.459039
# [184]	valid_0's binary_logloss: 0.458357
# [185]	valid_0's binary_logloss: 0.457473
# [186]	valid_0's binary_logloss: 0.456807
# [187]	valid_0's binary_logloss: 0.456034
# [188]	valid_0's binary_logloss: 0.455324
# [189]	valid_0's binary_logloss: 0.454343
# [190]	valid_0's binary_logloss: 0.453549
# [191]	valid_0's binary_logloss: 0.452898
# [192]	valid_0's binary_logloss: 0.452219
# [193]	valid_0's binary_logloss: 0.451332
# [194]	valid_0's binary_logloss: 0.450583
# [195]	valid_0's binary_logloss: 0.449808
# [196]	valid_0's binary_logloss: 0.448989
# [197]	valid_0's binary_logloss: 0.447974
# [198]	valid_0's binary_logloss: 0.447315
# [199]	valid_0's binary_logloss: 0.446657
# [200]	valid_0's binary_logloss: 0.445971
# [201]	valid_0's binary_logloss: 0.444962
# [202]	valid_0's binary_logloss: 0.444309
# [203]	valid_0's binary_logloss: 0.443608
# [204]	valid_0's binary_logloss: 0.442835
# [205]	valid_0's binary_logloss: 0.442163
# [206]	valid_0's binary_logloss: 0.441452
# [207]	valid_0's binary_logloss: 0.440733
# [208]	valid_0's binary_logloss: 0.440091
# [209]	valid_0's binary_logloss: 0.439227
# [210]	valid_0's binary_logloss: 0.438611
# [211]	valid_0's binary_logloss: 0.437945
# [212]	valid_0's binary_logloss: 0.436973
# [213]	valid_0's binary_logloss: 0.4363
# [214]	valid_0's binary_logloss: 0.435618
# [215]	valid_0's binary_logloss: 0.434974
# [216]	valid_0's binary_logloss: 0.434278
# [217]	valid_0's binary_logloss: 0.433091
# [218]	valid_0's binary_logloss: 0.432368
# [219]	valid_0's binary_logloss: 0.431697
# [220]	valid_0's binary_logloss: 0.431087
# [221]	valid_0's binary_logloss: 0.430351
# [222]	valid_0's binary_logloss: 0.429647
# [223]	valid_0's binary_logloss: 0.428683
# [224]	valid_0's binary_logloss: 0.427928
# [225]	valid_0's binary_logloss: 0.427254
# [226]	valid_0's binary_logloss: 0.426647
# [227]	valid_0's binary_logloss: 0.42585
# [228]	valid_0's binary_logloss: 0.425219
# [229]	valid_0's binary_logloss: 0.42442
# [230]	valid_0's binary_logloss: 0.423752
# [231]	valid_0's binary_logloss: 0.422828
# [232]	valid_0's binary_logloss: 0.422146
# [233]	valid_0's binary_logloss: 0.421454
# [234]	valid_0's binary_logloss: 0.420611
# [235]	valid_0's binary_logloss: 0.419877
# [236]	valid_0's binary_logloss: 0.419201
# [237]	valid_0's binary_logloss: 0.418301
# [238]	valid_0's binary_logloss: 0.417587
# [239]	valid_0's binary_logloss: 0.416861
# Did not meet early stopping. Best iteration is:
# [239]	valid_0's binary_logloss: 0.416861
# [1]	valid_0's binary_logloss: 0.686824
# Training until validation scores don't improve for 5 rounds.
# [2]	valid_0's binary_logloss: 0.68201
# [3]	valid_0's binary_logloss: 0.677994
# [4]	valid_0's binary_logloss: 0.67454
# [5]	valid_0's binary_logloss: 0.67145
# [6]	valid_0's binary_logloss: 0.66882
# [7]	valid_0's binary_logloss: 0.666254
# [8]	valid_0's binary_logloss: 0.663904
# [9]	valid_0's binary_logloss: 0.661691
# [10]	valid_0's binary_logloss: 0.659463
# [11]	valid_0's binary_logloss: 0.657485
# [12]	valid_0's binary_logloss: 0.655351
# [13]	valid_0's binary_logloss: 0.653019
# [14]	valid_0's binary_logloss: 0.651083
# [15]	valid_0's binary_logloss: 0.649212
# [16]	valid_0's binary_logloss: 0.647254
# [17]	valid_0's binary_logloss: 0.645595
# [18]	valid_0's binary_logloss: 0.643979
# [19]	valid_0's binary_logloss: 0.642079
# [20]	valid_0's binary_logloss: 0.640085
# [21]	valid_0's binary_logloss: 0.637421
# [22]	valid_0's binary_logloss: 0.635907
# [23]	valid_0's binary_logloss: 0.634421
# [24]	valid_0's binary_logloss: 0.632909
# [25]	valid_0's binary_logloss: 0.630311
# [26]	valid_0's binary_logloss: 0.628879
# [27]	valid_0's binary_logloss: 0.627371
# [28]	valid_0's binary_logloss: 0.624915
# [29]	valid_0's binary_logloss: 0.622873
# [30]	valid_0's binary_logloss: 0.621581
# [31]	valid_0's binary_logloss: 0.619258
# [32]	valid_0's binary_logloss: 0.61804
# [33]	valid_0's binary_logloss: 0.615973
# [34]	valid_0's binary_logloss: 0.61458
# [35]	valid_0's binary_logloss: 0.613061
# [36]	valid_0's binary_logloss: 0.611503
# [37]	valid_0's binary_logloss: 0.609791
# [38]	valid_0's binary_logloss: 0.608641
# [39]	valid_0's binary_logloss: 0.607019
# [40]	valid_0's binary_logloss: 0.605779
# [41]	valid_0's binary_logloss: 0.60454
# [42]	valid_0's binary_logloss: 0.603436
# [43]	valid_0's binary_logloss: 0.601896
# [44]	valid_0's binary_logloss: 0.600296
# [45]	valid_0's binary_logloss: 0.5992
# [46]	valid_0's binary_logloss: 0.597841
# [47]	valid_0's binary_logloss: 0.595747
# [48]	valid_0's binary_logloss: 0.594538
# [49]	valid_0's binary_logloss: 0.593438
# [50]	valid_0's binary_logloss: 0.591599
# [51]	valid_0's binary_logloss: 0.590472
# [52]	valid_0's binary_logloss: 0.589039
# [53]	valid_0's binary_logloss: 0.587974
# [54]	valid_0's binary_logloss: 0.586095
# [55]	valid_0's binary_logloss: 0.58494
# [56]	valid_0's binary_logloss: 0.583695
# [57]	valid_0's binary_logloss: 0.582658
# [58]	valid_0's binary_logloss: 0.580992
# [59]	valid_0's binary_logloss: 0.580007
# [60]	valid_0's binary_logloss: 0.578561
# [61]	valid_0's binary_logloss: 0.577381
# [62]	valid_0's binary_logloss: 0.575839
# [63]	valid_0's binary_logloss: 0.5746
# [64]	valid_0's binary_logloss: 0.573372
# [65]	valid_0's binary_logloss: 0.572403
# [66]	valid_0's binary_logloss: 0.571018
# [67]	valid_0's binary_logloss: 0.569788
# [68]	valid_0's binary_logloss: 0.568242
# [69]	valid_0's binary_logloss: 0.567099
# [70]	valid_0's binary_logloss: 0.566086
# [71]	valid_0's binary_logloss: 0.564426
# [72]	valid_0's binary_logloss: 0.563341
# [73]	valid_0's binary_logloss: 0.562155
# [74]	valid_0's binary_logloss: 0.560325
# [75]	valid_0's binary_logloss: 0.559364
# [76]	valid_0's binary_logloss: 0.558069
# [77]	valid_0's binary_logloss: 0.557084
# [78]	valid_0's binary_logloss: 0.555948
# [79]	valid_0's binary_logloss: 0.554503
# [80]	valid_0's binary_logloss: 0.553533
# [81]	valid_0's binary_logloss: 0.552514
# [82]	valid_0's binary_logloss: 0.55157
# [83]	valid_0's binary_logloss: 0.550251
# [84]	valid_0's binary_logloss: 0.549247
# [85]	valid_0's binary_logloss: 0.547759
# [86]	valid_0's binary_logloss: 0.54667
# [87]	valid_0's binary_logloss: 0.545673
# [88]	valid_0's binary_logloss: 0.544478
# [89]	valid_0's binary_logloss: 0.54341
# [90]	valid_0's binary_logloss: 0.542501
# [91]	valid_0's binary_logloss: 0.540991
# [92]	valid_0's binary_logloss: 0.540073
# [93]	valid_0's binary_logloss: 0.538829
# [94]	valid_0's binary_logloss: 0.537885
# [95]	valid_0's binary_logloss: 0.536837
# [96]	valid_0's binary_logloss: 0.535532
# [97]	valid_0's binary_logloss: 0.534284
# [98]	valid_0's binary_logloss: 0.533369
# [99]	valid_0's binary_logloss: 0.532387
# [100]	valid_0's binary_logloss: 0.53136
# [101]	valid_0's binary_logloss: 0.530359
# [102]	valid_0's binary_logloss: 0.529014
# [103]	valid_0's binary_logloss: 0.528113
# [104]	valid_0's binary_logloss: 0.526656
# [105]	valid_0's binary_logloss: 0.525719
# [106]	valid_0's binary_logloss: 0.524498
# [107]	valid_0's binary_logloss: 0.523588
# [108]	valid_0's binary_logloss: 0.522584
# [109]	valid_0's binary_logloss: 0.521725
# [110]	valid_0's binary_logloss: 0.520435
# [111]	valid_0's binary_logloss: 0.51956
# [112]	valid_0's binary_logloss: 0.518401
# [113]	valid_0's binary_logloss: 0.517514
# [114]	valid_0's binary_logloss: 0.516706
# [115]	valid_0's binary_logloss: 0.515188
# [116]	valid_0's binary_logloss: 0.514249
# [117]	valid_0's binary_logloss: 0.5133
# [118]	valid_0's binary_logloss: 0.512427
# [119]	valid_0's binary_logloss: 0.51111
# [120]	valid_0's binary_logloss: 0.5101
# [121]	valid_0's binary_logloss: 0.509282
# [122]	valid_0's binary_logloss: 0.50826
# [123]	valid_0's binary_logloss: 0.507277
# [124]	valid_0's binary_logloss: 0.5064
# [125]	valid_0's binary_logloss: 0.505366
# [126]	valid_0's binary_logloss: 0.504387
# [127]	valid_0's binary_logloss: 0.503485
# [128]	valid_0's binary_logloss: 0.502422
# [129]	valid_0's binary_logloss: 0.501239
# [130]	valid_0's binary_logloss: 0.500367
# [131]	valid_0's binary_logloss: 0.499539
# [132]	valid_0's binary_logloss: 0.497838
# [133]	valid_0's binary_logloss: 0.497008
# [134]	valid_0's binary_logloss: 0.496094
# [135]	valid_0's binary_logloss: 0.49478
# [136]	valid_0's binary_logloss: 0.493965
# [137]	valid_0's binary_logloss: 0.492604
# [138]	valid_0's binary_logloss: 0.491792
# [139]	valid_0's binary_logloss: 0.490859
# [140]	valid_0's binary_logloss: 0.490015
# [141]	valid_0's binary_logloss: 0.489223
# [142]	valid_0's binary_logloss: 0.48842
# [143]	valid_0's binary_logloss: 0.487359
# [144]	valid_0's binary_logloss: 0.486337
# [145]	valid_0's binary_logloss: 0.485554
# [146]	valid_0's binary_logloss: 0.484659
# [147]	valid_0's binary_logloss: 0.483826
# [148]	valid_0's binary_logloss: 0.482662
# [149]	valid_0's binary_logloss: 0.481778
# [150]	valid_0's binary_logloss: 0.480679
# [151]	valid_0's binary_logloss: 0.479672
# [152]	valid_0's binary_logloss: 0.478864
# [153]	valid_0's binary_logloss: 0.47804
# [154]	valid_0's binary_logloss: 0.477077
# [155]	valid_0's binary_logloss: 0.476254
# [156]	valid_0's binary_logloss: 0.475323
# [157]	valid_0's binary_logloss: 0.474476
# [158]	valid_0's binary_logloss: 0.473697
# [159]	valid_0's binary_logloss: 0.472945
# [160]	valid_0's binary_logloss: 0.472047
# [161]	valid_0's binary_logloss: 0.471092
# [162]	valid_0's binary_logloss: 0.470317
# [163]	valid_0's binary_logloss: 0.469418
# [164]	valid_0's binary_logloss: 0.468515
# [165]	valid_0's binary_logloss: 0.467672
# [166]	valid_0's binary_logloss: 0.466775
# [167]	valid_0's binary_logloss: 0.465748
# [168]	valid_0's binary_logloss: 0.464815
# [169]	valid_0's binary_logloss: 0.464105
# [170]	valid_0's binary_logloss: 0.463353
# [171]	valid_0's binary_logloss: 0.462519
# [172]	valid_0's binary_logloss: 0.461719
# Did not meet early stopping. Best iteration is:
# [172]	valid_0's binary_logloss: 0.461719
# [1]	valid_0's binary_logloss: 0.686769
# Training until validation scores don't improve for 5 rounds.
# [2]	valid_0's binary_logloss: 0.681962
# [3]	valid_0's binary_logloss: 0.677973
# [4]	valid_0's binary_logloss: 0.674553
# [5]	valid_0's binary_logloss: 0.671679
# [6]	valid_0's binary_logloss: 0.669038
# [7]	valid_0's binary_logloss: 0.666435
# [8]	valid_0's binary_logloss: 0.664255
# [9]	valid_0's binary_logloss: 0.662049
# [10]	valid_0's binary_logloss: 0.660061
# [11]	valid_0's binary_logloss: 0.657852
# [12]	valid_0's binary_logloss: 0.655755
# [13]	valid_0's binary_logloss: 0.653422
# [14]	valid_0's binary_logloss: 0.651052
# [15]	valid_0's binary_logloss: 0.64933
# [16]	valid_0's binary_logloss: 0.647264
# [17]	valid_0's binary_logloss: 0.645248
# [18]	valid_0's binary_logloss: 0.64288
# [19]	valid_0's binary_logloss: 0.641079
# [20]	valid_0's binary_logloss: 0.638444
# [21]	valid_0's binary_logloss: 0.636895
# [22]	valid_0's binary_logloss: 0.635329
# [23]	valid_0's binary_logloss: 0.633321
# [24]	valid_0's binary_logloss: 0.630958
# [25]	valid_0's binary_logloss: 0.62956
# [26]	valid_0's binary_logloss: 0.628092
# [27]	valid_0's binary_logloss: 0.625825
# [28]	valid_0's binary_logloss: 0.623703
# [29]	valid_0's binary_logloss: 0.622317
# [30]	valid_0's binary_logloss: 0.620861
# [31]	valid_0's binary_logloss: 0.61926
# [32]	valid_0's binary_logloss: 0.617848
# [33]	valid_0's binary_logloss: 0.616349
# [34]	valid_0's binary_logloss: 0.615263
# [35]	valid_0's binary_logloss: 0.614026
# [36]	valid_0's binary_logloss: 0.612728
# [37]	valid_0's binary_logloss: 0.611253
# [38]	valid_0's binary_logloss: 0.609123
# [39]	valid_0's binary_logloss: 0.608002
# [40]	valid_0's binary_logloss: 0.606581
# [41]	valid_0's binary_logloss: 0.605329
# [42]	valid_0's binary_logloss: 0.60384
# [43]	valid_0's binary_logloss: 0.602706
# [44]	valid_0's binary_logloss: 0.60056
# [45]	valid_0's binary_logloss: 0.599452
# [46]	valid_0's binary_logloss: 0.597822
# [47]	valid_0's binary_logloss: 0.596743
# [48]	valid_0's binary_logloss: 0.595137
# [49]	valid_0's binary_logloss: 0.593931
# [50]	valid_0's binary_logloss: 0.592743
# [51]	valid_0's binary_logloss: 0.591718
# [52]	valid_0's binary_logloss: 0.590424
# [53]	valid_0's binary_logloss: 0.589176
# [54]	valid_0's binary_logloss: 0.586789
# [55]	valid_0's binary_logloss: 0.585678
# [56]	valid_0's binary_logloss: 0.584524
# [57]	valid_0's binary_logloss: 0.583424
# [58]	valid_0's binary_logloss: 0.581991
# [59]	valid_0's binary_logloss: 0.580634
# [60]	valid_0's binary_logloss: 0.57948
# [61]	valid_0's binary_logloss: 0.57772
# [62]	valid_0's binary_logloss: 0.576675
# [63]	valid_0's binary_logloss: 0.574969
# [64]	valid_0's binary_logloss: 0.573667
# [65]	valid_0's binary_logloss: 0.572683
# [66]	valid_0's binary_logloss: 0.571625
# [67]	valid_0's binary_logloss: 0.57049
# [68]	valid_0's binary_logloss: 0.56856
# [69]	valid_0's binary_logloss: 0.56752
# [70]	valid_0's binary_logloss: 0.566543
# [71]	valid_0's binary_logloss: 0.565087
# [72]	valid_0's binary_logloss: 0.563909
# [73]	valid_0's binary_logloss: 0.562885
# [74]	valid_0's binary_logloss: 0.561671
# [75]	valid_0's binary_logloss: 0.560727
# [76]	valid_0's binary_logloss: 0.559769
# [77]	valid_0's binary_logloss: 0.558369
# [78]	valid_0's binary_logloss: 0.557336
# [79]	valid_0's binary_logloss: 0.556115
# [80]	valid_0's binary_logloss: 0.55466
# [81]	valid_0's binary_logloss: 0.553632
# [82]	valid_0's binary_logloss: 0.552369
# [83]	valid_0's binary_logloss: 0.551263
# [84]	valid_0's binary_logloss: 0.55
# [85]	valid_0's binary_logloss: 0.549121
# [86]	valid_0's binary_logloss: 0.548187
# [87]	valid_0's binary_logloss: 0.547148
# [88]	valid_0's binary_logloss: 0.54562
# [89]	valid_0's binary_logloss: 0.544647
# [90]	valid_0's binary_logloss: 0.543141
# [91]	valid_0's binary_logloss: 0.542194
# [92]	valid_0's binary_logloss: 0.540986
# [93]	valid_0's binary_logloss: 0.540058
# [94]	valid_0's binary_logloss: 0.538996
# [95]	valid_0's binary_logloss: 0.537989
# [96]	valid_0's binary_logloss: 0.536936
# [97]	valid_0's binary_logloss: 0.535969
# [98]	valid_0's binary_logloss: 0.535019
# [99]	valid_0's binary_logloss: 0.534108
# [100]	valid_0's binary_logloss: 0.532732
# [101]	valid_0's binary_logloss: 0.531677
# [102]	valid_0's binary_logloss: 0.530801
# [103]	valid_0's binary_logloss: 0.529663
# [104]	valid_0's binary_logloss: 0.528748
# [105]	valid_0's binary_logloss: 0.527617
# [106]	valid_0's binary_logloss: 0.52671
# [107]	valid_0's binary_logloss: 0.525586
# [108]	valid_0's binary_logloss: 0.52427
# [109]	valid_0's binary_logloss: 0.523324
# [110]	valid_0's binary_logloss: 0.52184
# [111]	valid_0's binary_logloss: 0.520921
# [112]	valid_0's binary_logloss: 0.519562
# [113]	valid_0's binary_logloss: 0.518342
# [114]	valid_0's binary_logloss: 0.517293
# [115]	valid_0's binary_logloss: 0.516448
# [116]	valid_0's binary_logloss: 0.514996
# [117]	valid_0's binary_logloss: 0.514096
# [118]	valid_0's binary_logloss: 0.512931
# [119]	valid_0's binary_logloss: 0.512086
# [120]	valid_0's binary_logloss: 0.510777
# [121]	valid_0's binary_logloss: 0.509948
# [122]	valid_0's binary_logloss: 0.509009
# [123]	valid_0's binary_logloss: 0.507916
# [124]	valid_0's binary_logloss: 0.50702
# [125]	valid_0's binary_logloss: 0.50614
# [126]	valid_0's binary_logloss: 0.505276
# [127]	valid_0's binary_logloss: 0.503951
# [128]	valid_0's binary_logloss: 0.503099
# [129]	valid_0's binary_logloss: 0.502259
# [130]	valid_0's binary_logloss: 0.501278
# [131]	valid_0's binary_logloss: 0.500422
# [132]	valid_0's binary_logloss: 0.499562
# [133]	valid_0's binary_logloss: 0.498802
# [134]	valid_0's binary_logloss: 0.497828
# [135]	valid_0's binary_logloss: 0.497011
# [136]	valid_0's binary_logloss: 0.496218
# [137]	valid_0's binary_logloss: 0.495297
# [138]	valid_0's binary_logloss: 0.494024
# [139]	valid_0's binary_logloss: 0.493123
# [140]	valid_0's binary_logloss: 0.491846
# [141]	valid_0's binary_logloss: 0.491072
# [142]	valid_0's binary_logloss: 0.490218
# [143]	valid_0's binary_logloss: 0.489342
# [144]	valid_0's binary_logloss: 0.488327
# [145]	valid_0's binary_logloss: 0.487381
# [146]	valid_0's binary_logloss: 0.486505
# [147]	valid_0's binary_logloss: 0.48539
# [148]	valid_0's binary_logloss: 0.484512
# [149]	valid_0's binary_logloss: 0.483406
# [150]	valid_0's binary_logloss: 0.482468
# [151]	valid_0's binary_logloss: 0.481693
# [152]	valid_0's binary_logloss: 0.480606
# [153]	valid_0's binary_logloss: 0.479652
# [154]	valid_0's binary_logloss: 0.478881
# [155]	valid_0's binary_logloss: 0.478082
# [156]	valid_0's binary_logloss: 0.477004
# [157]	valid_0's binary_logloss: 0.476253
# [158]	valid_0's binary_logloss: 0.475367
# [159]	valid_0's binary_logloss: 0.474007
# [160]	valid_0's binary_logloss: 0.473178
# Did not meet early stopping. Best iteration is:
# [160]	valid_0's binary_logloss: 0.473178
# [1]	valid_0's binary_logloss: 0.686891
# Training until validation scores don't improve for 5 rounds.
# [2]	valid_0's binary_logloss: 0.682133
# [3]	valid_0's binary_logloss: 0.678166
# [4]	valid_0's binary_logloss: 0.674809
# [5]	valid_0's binary_logloss: 0.671936
# [6]	valid_0's binary_logloss: 0.669292
# [7]	valid_0's binary_logloss: 0.666803
# [8]	valid_0's binary_logloss: 0.664546
# [9]	valid_0's binary_logloss: 0.662174
# [10]	valid_0's binary_logloss: 0.660089
# [11]	valid_0's binary_logloss: 0.657979
# [12]	valid_0's binary_logloss: 0.655916
# [13]	valid_0's binary_logloss: 0.653695
# [14]	valid_0's binary_logloss: 0.651811
# [15]	valid_0's binary_logloss: 0.649824
# [16]	valid_0's binary_logloss: 0.647372
# [17]	valid_0's binary_logloss: 0.645394
# [18]	valid_0's binary_logloss: 0.643562
# [19]	valid_0's binary_logloss: 0.641748
# [20]	valid_0's binary_logloss: 0.640184
# [21]	valid_0's binary_logloss: 0.638092
# [22]	valid_0's binary_logloss: 0.635784
# [23]	valid_0's binary_logloss: 0.634313
# [24]	valid_0's binary_logloss: 0.631787
# [25]	valid_0's binary_logloss: 0.630326
# [26]	valid_0's binary_logloss: 0.628915
# [27]	valid_0's binary_logloss: 0.626859
# [28]	valid_0's binary_logloss: 0.625645
# [29]	valid_0's binary_logloss: 0.624071
# [30]	valid_0's binary_logloss: 0.621836
# [31]	valid_0's binary_logloss: 0.620529
# [32]	valid_0's binary_logloss: 0.619241
# [33]	valid_0's binary_logloss: 0.617765
# [34]	valid_0's binary_logloss: 0.616527
# [35]	valid_0's binary_logloss: 0.615427
# [36]	valid_0's binary_logloss: 0.613186
# [37]	valid_0's binary_logloss: 0.611925
# [38]	valid_0's binary_logloss: 0.610374
# [39]	valid_0's binary_logloss: 0.609267
# [40]	valid_0's binary_logloss: 0.607212
# [41]	valid_0's binary_logloss: 0.606002
# [42]	valid_0's binary_logloss: 0.604647
# [43]	valid_0's binary_logloss: 0.603551
# [44]	valid_0's binary_logloss: 0.602209
# [45]	valid_0's binary_logloss: 0.601097
# [46]	valid_0's binary_logloss: 0.599973
# [47]	valid_0's binary_logloss: 0.598631
# [48]	valid_0's binary_logloss: 0.597387
# [49]	valid_0's binary_logloss: 0.595565
# [50]	valid_0's binary_logloss: 0.594176
# [51]	valid_0's binary_logloss: 0.592876
# [52]	valid_0's binary_logloss: 0.591447
# [53]	valid_0's binary_logloss: 0.590162
# [54]	valid_0's binary_logloss: 0.589137
# [55]	valid_0's binary_logloss: 0.58801
# [56]	valid_0's binary_logloss: 0.586993
# [57]	valid_0's binary_logloss: 0.58514
# [58]	valid_0's binary_logloss: 0.583965
# [59]	valid_0's binary_logloss: 0.58271
# [60]	valid_0's binary_logloss: 0.580943
# [61]	valid_0's binary_logloss: 0.579877
# [62]	valid_0's binary_logloss: 0.578745
# [63]	valid_0's binary_logloss: 0.577803
# [64]	valid_0's binary_logloss: 0.5764
# [65]	valid_0's binary_logloss: 0.574944
# [66]	valid_0's binary_logloss: 0.573823
# [67]	valid_0's binary_logloss: 0.572423
# [68]	valid_0's binary_logloss: 0.57123
# [69]	valid_0's binary_logloss: 0.570212
# [70]	valid_0's binary_logloss: 0.569089
# [71]	valid_0's binary_logloss: 0.567497
# [72]	valid_0's binary_logloss: 0.565784
# [73]	valid_0's binary_logloss: 0.564769
# [74]	valid_0's binary_logloss: 0.563735
# [75]	valid_0's binary_logloss: 0.562613
# [76]	valid_0's binary_logloss: 0.561666
# [77]	valid_0's binary_logloss: 0.560277
# [78]	valid_0's binary_logloss: 0.558994
# [79]	valid_0's binary_logloss: 0.558058
# [80]	valid_0's binary_logloss: 0.557034
# [81]	valid_0's binary_logloss: 0.55575
# [82]	valid_0's binary_logloss: 0.55469
# [83]	valid_0's binary_logloss: 0.553637
# [84]	valid_0's binary_logloss: 0.552512
# [85]	valid_0's binary_logloss: 0.551539
# [86]	valid_0's binary_logloss: 0.55052
# [87]	valid_0's binary_logloss: 0.549416
# [88]	valid_0's binary_logloss: 0.548469
# [89]	valid_0's binary_logloss: 0.547381
# [90]	valid_0's binary_logloss: 0.546287
# [91]	valid_0's binary_logloss: 0.544439
# [92]	valid_0's binary_logloss: 0.54343
# [93]	valid_0's binary_logloss: 0.542438
# [94]	valid_0's binary_logloss: 0.541315
# [95]	valid_0's binary_logloss: 0.540431
# [96]	valid_0's binary_logloss: 0.539496
# [97]	valid_0's binary_logloss: 0.53833
# [98]	valid_0's binary_logloss: 0.537313
# [99]	valid_0's binary_logloss: 0.536338
# [100]	valid_0's binary_logloss: 0.535387
# [101]	valid_0's binary_logloss: 0.534198
# [102]	valid_0's binary_logloss: 0.532906
# [103]	valid_0's binary_logloss: 0.531946
# [104]	valid_0's binary_logloss: 0.531079
# [105]	valid_0's binary_logloss: 0.530149
# [106]	valid_0's binary_logloss: 0.528975
# [107]	valid_0's binary_logloss: 0.528024
# [108]	valid_0's binary_logloss: 0.527094
# [109]	valid_0's binary_logloss: 0.526293
# [110]	valid_0's binary_logloss: 0.525252
# [111]	valid_0's binary_logloss: 0.523577
# [112]	valid_0's binary_logloss: 0.522756
# [113]	valid_0's binary_logloss: 0.521894
# [114]	valid_0's binary_logloss: 0.520957
# [115]	valid_0's binary_logloss: 0.520112
# [116]	valid_0's binary_logloss: 0.519282
# [117]	valid_0's binary_logloss: 0.518389
# [118]	valid_0's binary_logloss: 0.517464
# [119]	valid_0's binary_logloss: 0.51609
# [120]	valid_0's binary_logloss: 0.514939
# [121]	valid_0's binary_logloss: 0.514034
# [122]	valid_0's binary_logloss: 0.512667
# [123]	valid_0's binary_logloss: 0.511709
# [124]	valid_0's binary_logloss: 0.510641
# [125]	valid_0's binary_logloss: 0.509814
# [126]	valid_0's binary_logloss: 0.508965
# [127]	valid_0's binary_logloss: 0.507817
# [128]	valid_0's binary_logloss: 0.506971
# [129]	valid_0's binary_logloss: 0.506105
# [130]	valid_0's binary_logloss: 0.505256
# [131]	valid_0's binary_logloss: 0.504127
# [132]	valid_0's binary_logloss: 0.502898
# [133]	valid_0's binary_logloss: 0.50204
# [134]	valid_0's binary_logloss: 0.500949
# [135]	valid_0's binary_logloss: 0.500097
# [136]	valid_0's binary_logloss: 0.499119
# [137]	valid_0's binary_logloss: 0.498205
# [138]	valid_0's binary_logloss: 0.497103
# [139]	valid_0's binary_logloss: 0.496005
# [140]	valid_0's binary_logloss: 0.495108
# [141]	valid_0's binary_logloss: 0.494289
# [142]	valid_0's binary_logloss: 0.493202
# [143]	valid_0's binary_logloss: 0.492356
# [144]	valid_0's binary_logloss: 0.491491
# [145]	valid_0's binary_logloss: 0.490672
# [146]	valid_0's binary_logloss: 0.489773
# [147]	valid_0's binary_logloss: 0.488876
# [148]	valid_0's binary_logloss: 0.488114
# [149]	valid_0's binary_logloss: 0.487222
# [150]	valid_0's binary_logloss: 0.486431
# Did not meet early stopping. Best iteration is:
# [150]	valid_0's binary_logloss: 0.486431
# [1]	valid_0's binary_logloss: 0.686816
# Training until validation scores don't improve for 5 rounds.
# [2]	valid_0's binary_logloss: 0.681983
# [3]	valid_0's binary_logloss: 0.677964
# [4]	valid_0's binary_logloss: 0.674533
# [5]	valid_0's binary_logloss: 0.671582
# [6]	valid_0's binary_logloss: 0.668923
# [7]	valid_0's binary_logloss: 0.666463
# [8]	valid_0's binary_logloss: 0.664137
# [9]	valid_0's binary_logloss: 0.66189
# [10]	valid_0's binary_logloss: 0.659762
# [11]	valid_0's binary_logloss: 0.657494
# [12]	valid_0's binary_logloss: 0.655466
# [13]	valid_0's binary_logloss: 0.65322
# [14]	valid_0's binary_logloss: 0.651312
# [15]	valid_0's binary_logloss: 0.649345
# [16]	valid_0's binary_logloss: 0.646935
# [17]	valid_0's binary_logloss: 0.644751
# [18]	valid_0's binary_logloss: 0.642688
# [19]	valid_0's binary_logloss: 0.640879
# [20]	valid_0's binary_logloss: 0.638809
# [21]	valid_0's binary_logloss: 0.636372
# [22]	valid_0's binary_logloss: 0.634835
# [23]	valid_0's binary_logloss: 0.632246
# [24]	valid_0's binary_logloss: 0.630737
# [25]	valid_0's binary_logloss: 0.629227
# [26]	valid_0's binary_logloss: 0.62644
# [27]	valid_0's binary_logloss: 0.625045
# [28]	valid_0's binary_logloss: 0.623618
# [29]	valid_0's binary_logloss: 0.621228
# [30]	valid_0's binary_logloss: 0.619836
# [31]	valid_0's binary_logloss: 0.618363
# [32]	valid_0's binary_logloss: 0.616903
# [33]	valid_0's binary_logloss: 0.615586
# [34]	valid_0's binary_logloss: 0.614177
# [35]	valid_0's binary_logloss: 0.612576
# [36]	valid_0's binary_logloss: 0.61045
# [37]	valid_0's binary_logloss: 0.609157
# [38]	valid_0's binary_logloss: 0.607778
# [39]	valid_0's binary_logloss: 0.606395
# [40]	valid_0's binary_logloss: 0.605157
# [41]	valid_0's binary_logloss: 0.603906
# [42]	valid_0's binary_logloss: 0.602432
# [43]	valid_0's binary_logloss: 0.600518
# [44]	valid_0's binary_logloss: 0.599341
# [45]	valid_0's binary_logloss: 0.598159
# [46]	valid_0's binary_logloss: 0.596078
# [47]	valid_0's binary_logloss: 0.594888
# [48]	valid_0's binary_logloss: 0.593662
# [49]	valid_0's binary_logloss: 0.592228
# [50]	valid_0's binary_logloss: 0.59108
# [51]	valid_0's binary_logloss: 0.589794
# [52]	valid_0's binary_logloss: 0.587655
# [53]	valid_0's binary_logloss: 0.586591
# [54]	valid_0's binary_logloss: 0.585549
# [55]	valid_0's binary_logloss: 0.583746
# [56]	valid_0's binary_logloss: 0.582551
# [57]	valid_0's binary_logloss: 0.581235
# [58]	valid_0's binary_logloss: 0.579989
# [59]	valid_0's binary_logloss: 0.578261
# [60]	valid_0's binary_logloss: 0.577197
# [61]	valid_0's binary_logloss: 0.575395
# [62]	valid_0's binary_logloss: 0.574299
# [63]	valid_0's binary_logloss: 0.572685
# [64]	valid_0's binary_logloss: 0.571487
# [65]	valid_0's binary_logloss: 0.570222
# [66]	valid_0's binary_logloss: 0.569153
# [67]	valid_0's binary_logloss: 0.568011
# [68]	valid_0's binary_logloss: 0.566907
# [69]	valid_0's binary_logloss: 0.565427
# [70]	valid_0's binary_logloss: 0.563909
# [71]	valid_0's binary_logloss: 0.562918
# [72]	valid_0's binary_logloss: 0.56131
# [73]	valid_0's binary_logloss: 0.560323
# [74]	valid_0's binary_logloss: 0.559333
# [75]	valid_0's binary_logloss: 0.557926
# [76]	valid_0's binary_logloss: 0.556915
# [77]	valid_0's binary_logloss: 0.555337
# [78]	valid_0's binary_logloss: 0.554153
# [79]	valid_0's binary_logloss: 0.552554
# [80]	valid_0's binary_logloss: 0.551533
# [81]	valid_0's binary_logloss: 0.550396
# [82]	valid_0's binary_logloss: 0.549398
# [83]	valid_0's binary_logloss: 0.548412
# [84]	valid_0's binary_logloss: 0.546797
# [85]	valid_0's binary_logloss: 0.545783
# [86]	valid_0's binary_logloss: 0.544355
# [87]	valid_0's binary_logloss: 0.543331
# [88]	valid_0's binary_logloss: 0.542203
# [89]	valid_0's binary_logloss: 0.541197
# [90]	valid_0's binary_logloss: 0.540147
# [91]	valid_0's binary_logloss: 0.538577
# [92]	valid_0's binary_logloss: 0.537628
# [93]	valid_0's binary_logloss: 0.536509
# [94]	valid_0's binary_logloss: 0.535547
# [95]	valid_0's binary_logloss: 0.534437
# [96]	valid_0's binary_logloss: 0.533342
# [97]	valid_0's binary_logloss: 0.531965
# [98]	valid_0's binary_logloss: 0.531048
# [99]	valid_0's binary_logloss: 0.529772
# [100]	valid_0's binary_logloss: 0.528844
# [101]	valid_0's binary_logloss: 0.527679
# [102]	valid_0's binary_logloss: 0.526626
# [103]	valid_0's binary_logloss: 0.525329
# [104]	valid_0's binary_logloss: 0.524367
# [105]	valid_0's binary_logloss: 0.523498
# [106]	valid_0's binary_logloss: 0.522243
# [107]	valid_0's binary_logloss: 0.521338
# [108]	valid_0's binary_logloss: 0.520289
# [109]	valid_0's binary_logloss: 0.519425
# [110]	valid_0's binary_logloss: 0.518518
# [111]	valid_0's binary_logloss: 0.517447
# [112]	valid_0's binary_logloss: 0.516507
# [113]	valid_0's binary_logloss: 0.515559
# [114]	valid_0's binary_logloss: 0.514449
# [115]	valid_0's binary_logloss: 0.513432
# [116]	valid_0's binary_logloss: 0.512562
# [117]	valid_0's binary_logloss: 0.511292
# [118]	valid_0's binary_logloss: 0.509655
# [119]	valid_0's binary_logloss: 0.50868
# [120]	valid_0's binary_logloss: 0.507756
# [121]	valid_0's binary_logloss: 0.506631
# [122]	valid_0's binary_logloss: 0.505781
# [123]	valid_0's binary_logloss: 0.504598
# [124]	valid_0's binary_logloss: 0.503635
# [125]	valid_0's binary_logloss: 0.50255
# [126]	valid_0's binary_logloss: 0.501727
# [127]	valid_0's binary_logloss: 0.500565
# [128]	valid_0's binary_logloss: 0.499749
# [129]	valid_0's binary_logloss: 0.498761
# [130]	valid_0's binary_logloss: 0.497676
# [131]	valid_0's binary_logloss: 0.496837
# [132]	valid_0's binary_logloss: 0.495702
# [133]	valid_0's binary_logloss: 0.494588
# [134]	valid_0's binary_logloss: 0.493494
# [135]	valid_0's binary_logloss: 0.492715
# [136]	valid_0's binary_logloss: 0.491923
# [137]	valid_0's binary_logloss: 0.491055
# [138]	valid_0's binary_logloss: 0.490271
# [139]	valid_0's binary_logloss: 0.489476
# [140]	valid_0's binary_logloss: 0.48854
# Did not meet early stopping. Best iteration is:
# [140]	valid_0's binary_logloss: 0.48854
# [1]	valid_0's binary_logloss: 0.686777
# Training until validation scores don't improve for 10 rounds.
# [2]	valid_0's binary_logloss: 0.681915
# [3]	valid_0's binary_logloss: 0.67786
# [4]	valid_0's binary_logloss: 0.674364
# [5]	valid_0's binary_logloss: 0.671393
# [6]	valid_0's binary_logloss: 0.668627
# [7]	valid_0's binary_logloss: 0.666084
# [8]	valid_0's binary_logloss: 0.663772
# [9]	valid_0's binary_logloss: 0.661458
# [10]	valid_0's binary_logloss: 0.659323
# [11]	valid_0's binary_logloss: 0.657152
# [12]	valid_0's binary_logloss: 0.654894
# [13]	valid_0's binary_logloss: 0.652508
# [14]	valid_0's binary_logloss: 0.650474
# [15]	valid_0's binary_logloss: 0.64864
# [16]	valid_0's binary_logloss: 0.646646
# [17]	valid_0's binary_logloss: 0.643998
# [18]	valid_0's binary_logloss: 0.642029
# [19]	valid_0's binary_logloss: 0.639794
# [20]	valid_0's binary_logloss: 0.638107
# [21]	valid_0's binary_logloss: 0.636303
# [22]	valid_0's binary_logloss: 0.634846
# [23]	valid_0's binary_logloss: 0.632535
# [24]	valid_0's binary_logloss: 0.630986
# [25]	valid_0's binary_logloss: 0.628367
# [26]	valid_0's binary_logloss: 0.627107
# [27]	valid_0's binary_logloss: 0.625616
# [28]	valid_0's binary_logloss: 0.624055
# [29]	valid_0's binary_logloss: 0.621859
# [30]	valid_0's binary_logloss: 0.620398
# [31]	valid_0's binary_logloss: 0.617751
# [32]	valid_0's binary_logloss: 0.6159
# [33]	valid_0's binary_logloss: 0.614538
# [34]	valid_0's binary_logloss: 0.613139
# [35]	valid_0's binary_logloss: 0.610966
# [36]	valid_0's binary_logloss: 0.609266
# [37]	valid_0's binary_logloss: 0.607891
# [38]	valid_0's binary_logloss: 0.606339
# [39]	valid_0's binary_logloss: 0.604679
# [40]	valid_0's binary_logloss: 0.603295
# [41]	valid_0's binary_logloss: 0.602088
# [42]	valid_0's binary_logloss: 0.600022
# [43]	valid_0's binary_logloss: 0.598932
# [44]	valid_0's binary_logloss: 0.597732
# [45]	valid_0's binary_logloss: 0.596475
# [46]	valid_0's binary_logloss: 0.594892
# [47]	valid_0's binary_logloss: 0.593677
# [48]	valid_0's binary_logloss: 0.592431
# [49]	valid_0's binary_logloss: 0.591121
# [50]	valid_0's binary_logloss: 0.589628
# [51]	valid_0's binary_logloss: 0.588454
# [52]	valid_0's binary_logloss: 0.58715
# [53]	valid_0's binary_logloss: 0.586063
# [54]	valid_0's binary_logloss: 0.584762
# [55]	valid_0's binary_logloss: 0.582943
# [56]	valid_0's binary_logloss: 0.58178
# [57]	valid_0's binary_logloss: 0.58069
# [58]	valid_0's binary_logloss: 0.578997
# [59]	valid_0's binary_logloss: 0.5779
# [60]	valid_0's binary_logloss: 0.576534
# [61]	valid_0's binary_logloss: 0.575306
# [62]	valid_0's binary_logloss: 0.574119
# [63]	valid_0's binary_logloss: 0.572714
# [64]	valid_0's binary_logloss: 0.571631
# [65]	valid_0's binary_logloss: 0.569881
# [66]	valid_0's binary_logloss: 0.568638
# [67]	valid_0's binary_logloss: 0.567356
# [68]	valid_0's binary_logloss: 0.566076
# [69]	valid_0's binary_logloss: 0.564134
# [70]	valid_0's binary_logloss: 0.562872
# [71]	valid_0's binary_logloss: 0.56178
# [72]	valid_0's binary_logloss: 0.560493
# [73]	valid_0's binary_logloss: 0.55928
# [74]	valid_0's binary_logloss: 0.558295
# [75]	valid_0's binary_logloss: 0.557199
# [76]	valid_0's binary_logloss: 0.556161
# [77]	valid_0's binary_logloss: 0.555065
# [78]	valid_0's binary_logloss: 0.554041
# [79]	valid_0's binary_logloss: 0.552637
# [80]	valid_0's binary_logloss: 0.55169
# [81]	valid_0's binary_logloss: 0.550473
# [82]	valid_0's binary_logloss: 0.549464
# [83]	valid_0's binary_logloss: 0.548042
# [84]	valid_0's binary_logloss: 0.547057
# [85]	valid_0's binary_logloss: 0.545902
# [86]	valid_0's binary_logloss: 0.54492
# [87]	valid_0's binary_logloss: 0.543386
# [88]	valid_0's binary_logloss: 0.542376
# [89]	valid_0's binary_logloss: 0.54116
# [90]	valid_0's binary_logloss: 0.540088
# [91]	valid_0's binary_logloss: 0.538971
# [92]	valid_0's binary_logloss: 0.537399
# [93]	valid_0's binary_logloss: 0.536187
# [94]	valid_0's binary_logloss: 0.534938
# [95]	valid_0's binary_logloss: 0.53385
# [96]	valid_0's binary_logloss: 0.532891
# [97]	valid_0's binary_logloss: 0.531386
# [98]	valid_0's binary_logloss: 0.530406
# [99]	valid_0's binary_logloss: 0.528945
# [100]	valid_0's binary_logloss: 0.527942
# [101]	valid_0's binary_logloss: 0.527016
# [102]	valid_0's binary_logloss: 0.525932
# [103]	valid_0's binary_logloss: 0.524515
# [104]	valid_0's binary_logloss: 0.523593
# [105]	valid_0's binary_logloss: 0.522127
# [106]	valid_0's binary_logloss: 0.520939
# [107]	valid_0's binary_logloss: 0.520037
# [108]	valid_0's binary_logloss: 0.519121
# [109]	valid_0's binary_logloss: 0.518
# [110]	valid_0's binary_logloss: 0.51693
# [111]	valid_0's binary_logloss: 0.515691
# [112]	valid_0's binary_logloss: 0.514577
# [113]	valid_0's binary_logloss: 0.513084
# [114]	valid_0's binary_logloss: 0.512114
# [115]	valid_0's binary_logloss: 0.511173
# [116]	valid_0's binary_logloss: 0.510268
# [117]	valid_0's binary_logloss: 0.509277
# [118]	valid_0's binary_logloss: 0.508213
# [119]	valid_0's binary_logloss: 0.506908
# [120]	valid_0's binary_logloss: 0.50601
# [121]	valid_0's binary_logloss: 0.505102
# [122]	valid_0's binary_logloss: 0.504115
# [123]	valid_0's binary_logloss: 0.502664
# [124]	valid_0's binary_logloss: 0.501811
# [125]	valid_0's binary_logloss: 0.50089
# [126]	valid_0's binary_logloss: 0.500008
# [127]	valid_0's binary_logloss: 0.499119
# [128]	valid_0's binary_logloss: 0.498237
# [129]	valid_0's binary_logloss: 0.497349
# [130]	valid_0's binary_logloss: 0.49624
# [131]	valid_0's binary_logloss: 0.49514
# [132]	valid_0's binary_logloss: 0.493964
# [133]	valid_0's binary_logloss: 0.493066
# [134]	valid_0's binary_logloss: 0.492021
# [135]	valid_0's binary_logloss: 0.490921
# [136]	valid_0's binary_logloss: 0.490031
# [137]	valid_0's binary_logloss: 0.489183
# [138]	valid_0's binary_logloss: 0.488203
# [139]	valid_0's binary_logloss: 0.487369
# [140]	valid_0's binary_logloss: 0.486529
# [141]	valid_0's binary_logloss: 0.485568
# [142]	valid_0's binary_logloss: 0.484517
# [143]	valid_0's binary_logloss: 0.483502
# [144]	valid_0's binary_logloss: 0.482507
# [145]	valid_0's binary_logloss: 0.481616
# [146]	valid_0's binary_logloss: 0.480771
# [147]	valid_0's binary_logloss: 0.479751
# [148]	valid_0's binary_logloss: 0.478765
# [149]	valid_0's binary_logloss: 0.477941
# [150]	valid_0's binary_logloss: 0.477
# [151]	valid_0's binary_logloss: 0.476123
# [152]	valid_0's binary_logloss: 0.474917
# Did not meet early stopping. Best iteration is:
# [152]	valid_0's binary_logloss: 0.474917

# %%
models = [gbm_1, gbm_2, gbm_3, gbm_4, gbm_5, gbm_6]
import pickle as pk
pk.dump(models, open("../pickle/_ref_models.pkl","wb"))

# %%
import os
os.listdir('../pickle')
# Out:
# ['_ref_market_train_df.pkl']

# %%
#实现零均值归一化操作
confidence_test = (gbm_1.predict(X_test) + gbm_2.predict(X_test)+gbm_3.predict(X_test)+gbm_4.predict(X_test)+gbm_5.predict(X_test)+gbm_6.predict(X_test))/6
confidence_test = (confidence_test-confidence_test.min())/(confidence_test.max()-confidence_test.min())
#print("max_min",max_min)
#confidence_test=(confidence_test-confidence_test.mean())/(confidence_test.std())
confidence_test = confidence_test*2-1
print(max(confidence_test),min(confidence_test))

# calculation of actual metric that is used to calculate final score
r_test = r_test.clip(-1,1) # get rid of outliers. Where do they come from??
x_t_i = confidence_test * r_test * u_test
data = {'day' : d_test, 'x_t_i' : x_t_i}
df = pd.DataFrame(data)
x_t = df.groupby('day').sum().values.flatten()
mean = np.mean(x_t)
std = np.std(x_t)
score_test = mean / std
print(score_test)

# %%
import gc
del X_train,X_test
gc.collect()

# %%
#prediction
days = env.get_prediction_days()
n_days = 0
prep_time = 0
prediction_time = 0
packaging_time = 0
total_market_obs_df = []
for (market_obs_df, news_obs_df, predictions_template_df) in days:
    n_days +=1
    if (n_days%50==0):
        pass
        #print(n_days,end=' ')
    t = time.time()
    market_obs_df['time'] = market_obs_df['time'].dt.date
    
    return_features = ['returnsClosePrevMktres10','returnsClosePrevRaw10','open','close']
    total_market_obs_df.append(market_obs_df)
    if len(total_market_obs_df)==1:
        history_df = total_market_obs_df[0]
    else:
        history_df = pd.concat(total_market_obs_df[-(np.max(n_lag)+1):])
    new_df = generate_lag_features(history_df,n_lag=[3,7,14])
    market_obs_df = pd.merge(market_obs_df,new_df,how='left',on=['time','assetCode'])
    market_obs_df = mis_impute(market_obs_df)
    market_obs_df = data_prep(market_obs_df)
    
    X_live = market_obs_df[fcol].values
    X_live = 1 - ((maxs - X_live) / rng)
    prep_time += time.time() - t
    t = time.time()
    lp = (gbm_1.predict(X_live) + gbm_2.predict(X_live)+gbm_3.predict(X_live)+gbm_4.predict(X_live)+gbm_5.predict(X_live)+gbm_6.predict(X_live))/6
    prediction_time += time.time() -t
    t = time.time()
    confidence = lp
    confidence = (confidence-confidence.min())/(confidence.max()-confidence.min())
    #print("max_min_predict",max_min_predict)
    confidence = confidence * 2 - 1
    preds = pd.DataFrame({'assetCode':market_obs_df['assetCode'],'confidence':confidence})
    predictions_template_df = predictions_template_df.merge(preds,how='left').drop('confidenceValue',axis=1).fillna(0).rename(columns={'confidence':'confidenceValue'})
    env.predict(predictions_template_df)
    packaging_time += time.time() - t
    
env.write_submission_file()
sub  = pd.read_csv("submission_versionnew.csv")
