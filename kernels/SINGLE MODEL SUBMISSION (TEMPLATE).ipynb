# %% [markdown]
# <h1>Single model submission template.
#
# <p>every model to be used must satisfy the APIs requirements of model_template.py, and must pass all the tests like test_model_template.py

# %%
"""
This is a template for the APIs of models to be used into the stacking framework.
"""
from time import time, ctime
from sklearn.linear_model import LinearRegression
import pandas as pd

class model_example():
    """base class for the model

    this class is for a model (that can also be
    a combination of bagged models)
    The commonality of the bagged models is that
    they share the feature generation
    """

    def __init__(self, name):
        self.name  = name
        self.model = None
        self.type  = LinearRegression
        self.max_lag = 1 #max lagged values (needed for rolling predictions)
        print("\ninit model {}".format(self.name))

    def _generate_features(self, market_data, news_data, verbose=False):
        """
        given the original market_data and news_data
        generate new features, doesn't change original data.
        NOTE: data cleaning and preprocessing is not here,
        here is only feats engineering

        Args:
            [market_train_df, news_train_df]: pandas.DataFrame
        Returns:
            complete_features: pandas.DataFrame
        """
        start_time = time()
        if verbose: print("Starting features generation for model {}, {}".format(self.name, ctime()))

        complete_features = market_data.copy()
        complete_features['open+close'] = complete_features['open'] + complete_features['close']
        
        complete_features['lag_10_open_max'] = complete_features['open'].rolling(10, min_periods=1).max()
        self.max_lag = 10
        
        complete_features.drop(['time','assetCode','assetName'],axis=1,inplace=True)
        complete_features.fillna(0, inplace=True)

        if verbose: print("Finished features generation for model {}, TIME {}".format(self.name, time()-start_time))
        return complete_features

    def train(self, X, Y, verbose=False):
        """
        basic method to train a model with given data
        model will be inside self.model after training

        Args:
            X: [market_train_df, news_train_df]
            Y: [target]
            verbose: (bool)
        Returns:
            (optional) training_results
        """
        start_time = time()
        if verbose: print("Starting training for model {}, {}".format(self.name, ctime()))

        X_train = self._generate_features(X[0], X[1])
        if verbose: print("X_train shape {}".format(X_train.shape))
        self.model = LinearRegression()
        self.model.fit(X_train, Y)
        del X_train

        if verbose: print("Finished training for model {}, TIME {}".format(self.name, time()-start_time))


    def predict(self, X, verbose=False):
        """
        given a block of X features gives prediction for everyrow

        Args:
            X: [market_train_df, news_train_df]
        Returns:
            y: pandas.Series
        """
        start_time = time()
        if verbose: print("Starting prediction for model {}, {}".format(self.name, ctime()))
        if self.model is None:
            raise "Error: model is not trained!"

        X_test = self._generate_features(X[0], X[1])
        if verbose: print("X_test shape {}".format(X_test.shape))
        y_test = self.model.predict(X_test)

        if verbose: print("Finished prediction for model {}, TIME {}".format(self.name, time()-start_time))
        return y_test


    def predict_rolling(self, historical_df, prediction_length, verbose=False):
        """
        predict features from X, uses historical for (lagged) feature generation
        to be used with rolling prediciton structure from competition

        Args:
            historical_df: [market_train_df, news_train_df]
            prediction_length: generate features on historical_df, predict only on the last rows
        """
        start_time = time()
        if verbose: print("Starting rolled prediction for model {}, {}".format(self.name, ctime()))

        processed_historical_df = self._generate_features(historical_df[0], historical_df[1])
        X_test = processed_historical_df.iloc[-prediction_length:]
        if verbose: print("X_test shape {}".format(X_test.shape))
        y_test = self.model.predict(X_test)

        if verbose: print("Finished rolled prediction for model {}, TIME {}".format(self.name, time()-start_time))
        return y_test

# %% [markdown]
# <h1>Get data

# %%
from kaggle.competitions import twosigmanews
# You can only call make_env() once, so don't lose it!
env = twosigmanews.make_env()
# Out:
# Loading the data... This could take a minute.
# Done!

# %%
(market_train_df, news_train_df) = env.get_training_data()

# %% [markdown]
# <h1>`Datacleaning and preprocessing procedure

# %% [markdown]
# datacleaning will applied to the whole dataset for every model, the only requirements is that at the end of the procedure ***NO NEW FEATURES can be added here***. They must be added inside the feature generation section of the model

# %%
import pandas as pd
import numpy as np
def prepare_predictions(market_obs_df):
    market_obs_df['close_to_open'] =  np.abs(market_obs_df['close'] / market_obs_df['open'])
    market_obs_df['assetName_mean_open'] = market_obs_df.groupby('assetName')['open'].transform('mean')
    market_obs_df['assetName_mean_close'] = market_obs_df.groupby('assetName')['close'].transform('mean')

    # if open price is too far from mean open price for this company, replace it. Otherwise replace close price.
    for i, row in market_obs_df.loc[market_obs_df['close_to_open'] >= 2].iterrows():
        if np.abs(row['assetName_mean_open'] - row['open']) > np.abs(row['assetName_mean_close'] - row['close']):
            market_obs_df.iloc[i,5] = row['assetName_mean_open']
        else:
            market_obs_df.iloc[i,4] = row['assetName_mean_close']

    for i, row in market_obs_df.loc[market_obs_df['close_to_open'] <= 0.5].iterrows():
        if np.abs(row['assetName_mean_open'] - row['open']) > np.abs(row['assetName_mean_close'] - row['close']):
            market_obs_df.iloc[i,5] = row['assetName_mean_open']
        else:
            market_obs_df.iloc[i,4] = row['assetName_mean_close']
            
    return market_obs_df.drop(['assetName_mean_open', 'assetName_mean_close','close_to_open'],axis=1)

# %%
market_train_df = prepare_predictions(market_train_df)
market_train_df = market_train_df.loc[market_train_df['time'] >= '2010-01-01 22:00:00+0000']

# %%
bottom, top = market_train_df.returnsOpenNextMktres10.quantile(0.001), market_train_df.returnsOpenNextMktres10.quantile(0.999)
market_train_df.returnsOpenNextMktres10 = market_train_df.returnsOpenNextMktres10.clip(bottom, top)

# %% [markdown]
# <h1>Initialize and train model

# %%
model = model_example('example_Linear_Regression')
# Out:
# init model example_Linear_Regression

# %%
target = market_train_df.returnsOpenNextMktres10
market_train_df.drop('returnsOpenNextMktres10', axis=1, inplace=True)

# %%
model.train([market_train_df, news_train_df], target, verbose=True)
# Out:
# Starting training for model example_Linear_Regression, Thu Dec 20 17:15:58 2018
# X_train shape (2946739, 14)
# Finished training for model example_Linear_Regression, TIME 3.053800582885742

# %% [markdown]
# <h1>Prediction loop

# %%
days = env.get_prediction_days()

# %%
# skip a prediction (for testing)
# env.predict(predictions_template_df)

# %%
from time import time, ctime

total_market_df = pd.DataFrame(columns=['time', 'assetCode', 'assetName', 'volume', 'close', 'open',
       'returnsClosePrevRaw1', 'returnsOpenPrevRaw1',
       'returnsClosePrevMktres1', 'returnsOpenPrevMktres1',
       'returnsClosePrevRaw10', 'returnsOpenPrevRaw10',
       'returnsClosePrevMktres10', 'returnsOpenPrevMktres10','period', 'universe'])

max_lag, days_count = model.max_lag, 0
for (market_obs_df, news_obs_df, predictions_template_df) in days:
    days_count += 1
    if not days_count%50: print(days_count)
        
    market_obs_df['period']   = days_count
    market_obs_df['universe'] = 1
    
    start_time = time()
    total_market_df = pd.concat([total_market_df, market_obs_df])
    #total_news_obs_df.append(news_obs_df)
        
    history_market_df = total_market_df[total_market_df['period'] > days_count - max_lag - 1].drop('period', axis=1)
    predictions = model.predict_rolling([history_market_df, None],
                                        len(predictions_template_df), verbose=True)
    
    predictions_template_df.confidenceValue = predictions.clip(-1, 1)
    env.predict(predictions_template_df)
    print("[{}] loop prediction {}, TIME {}".format(days_count, ctime(), time()-start_time))
print('Done!')
# Out:
# [1] created history dataframes Thu Dec 20 17:16:37 2018, TIME 0.008631229400634766
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:16:37 2018
# X_test shape (1823, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.008206605911254883
# [1] loop prediction Thu Dec 20 17:16:37 2018, TIME 0.016048908233642578
# [2] created history dataframes Thu Dec 20 17:16:37 2018, TIME 0.008676290512084961
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:16:37 2018
# X_test shape (1818, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.01040506362915039
# [2] loop prediction Thu Dec 20 17:16:37 2018, TIME 0.021320104598999023
# [3] created history dataframes Thu Dec 20 17:16:37 2018, TIME 0.00991058349609375
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:16:38 2018
# X_test shape (1821, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.007759571075439453
# [3] loop prediction Thu Dec 20 17:16:38 2018, TIME 0.014907121658325195
# [4] created history dataframes Thu Dec 20 17:16:38 2018, TIME 0.009571313858032227
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:16:38 2018
# X_test shape (1822, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.008573770523071289
# [4] loop prediction Thu Dec 20 17:16:38 2018, TIME 0.01610589027404785
# [5] created history dataframes Thu Dec 20 17:16:38 2018, TIME 0.009150266647338867
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:16:38 2018
# X_test shape (1820, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.010111331939697266
# [5] loop prediction Thu Dec 20 17:16:38 2018, TIME 0.018307924270629883
# [6] created history dataframes Thu Dec 20 17:16:38 2018, TIME 0.009518146514892578
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:16:38 2018
# X_test shape (1825, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.010863065719604492
# [6] loop prediction Thu Dec 20 17:16:38 2018, TIME 0.01968526840209961
# [7] created history dataframes Thu Dec 20 17:16:38 2018, TIME 0.01094198226928711
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:16:38 2018
# X_test shape (1823, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.012344121932983398
# [7] loop prediction Thu Dec 20 17:16:38 2018, TIME 0.023148298263549805
# [8] created history dataframes Thu Dec 20 17:16:38 2018, TIME 0.011473894119262695
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:16:38 2018
# X_test shape (1825, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.013174295425415039
# [8] loop prediction Thu Dec 20 17:16:38 2018, TIME 0.02403569221496582
# [9] created history dataframes Thu Dec 20 17:16:38 2018, TIME 0.012803077697753906
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:16:38 2018
# X_test shape (1830, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.013554096221923828
# [9] loop prediction Thu Dec 20 17:16:38 2018, TIME 0.026117563247680664
# [10] created history dataframes Thu Dec 20 17:16:38 2018, TIME 0.010987281799316406
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:16:38 2018
# X_test shape (1831, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.013602256774902344
# [10] loop prediction Thu Dec 20 17:16:38 2018, TIME 0.024438858032226562
# [11] created history dataframes Thu Dec 20 17:16:38 2018, TIME 0.011232852935791016
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:16:38 2018
# X_test shape (1828, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.014447927474975586
# [11] loop prediction Thu Dec 20 17:16:38 2018, TIME 0.026001930236816406
# [12] created history dataframes Thu Dec 20 17:16:38 2018, TIME 0.011309623718261719
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:16:38 2018
# X_test shape (1819, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.014355897903442383
# [12] loop prediction Thu Dec 20 17:16:38 2018, TIME 0.026343107223510742
# [13] created history dataframes Thu Dec 20 17:16:38 2018, TIME 0.013412714004516602
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:16
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:16:40 2018
# X_test shape (1807, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.02198338508605957
# [42] loop prediction Thu Dec 20 17:16:40 2018, TIME 0.05528593063354492
# [43] created history dataframes Thu Dec 20 17:16:40 2018, TIME 0.03280901908874512
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:16:40 2018
# X_test shape (1807, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.02752852439880371
# [43] loop prediction Thu Dec 20 17:16:40 2018, TIME 0.06231856346130371
# [44] created history dataframes Thu Dec 20 17:16:40 2018, TIME 0.17869949340820312
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:16:40 2018
# X_test shape (1810, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.016927003860473633
# [44] loop prediction Thu Dec 20 17:16:40 2018, TIME 0.0492098331451416
# [45] created history dataframes Thu Dec 20 17:16:40 2018, TIME 0.03230786323547363
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:16:40 2018
# X_test shape (1810, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.02175307273864746
# [45] loop prediction Thu Dec 20 17:16:40 2018, TIME 0.05737948417663574
# [46] created history dataframes Thu Dec 20 17:16:40 2018, TIME 0.033023834228515625
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:16:40 2018
# X_test shape (1809, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.02328205108642578
# [46] loop prediction Thu Dec 20 17:16:40 2018, TIME 0.059307098388671875
# [47] created history dataframes Thu Dec 20 17:16:40 2018, TIME 0.0366969108581543
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:16:40 2018
# X_test shape (1808, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.023591995239257812
# [47] loop prediction Thu Dec 20 17:16:40 2018, TIME 0.061542510986328125
# [48] created history dataframes Thu Dec 20 17:16:40 2018, TIME 0.03560924530029297
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:16:40 2018
# X_test shape (1807, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.02248835563659668
# [48] loop prediction Thu Dec 20 17:16:40 2018, TIME 0.06013965606689453
# [49] created history dataframes Thu Dec 20 17:16:40 2018, TIME 0.03459620475769043
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:16:40 2018
# X_test shape (1807, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.022391319274902344
# [49] loop prediction Thu Dec 20 17:16:40 2018, TIME 0.06053519248962402
# 50
# [50] created history dataframes Thu Dec 20 17:16:41 2018, TIME 0.03521394729614258
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:16:41 2018
# X_test shape (1808, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.016019821166992188
# [50] loop prediction Thu Dec 20 17:16:41 2018, TIME 0.10560727119445801
# [51] created history dataframes Thu Dec 20 17:16:41 2018, TIME 0.03453207015991211
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:16:41 2018
# X_test shape (1806, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.02197575569152832
# [51] loop prediction Thu Dec 20 17:16:41 2018, TIME 0.060700178146362305
# [52] created history dataframes Thu Dec 20 17:16:41 2018, TIME 0.036971092224121094
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:16:41 2018
# X_test shape (1809, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.023107528686523438
# [52] loop prediction Thu Dec 20 17:16:41 2018, TIME 0.06347870826721191
# [53] created history dataframes Thu Dec 20 17:16:41 2018, TIME 0.03598928451538086
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:16:41 2018
# X_test shape (1813, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.02212357521057129
# [53] loop prediction Thu Dec 20 17:16:41 2018, TIME 0.06242513656616211
# [54] created history dataframes Thu Dec 20 17:16:41 2018, TIME 0.03856682777404785
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:16:41 2018
# X_test shape (1814, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.021816492080688477
# [54] loop prediction Thu Dec 20 17:16:41 2018, TIME 0.0626060962677002
# [55] created history dataframes Thu Dec 20 17:16:41 2018, TIME 0.03891801834106445
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:16:41 2018
# X_test shape (1811, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.021936416625976562
# [55] loop prediction Thu Dec 20 17:16:41 2018, TIME 0.06287240982055664
# [56] created history dataframes Thu Dec 20 17:16:41 2018, TIME 0.037926435470581055
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:16
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:16:51 2018
# X_test shape (1786, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.015843868255615234
# [128] loop prediction Thu Dec 20 17:16:51 2018, TIME 0.0855562686920166
# [129] created history dataframes Thu Dec 20 17:16:51 2018, TIME 0.06716084480285645
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:16:51 2018
# X_test shape (1789, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.01583576202392578
# [129] loop prediction Thu Dec 20 17:16:52 2018, TIME 0.08939385414123535
# [130] created history dataframes Thu Dec 20 17:16:52 2018, TIME 0.06977391242980957
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:16:52 2018
# X_test shape (1790, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.015126466751098633
# [130] loop prediction Thu Dec 20 17:16:52 2018, TIME 0.08592557907104492
# [131] created history dataframes Thu Dec 20 17:16:52 2018, TIME 0.06668210029602051
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:16:52 2018
# X_test shape (1791, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.026403427124023438
# [131] loop prediction Thu Dec 20 17:16:52 2018, TIME 0.10010862350463867
# [132] created history dataframes Thu Dec 20 17:16:52 2018, TIME 0.06770658493041992
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:16:52 2018
# X_test shape (1791, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.01588273048400879
# [132] loop prediction Thu Dec 20 17:16:52 2018, TIME 0.08948016166687012
# [133] created history dataframes Thu Dec 20 17:16:52 2018, TIME 0.07022380828857422
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:16:52 2018
# X_test shape (1796, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.016285419464111328
# [133] loop prediction Thu Dec 20 17:16:52 2018, TIME 0.08982706069946289
# [134] created history dataframes Thu Dec 20 17:16:52 2018, TIME 0.0723428726196289
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:16:52 2018
# X_test shape (1797, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.015207052230834961
# ...
# X_test shape (1858, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.018335342407226562
# [594] loop prediction Thu Dec 20 17:19:41 2018, TIME 0.3146514892578125
# [595] created history dataframes Thu Dec 20 17:19:41 2018, TIME 0.28717994689941406
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:19:42 2018
# X_test shape (1854, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.013820648193359375
# [595] loop prediction Thu Dec 20 17:19:42 2018, TIME 0.3009178638458252
# [596] created history dataframes Thu Dec 20 17:19:42 2018, TIME 0.2893867492675781
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:19:42 2018
# X_test shape (1856, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.01384735107421875
# [596] loop prediction Thu Dec 20 17:19:42 2018, TIME 0.3070967197418213
# [597] created history dataframes Thu Dec 20 17:19:43 2018, TIME 0.2820403575897217
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:19:43 2018
# X_test shape (1855, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.01710057258605957
# [597] loop prediction Thu Dec 20 17:19:43 2018, TIME 0.3004636764526367
# [598] created history dataframes Thu Dec 20 17:19:43 2018, TIME 0.2885584831237793
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:19:43 2018
# X_test shape (1855, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.014036178588867188
# [598] loop prediction Thu Dec 20 17:19:43 2018, TIME 0.30005407333374023
# [599] created history dataframes Thu Dec 20 17:19:44 2018, TIME 0.28404879570007324
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:19:44 2018
# X_test shape (1850, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.013566255569458008
# [599] loop prediction Thu Dec 20 17:19:44 2018, TIME 0.303692102432251
# 600
# [600] created history dataframes Thu Dec 20 17:19:44 2018, TIME 0.2675027847290039
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:19:45 2018
# X_test shape (1849, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.01343226432800293
# [600] loop prediction Thu Dec 20 17:19:45 2018, TIME 0.29740381240844727
# [601] created history dataframes Thu Dec 20 17:19:45 2018, TIME 0.2704901695251465
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:19:45 2018
# X_test shape (1853, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.013989686965942383
# [601] loop prediction Thu Dec 20 17:19:45 2018, TIME 0.3089432716369629
# [602] created history dataframes Thu Dec 20 17:19:46 2018, TIME 0.29229187965393066
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:19:46 2018
# X_test shape (1850, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.013940811157226562
# [602] loop prediction Thu Dec 20 17:19:46 2018, TIME 0.3043808937072754
# [603] created history dataframes Thu Dec 20 17:19:46 2018, TIME 0.27344393730163574
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:19:46 2018
# X_test shape (1852, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.019258499145507812
# [603] loop prediction Thu Dec 20 17:19:46 2018, TIME 0.30792713165283203
# [604] created history dataframes Thu Dec 20 17:19:47 2018, TIME 0.29100608825683594
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:19:47 2018
# X_test shape (1846, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.0187532901763916
# [604] loop prediction Thu Dec 20 17:19:47 2018, TIME 0.3185288906097412
# [605] created history dataframes Thu Dec 20 17:19:47 2018, TIME 0.27582240104675293
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:19:48 2018
# X_test shape (1848, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.016654491424560547
# [605] loop prediction Thu Dec 20 17:19:48 2018, TIME 0.31243252754211426
# [606] created history dataframes Thu Dec 20 17:19:48 2018, TIME 0.2765767574310303
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:19:48 2018
# X_test shape (1849, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.015003681182861328
# [606] loop prediction Thu Dec 20 17:19:48 2018, TIME 0.30675387382507324
# [607] created history dataframes Thu Dec 20 17:19:49 2018, TIME 0.29184937477111816
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:19:49 2018
# X_test shape (1848, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.014371871948242188
# [607] loop prediction Thu Dec 20 17:19:49 2018, TIME 0.3060002326965332
# [608] created history dataframes Thu Dec 20 17:19:49 2018, TIME 0.286637544631958
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:19:49 2018
# X_test shape (1842, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.013443231582641602
# [608] loop prediction Thu Dec 20 17:19:49 2018, TIME 0.30631470680236816
# [609] created history dataframes Thu Dec 20 17:19:50 2018, TIME 0.29107236862182617
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:19:50 2018
# X_test shape (1845, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.015037059783935547
# [609] loop prediction Thu Dec 20 17:19:50 2018, TIME 0.30701470375061035
# [610] created history dataframes Thu Dec 20 17:19:50 2018, TIME 0.27454066276550293
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:19:51 2018
# X_test shape (1846, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.014000892639160156
# [610] loop prediction Thu Dec 20 17:19:51 2018, TIME 0.30501651763916016
# [611] created history dataframes Thu Dec 20 17:19:51 2018, TIME 0.2974891662597656
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:19:51 2018
# X_test shape (1852, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.014677047729492188
# [611] loop prediction Thu Dec 20 17:19:51 2018, TIME 0.30927085876464844
# [612] created history dataframes Thu Dec 20 17:19:52 2018, TIME 0.29429101943969727
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:19:52 2018
# X_test shape (1855, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.013703346252441406
# [612] loop prediction Thu Dec 20 17:19:52 2018, TIME 0.3129289150238037
# [613] created history dataframes Thu Dec 20 17:19:52 2018, TIME 0.2848334312438965
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:19:52 2018
# X_test shape (1825, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.01667189598083496
# [613] loop prediction Thu Dec 20 17:19:52 2018, TIME 0.3179357051849365
# [614] created history dataframes Thu Dec 20 17:19:53 2018, TIME 0.2815830707550049
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:19:53 2018
# X_test shape (1822, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.014204740524291992
# [614] loop prediction Thu Dec 20 17:19:53 2018, TIME 0.3168802261352539
# [615] created history dataframes Thu Dec 20 17:19:53 2018, TIME 0.289931058883667
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:19:54 2018
# X_test shape (1825, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.015250444412231445
# [615] loop prediction Thu Dec 20 17:19:54 2018, TIME 0.31012415885925293
# [616] created history dataframes Thu Dec 20 17:19:54 2018, TIME 0.27739620208740234
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:19:54 2018
# X_test shape (1825, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.014135360717773438
# [616] loop prediction Thu Dec 20 17:19:54 2018, TIME 0.31028246879577637
# [617] created history dataframes Thu Dec 20 17:19:55 2018, TIME 0.2926640510559082
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:19:55 2018
# X_test shape (1821, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.014230966567993164
# [617] loop prediction Thu Dec 20 17:19:55 2018, TIME 0.31201934814453125
# [618] created history dataframes Thu Dec 20 17:19:55 2018, TIME 0.2813704013824463
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:19:55 2018
# X_test shape (1818, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.01340794563293457
# [618] loop prediction Thu Dec 20 17:19:55 2018, TIME 0.30695343017578125
# [619] created history dataframes Thu Dec 20 17:19:56 2018, TIME 0.29225850105285645
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:19:56 2018
# X_test shape (1814, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.013138771057128906
# [619] loop prediction Thu Dec 20 17:19:56 2018, TIME 0.30942630767822266
# [620] created history dataframes Thu Dec 20 17:19:56 2018, TIME 0.2941782474517822
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:19:57 2018
# X_test shape (1816, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.014661312103271484
# [620] loop prediction Thu Dec 20 17:19:57 2018, TIME 0.3071742057800293
# [621] created history dataframes Thu Dec 20 17:19:57 2018, TIME 0.27242136001586914
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:19:57 2018
# X_test shape (1813, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.013349771499633789
# [621] loop prediction Thu Dec 20 17:19:57 2018, TIME 0.31176304817199707
# [622] created history dataframes Thu Dec 20 17:19:58 2018, TIME 0.27376389503479004
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:19:58 2018
# X_test shape (1812, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.013775348663330078
# [622] loop prediction Thu Dec 20 17:19:58 2018, TIME 0.3140127658843994
# [623] created history dataframes Thu Dec 20 17:19:58 2018, TIME 0.29416894912719727
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:19:58 2018
# X_test shape (1804, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.013428449630737305
# [623] loop prediction Thu Dec 20 17:19:58 2018, TIME 0.3109455108642578
# [624] created history dataframes Thu Dec 20 17:19:59 2018, TIME 0.295673131942749
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:19:59 2018
# X_test shape (1806, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.013837099075317383
# [624] loop prediction Thu Dec 20 17:19:59 2018, TIME 0.3112363815307617
# [625] created history dataframes Thu Dec 20 17:19:59 2018, TIME 0.2751131057739258
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:20:00 2018
# X_test shape (1813, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.015304327011108398
# [625] loop prediction Thu Dec 20 17:20:00 2018, TIME 0.31371355056762695
# [626] created history dataframes Thu Dec 20 17:20:00 2018, TIME 0.3005659580230713
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:20:00 2018
# X_test shape (1813, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.017585277557373047
# [626] loop prediction Thu Dec 20 17:20:00 2018, TIME 0.32103657722473145
# [627] created history dataframes Thu Dec 20 17:20:01 2018, TIME 0.2868227958679199
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:20:01 2018
# X_test shape (1812, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.013570547103881836
# [627] loop prediction Thu Dec 20 17:20:01 2018, TIME 0.31665730476379395
# [628] created history dataframes Thu Dec 20 17:20:01 2018, TIME 0.2870657444000244
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:20:02 2018
# X_test shape (1804, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.014031648635864258
# [628] loop prediction Thu Dec 20 17:20:02 2018, TIME 0.31415677070617676
# [629] created history dataframes Thu Dec 20 17:20:02 2018, TIME 0.30220627784729004
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:20:02 2018
# X_test shape (1812, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.01454019546508789
# [629] loop prediction Thu Dec 20 17:20:02 2018, TIME 0.31648683547973633
# [630] created history dataframes Thu Dec 20 17:20:02 2018, TIME 0.297778844833374
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:20:03 2018
# X_test shape (1811, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.013553857803344727
# [630] loop prediction Thu Dec 20 17:20:03 2018, TIME 0.31128573417663574
# [631] created history dataframes Thu Dec 20 17:20:03 2018, TIME 0.3016977310180664
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:20:03 2018
# X_test shape (1810, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.01634359359741211
# [631] loop prediction Thu Dec 20 17:20:03 2018, TIME 0.3245406150817871
# [632] created history dataframes Thu Dec 20 17:20:04 2018, TIME 0.30930185317993164
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:20:04 2018
# X_test shape (1809, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.01703667640686035
# [632] loop prediction Thu Dec 20 17:20:04 2018, TIME 0.3241434097290039
# [633] created history dataframes Thu Dec 20 17:20:04 2018, TIME 0.303206205368042
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:20:05 2018
# X_test shape (1808, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.015036821365356445
# [633] loop prediction Thu Dec 20 17:20:05 2018, TIME 0.3190021514892578
# [634] created history dataframes Thu Dec 20 17:20:05 2018, TIME 0.3097388744354248
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:20:05 2018
# X_test shape (1813, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.021777868270874023
# [634] loop prediction Thu Dec 20 17:20:05 2018, TIME 0.33150649070739746
# [635] created history dataframes Thu Dec 20 17:20:06 2018, TIME 0.28455281257629395
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:20:06 2018
# X_test shape (1813, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.01658463478088379
# [635] loop prediction Thu Dec 20 17:20:06 2018, TIME 0.3366572856903076
# [636] created history dataframes Thu Dec 20 17:20:06 2018, TIME 0.30551767349243164
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:20:07 2018
# X_test shape (1816, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.01581597328186035
# [636] loop prediction Thu Dec 20 17:20:07 2018, TIME 0.32132387161254883
# [637] created history dataframes Thu Dec 20 17:20:07 2018, TIME 0.2941913604736328
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:20:07 2018
# X_test shape (1816, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.01613140106201172
# [637] loop prediction Thu Dec 20 17:20:07 2018, TIME 0.32713794708251953
# [638] created history dataframes Thu Dec 20 17:20:08 2018, TIME 0.3072786331176758
# Starting rolled prediction for model example_Linear_Regression, Thu Dec 20 17:20:08 2018
# X_test shape (1815, 14)
# Finished rolled prediction for model example_Linear_Regression, TIME 0.015806913375854492
# [638] loop prediction Thu Dec 20 17:20:08 2018, TIME 0.322094202041626
# Done!

# %% [markdown]
# ## **`write_submission_file`** function
#
# Writes your predictions to a CSV file (`submission.csv`) in the current working directory.

# %%
env.write_submission_file()

# %%
# We've got a submission file!
import os
print([filename for filename in os.listdir('.') if '.csv' in filename])

# %% [markdown]
# As indicated by the helper message, calling `write_submission_file` on its own does **not** make a submission to the competition.  It merely tells the module to write the `submission.csv` file as part of the Kernel's output.  To make a submission to the competition, you'll have to **Commit** your Kernel and find the generated `submission.csv` file in that Kernel Version's Output tab (note this is _outside_ of the Kernel Editor), then click "Submit to Competition".  When we re-run your Kernel during Stage Two, we will run the Kernel Version (generated when you hit "Commit") linked to your chosen Submission.

# %% [markdown]
# ## Restart the Kernel to run your code again
# In order to combat cheating, you are only allowed to call `make_env` or iterate through `get_prediction_days` once per Kernel run.  However, while you're iterating on your model it's reasonable to try something out, change the model a bit, and try it again.  Unfortunately, if you try to simply re-run the code, or even refresh the browser page, you'll still be running on the same Kernel execution session you had been running before, and the `twosigmanews` module will still throw errors.  To get around this, you need to explicitly restart your Kernel execution session, which you can do by pressing the Restart button in the Kernel Editor's bottom Console tab:
# ![Restart button](https://i.imgur.com/hudu8jF.png)
